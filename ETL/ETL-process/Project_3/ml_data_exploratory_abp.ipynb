# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
all_race_df_path = "../../../machine_learning/Resources/final_combined_avg_2009_2030.csv"
all_race_df = pd.read_csv(all_race_df_path)
all_race_df
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                     26.75          8.92         7845.04
# 1   2010                     25.72          9.29         7816.88
# 2   2011                     27.87          9.23         7603.67
# 3   2012                     29.93         10.21         8014.04
# 4   2013                     31.73         10.20         7635.30
# 5   2014                     32.34         10.07         7233.48
# 6   2015                     31.94         10.68         7530.67
# 7   2016                     35.44         10.67         7582.19
# 8   2017                     34.21         10.87         7658.86
# 9   2018                     31.53         11.51         8270.43
# 10  2019                     34.07         11.65         8077.37
# 11  2020                     35.96         11.88         7870.16
# 12  2021                     36.78         12.14         7889.92
# ...

# %%
all_race_df = all_race_df.set_index('year')

# %%
# Creating subplots of the all race dataframe
df_plots = all_race_df.plot(subplots=True, figsize=(16,14))

# set the spacing between subplots 
plt.subplots_adjust(left=0.125,
                    bottom=0.20, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.35)
