# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# CSV files to import

MMR_totals = "../../output_file/2009_2019_CDC_MMR.csv"
M_Deaths_race = "../../Resources/Maternal_Deaths_race_2009-2019.csv"
M_race_births = "../../Resources/Births_Maternal_race_2009-2019.csv"

# %%
# read csv files
MMR_totals = pd.read_csv(MMR_totals)
deaths_df = pd.read_csv(M_Deaths_race)
births_mat_race = pd.read_csv(M_race_births)

# %% [markdown]
# ### Maternal Deaths by race 2009-2019
# #### Publicly available Underlying Cause of Death data produced by the National Center for Health Statistics (NCHS) and collected from the [CDC Wonder site](https://wonder.cdc.gov/ucd-icd10.html).

# %%
deaths_df.head()
# Out:
#      State  State Code  Year                       Race Race Code  \
# 0  Alabama           1  2016  Black or African American    2054-5
# 1  Alabama           1  2016                      White    2106-3
# 2  Alabama           1  2017  Black or African American    2054-5
# 3  Alabama           1  2017                      White    2106-3
# 4  Alabama           1  2018  Black or African American    2054-5
#
#           Hispanic Origin Hispanic Origin Code  Deaths  Population  Crude Rate
# 0  Not Hispanic or Latino               2186-2      14           0  Unreliable
# 1  Not Hispanic or Latino               2186-2      18           0  Unreliable
# 2  Not Hispanic or Latino               2186-2      25      704201         3.6
# 3  Not Hispanic or Latino               2186-2      15     1655605  Unreliable
# 4  Not Hispanic or Latino               2186-2      14      706754  Unreliable

# %%
# change "Population" column to "Population by Race"
deaths_race_df = deaths_df.rename(columns={"State": "state",
                                           "State Code": "state_code",
                                           "Year": "year",
                                           "Population": "population_by_race",
                                           "Deaths": "deaths_by_race"})
deaths_race_df.head()
# Out:
#      state  state_code  year                       Race Race Code  \
# 0  Alabama           1  2016  Black or African American    2054-5
# 1  Alabama           1  2016                      White    2106-3
# 2  Alabama           1  2017  Black or African American    2054-5
# 3  Alabama           1  2017                      White    2106-3
# 4  Alabama           1  2018  Black or African American    2054-5
#
#           Hispanic Origin Hispanic Origin Code  deaths_by_race  \
# 0  Not Hispanic or Latino               2186-2              14
# 1  Not Hispanic or Latino               2186-2              18
# 2  Not Hispanic or Latino               2186-2              25
# 3  Not Hispanic or Latino               2186-2              15
# 4  Not Hispanic or Latino               2186-2              14
#
#    population_by_race  Crude Rate
# 0                   0  Unreliable
# 1                   0  Unreliable
# 2              704201         3.6
# 3             1655605  Unreliable
# 4              706754  Unreliable

# %% [markdown]
# ### Natality data by race 2009-2019
# #### Publicly available natality data produced by:
# #### United States Department of Health and Human Services (US DHHS), Centers for Disease Control and Prevention (CDC), National Center for Health Statistics (NCHS), Division of Vital Statistics (DVS), and collected from the [CDC Wonder Site](https://wonder.cdc.gov/natality-current.html)

# %%
# dataframe for births by maternal race
# change race column names to match for merging
# noting that for births the race is the maternal race
births_mat_race.head()
births_by_race = births_mat_race.rename(columns={"Births": "births_by_race", 
                                    "Mother's Bridged Race": "Race", 
                                    "Mother's Bridged Race Code": "Race Code", 
                                    "Mother's Hispanic Origin": "Hispanic Origin",
                                    "Mother's Hispanic Origin Code": "Hispanic Origin Code",
                                    "State": "state",
                                    "State Code": "state_code",
                                    "Year": "year"})
births_by_race.head()
# Out:
#      state  state_code  year                              Race Race Code  \
# 0  Alabama           1  2009  American Indian or Alaska Native    1002-5
# 1  Alabama           1  2009  American Indian or Alaska Native    1002-5
# 2  Alabama           1  2009         Asian or Pacific Islander      A-PI
# 3  Alabama           1  2009         Black or African American    2054-5
# 4  Alabama           1  2009         Black or African American    2054-5
#
#           Hispanic Origin Hispanic Origin Code  births_by_race
# 0      Hispanic or Latino               2135-2              13
# 1  Not Hispanic or Latino               2186-5             203
# 2  Not Hispanic or Latino               2186-5             981
# 3      Hispanic or Latino               2135-2              53
# 4  Not Hispanic or Latino               2186-5           19230

# %% [markdown]
# #### Merge maternal death and natality data for 2009-2019

# %%
race_birth_death_df = deaths_race_df.merge(births_by_race, how="left", on=["state", "year", "Race", "Hispanic Origin"])
race_birth_death_df.head()

# clean up by selecting only the columns we need
race_birth_death_df_clean = race_birth_death_df[["state", "state_code_x", "year", "Race",\
                                                "Race Code_x", "Hispanic Origin",\
                                                "Hispanic Origin Code_x", "deaths_by_race",\
                                                "population_by_race", "births_by_race"]]
race_birth_death_df_clean.head()

# clean by renaming columns
race_b_d_df = race_birth_death_df_clean.rename(columns={"Race": "race", 
                                    "Race Code_x": "race_code", 
                                    "Hispanic Origin": "hispanic_origin",             
                                    "Hispanic Origin Code_x":"hispanic_origin_code",
                                    "state_code_x": "state_code"})
race_b_d_df
# Out:
#              state  state_code  year                       race race_code  \
# 0          Alabama           1  2016  Black or African American    2054-5
# 1          Alabama           1  2016                      White    2106-3
# 2          Alabama           1  2017  Black or African American    2054-5
# 3          Alabama           1  2017                      White    2106-3
# 4          Alabama           1  2018  Black or African American    2054-5
# ..             ...         ...   ...                        ...       ...
# 383  West Virginia          54  2018                      White    2106-3
# 384      Wisconsin          55  2009                      White    2106-3
# 385      Wisconsin          55  2011                      White    2106-3
# 386      Wisconsin          55  2014                      White    2106-3
# 387      Wisconsin          55  2015                      White    2106-3
#
#             hispanic_origin hispanic_origin_code  deaths_by_race  \
# 0    Not Hispanic or Latino               2186-2              14
# 1    Not Hispanic or Latino               2186-2              18
# 2    Not Hispanic or Latino               2186-2              25
# 3    Not Hispanic or Latino               2186-2              15
# 4    Not Hispanic or Latino               2186-2              14
# ..                      ...                  ...             ...
# 383  Not Hispanic or Latino               2186-2              10
# 384  Not Hispanic or Latino               2186-2              10
# 385  Not Hispanic or Latino               2186-2              10
# 386  Not Hispanic or Latino               2186-2              13
# 387  Not Hispanic or Latino               2186-2              10
#
#      population_by_race  births_by_race
# 0                     0           17989
# 1                     0           35319
# 2                704201           18354
# 3               1655605           34784
# 4                706754           17939
# ..                  ...             ...
# 383              853052           16785
# 384                   0           52462
# 385                   0           50500
# 386             2409803           49440
# 387                   0           49024
#
# [388 rows x 10 columns]

# %% [markdown]
# #### Bring in previously calculated MMR data from Project 2, with totals per state, per year, not stratified by race

# %%
MMR_totals.head()
# Out:
#    record_id    state     id  state_code  year  deaths  births  \
# 0          0  Alabama  US.AL           1  2015      12   59657
# 1          1  Alabama  US.AL           1  2016      35   59151
# 2          2  Alabama  US.AL           1  2017      41   58941
# 3          3  Alabama  US.AL           1  2018      31   57761
# 4          4  Alabama  US.AL           1  2019      35   58615
#
#    maternal_mortality_ratio  population
# 0                     20.11     2505795
# 1                     59.17     2507714
# 2                     69.56     2514911
# 3                     53.67     2523756
# 4                     59.71     2533668

# %%
# rename columns to clarify these are the total figures
MMR_totals_us = MMR_totals.rename(columns={"population": "total_population",
                                           "maternal_mortality_ratio": "total_mmr",
                                           "deaths": "total_deaths", 
                                           "births": "total_births"})
MMR_totals_us
# Out:
#      record_id      state     id  state_code  year  total_deaths  \
# 0            0    Alabama  US.AL           1  2015            12
# 1            1    Alabama  US.AL           1  2016            35
# 2            2    Alabama  US.AL           1  2017            41
# 3            3    Alabama  US.AL           1  2018            31
# 4            4    Alabama  US.AL           1  2019            35
# ..         ...        ...    ...         ...   ...           ...
# 303        303  Wisconsin  US.WI          55  2014            16
# 304        304  Wisconsin  US.WI          55  2015            11
# 305        305  Wisconsin  US.WI          55  2016            15
# 306        306  Wisconsin  US.WI          55  2017            12
# 307        307  Wisconsin  US.WI          55  2019            13
#
#      total_births  total_mmr  total_population
# 0           59657      20.11           2505795
# 1           59151      59.17           2507714
# 2           58941      69.56           2514911
# 3           57761      53.67           2523756
# 4           58615      59.71           2533668
# ..            ...        ...               ...
# 303         67161      23.82           2898057
# 304         67041      16.41           2903737
# 305         66615      22.52           2905282
# 306         64975      18.47           2912745
# 307         63270      20.55           2925225
#
# [308 rows x 9 columns]

# %% [markdown]
# #### Merge total MMR data with births and death data by maternal race

# %%
CDC_MMR_race_total = race_b_d_df.merge(MMR_totals_us, how="left", on=["state", "year"])
CDC_MMR_race_total.head()
# Out:
#      state  state_code_x  year                       race race_code  \
# 0  Alabama             1  2016  Black or African American    2054-5
# 1  Alabama             1  2016                      White    2106-3
# 2  Alabama             1  2017  Black or African American    2054-5
# 3  Alabama             1  2017                      White    2106-3
# 4  Alabama             1  2018  Black or African American    2054-5
#
#           hispanic_origin hispanic_origin_code  deaths_by_race  \
# 0  Not Hispanic or Latino               2186-2              14
# 1  Not Hispanic or Latino               2186-2              18
# 2  Not Hispanic or Latino               2186-2              25
# 3  Not Hispanic or Latino               2186-2              15
# 4  Not Hispanic or Latino               2186-2              14
#
#    population_by_race  births_by_race  record_id     id  state_code_y  \
# 0                   0           17989          1  US.AL             1
# 1                   0           35319          1  US.AL             1
# 2              704201           18354          2  US.AL             1
# 3             1655605           34784          2  US.AL             1
# 4              706754           17939          3  US.AL             1
#
#    total_deaths  total_births  total_mmr  total_population
# 0            35         59151      59.17           2507714
# 1            35         59151      59.17           2507714
# 2            41         58941      69.56           2514911
# 3            41         58941      69.56           2514911
# 4            31         57761      53.67           2523756

# %%
# clean up by selecting only the columns we need
CDC_MMR_race_total_clean = CDC_MMR_race_total[["state", "state_code_x", "year", "race",\
                                                "race_code", "hispanic_origin",\
                                                "hispanic_origin_code","total_births",\
                                                "births_by_race", "total_deaths",\
                                                "deaths_by_race", "total_mmr",\
                                                "total_population","population_by_race"]]
CDC_MMR_race_total_clean.head()

# rename column
MMR_race_df = CDC_MMR_race_total_clean.rename(columns={"state_code_x": "state_code"})
MMR_race_df.head()
# Out:
#      state  state_code  year                       race race_code  \
# 0  Alabama           1  2016  Black or African American    2054-5
# 1  Alabama           1  2016                      White    2106-3
# 2  Alabama           1  2017  Black or African American    2054-5
# 3  Alabama           1  2017                      White    2106-3
# 4  Alabama           1  2018  Black or African American    2054-5
#
#           hispanic_origin hispanic_origin_code  total_births  births_by_race  \
# 0  Not Hispanic or Latino               2186-2         59151           17989
# 1  Not Hispanic or Latino               2186-2         59151           35319
# 2  Not Hispanic or Latino               2186-2         58941           18354
# 3  Not Hispanic or Latino               2186-2         58941           34784
# 4  Not Hispanic or Latino               2186-2         57761           17939
#
#    total_deaths  deaths_by_race  total_mmr  total_population  \
# 0            35              14      59.17           2507714
# 1            35              18      59.17           2507714
# 2            41              25      69.56           2514911
# 3            41              15      69.56           2514911
# 4            31              14      53.67           2523756
#
#    population_by_race
# 0                   0
# 1                   0
# 2              704201
# 3             1655605
# 4              706754

# %% [markdown]
# #### Calculate MMR by race: maternal deaths / births for the same period x 100,000. The birth data uses the maternal race.

# %%
# maternal deaths / births for same period * 100000
ratio_straight = round((MMR_race_df["deaths_by_race"] / MMR_race_df["births_by_race"]) * 100000, 2)
ratio_straight
# Out:
# 0       77.83
# 1       50.96
# 2      136.21
# 3       43.12
# 4       78.04
#         ...
# 383     59.58
# 384     19.06
# 385     19.80
# 386     26.29
# 387     20.40
# Length: 388, dtype: float64

# %%
# add ratio as a column to our df

MMR_race_df["mmr_by_race"] = ratio_straight
MMR_race_df.head()

# reorder columns

MMR_race_final_df = MMR_race_df[["state", "state_code", "year", "race",\
                                                "race_code", "hispanic_origin",\
                                                "hispanic_origin_code","total_births",\
                                                "births_by_race", "total_deaths",\
                                                "deaths_by_race", "total_mmr", "mmr_by_race",\
                                                "total_population","population_by_race"]]
MMR_race_final_df.head()
# Out:
#      state  state_code  year                       race race_code  \
# 0  Alabama           1  2016  Black or African American    2054-5
# 1  Alabama           1  2016                      White    2106-3
# 2  Alabama           1  2017  Black or African American    2054-5
# 3  Alabama           1  2017                      White    2106-3
# 4  Alabama           1  2018  Black or African American    2054-5
#
#           hispanic_origin hispanic_origin_code  total_births  births_by_race  \
# 0  Not Hispanic or Latino               2186-2         59151           17989
# 1  Not Hispanic or Latino               2186-2         59151           35319
# 2  Not Hispanic or Latino               2186-2         58941           18354
# 3  Not Hispanic or Latino               2186-2         58941           34784
# 4  Not Hispanic or Latino               2186-2         57761           17939
#
#    total_deaths  deaths_by_race  total_mmr  mmr_by_race  total_population  \
# 0            35              14      59.17        77.83           2507714
# 1            35              18      59.17        50.96           2507714
# 2            41              25      69.56       136.21           2514911
# 3            41              15      69.56        43.12           2514911
# 4            31              14      53.67        78.04           2523756
#
#    population_by_race
# 0                   0
# 1                   0
# 2              704201
# 3             1655605
# 4              706754

# %%
# check datatypes
MMR_race_final_df.dtypes
# Out:
# state                    object
# state_code                int64
# year                      int64
# race                     object
# race_code                object
# hispanic_origin          object
# hispanic_origin_code     object
# total_births              int64
# births_by_race            int64
# total_deaths              int64
# deaths_by_race            int64
# total_mmr               float64
# mmr_by_race             float64
# total_population          int64
# population_by_race        int64
# dtype: object

# %% [markdown]
# #### Exploratory Data Analysis: MMR by race for years 2009-2019

# %%
# viewing MMR by race
group_by = MMR_race_final_df.groupby(["race", "hispanic_origin"]).agg({"mmr_by_race":["mean", "median", "max", "min"]})
group_by
# Out:
#                                                  mmr_by_race                  \
#                                                         mean  median     max
# race                      hispanic_origin
# Asian or Pacific Islander Not Hispanic or Latino   17.036667  17.470   20.46
# Black or African American Not Hispanic or Latino   72.913475  66.760  192.68
# White                     Hispanic or Latino       23.804737  23.005   46.58
#                           Not Hispanic or Latino   30.015813  27.180   78.20
#
#
#                                                     min
# race                      hispanic_origin
# Asian or Pacific Islander Not Hispanic or Latino  13.75
# Black or African American Not Hispanic or Latino  32.14
# White                     Hispanic or Latino       8.55
#                           Not Hispanic or Latino  12.33

# %%
# boxplot for MMR by race
boxplot_mmr = MMR_race_final_df.boxplot(column=["mmr_by_race"], by=["race", "hispanic_origin"], figsize=(16,5))


#set x ticks 
positions = (1, 2, 3, 4)
labels = ("Asian or Pacific Islander", "Black or African American", "White", "Hispanic or Latino")
plt.xticks(positions, labels)

# set x and y label
plt.xlabel("Race or Hispanic Origin", fontweight="bold")
plt.ylabel("Maternal Mortality Ratio", fontweight="bold")

# saving plot
plt.savefig("../../../static/img/boxplot_mmr_strat_by_race.png")

# %%
# boxplot for births by race
boxplot_births = MMR_race_final_df.boxplot(column=["births_by_race"], by=["race", "hispanic_origin"], rot=75, figsize=(12,6))
boxplot_births

# %%
# boxplot for maternal deaths by race
boxplot_m_deaths = MMR_race_final_df.boxplot(column=["deaths_by_race"], by=["race", "hispanic_origin"], rot=75, figsize=(12,6))

# %%
# comparing births and deaths by race
MMR_race_final_df.plot.scatter(x="births_by_race", y="deaths_by_race", alpha=0.5)

# %%
# run correlation
MMR_race_final_df.corr()
# Out:
#                     state_code      year  total_births  births_by_race  \
# state_code            1.000000 -0.003414     -0.200229       -0.064594
# year                 -0.003414  1.000000     -0.119619       -0.110851
# total_births         -0.200229 -0.119619      1.000000        0.630711
# births_by_race       -0.064594 -0.110851      0.630711        1.000000
# total_deaths          0.026575 -0.086712      0.788065        0.516851
# deaths_by_race        0.076853 -0.078901      0.463293        0.526657
# total_mmr             0.002985  0.144595     -0.459144       -0.331363
# mmr_by_race           0.060864  0.051548     -0.223353       -0.562631
# total_population     -0.249864 -0.059042      0.986360        0.612429
# population_by_race    0.030284  0.362474      0.253773        0.431093
#
#                     total_deaths  deaths_by_race  total_mmr  mmr_by_race  \
# state_code              0.026575        0.076853   0.002985     0.060864
# year                   -0.086712       -0.078901   0.144595     0.051548
# total_births            0.788065        0.463293  -0.459144    -0.223353
# births_by_race          0.516851        0.526657  -0.331363    -0.562631
# total_deaths            1.000000        0.794033   0.019396     0.049517
# deaths_by_race          0.794033        1.000000   0.237101     0.175630
# total_mmr               0.019396        0.237101   1.000000     0.538505
# mmr_by_race             0.049517        0.175630   0.538505     1.000000
# total_population        0.733430        0.402399  -0.501266    -0.246148
# population_by_race      0.196693        0.172267  -0.161596    -0.360120
#
#                     total_population  population_by_race
# state_code                 -0.249864            0.030284
# year                       -0.059042            0.362474
# total_births                0.986360            0.253773
# births_by_race              0.612429            0.431093
# total_deaths                0.733430            0.196693
# deaths_by_race              0.402399            0.172267
# total_mmr                  -0.501266           -0.161596
# mmr_by_race                -0.246148           -0.360120
# total_population            1.000000            0.291567
# population_by_race          0.291567            1.000000

# %% [markdown]
# #### Export Final DataFrame to CSV

# %%
# export file as a CSV, without the Pandas Index, but with the header
MMR_race_final_df.to_csv("../../output_file/MMR_by_race_ML.csv", index=False, header=True, float_format='%.2f')
