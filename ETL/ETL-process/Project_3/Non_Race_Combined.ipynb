# %% [markdown]
# # Combined Datasets by State without Race from 2009 to 2019
# ****

# %% [markdown]
# ### Importing Dependencies

# %%
# Importing dependencies:
import numpy as np
import pandas as pd

# %% [markdown]
# ### Store CSV Into DataFrame

# %%
# Reading the csv file into a pandas DataFrame
states_df = pd.read_csv('../../output_file/state_non_race_info.csv')
states_df.head()
# Out:
#    year    state     id state_code   latitude  longitude
# 0  2009  Alabama  US.AL         AL  32.318231 -86.902298
# 1  2010  Alabama  US.AL         AL  32.318231 -86.902298
# 2  2011  Alabama  US.AL         AL  32.318231 -86.902298
# 3  2012  Alabama  US.AL         AL  32.318231 -86.902298
# 4  2013  Alabama  US.AL         AL  32.318231 -86.902298

# %%
# Reading the csv file into a pandas DataFrame
CDC_MMR = pd.read_csv('../../output_file/2009_2019_CDC_MMR.csv')
CDC_MMR.head()
# Out:
#    record_id    state     id  state_code  year  deaths  births  \
# 0          0  Alabama  US.AL           1  2015      12   59657
# 1          1  Alabama  US.AL           1  2016      35   59151
# 2          2  Alabama  US.AL           1  2017      41   58941
# 3          3  Alabama  US.AL           1  2018      31   57761
# 4          4  Alabama  US.AL           1  2019      35   58615
#
#    maternal_mortality_ratio  population
# 0                     20.11     2505795
# 1                     59.17     2507714
# 2                     69.56     2514911
# 3                     53.67     2523756
# 4                     59.71     2533668

# %%
# Reading the csv file into a pandas DataFrame
US_Ins = pd.read_csv('../../output_file/2009_2019_Updated_US_ins_cleaned.csv')
US_Ins.head()
# Out:
#      location  year  employer  non_group  medicaid  medicare  military  \
# 0     Alabama  2009      58.6        6.1      11.4       3.5       2.2
# 1      Alaska  2009      56.7        4.2      10.1       0.0       5.6
# 2     Arizona  2009      53.8        6.9      15.5       2.0       1.7
# 3    Arkansas  2009      54.1        5.8      11.8       3.6       1.5
# 4  California  2009      55.4        8.6      12.2       1.3       0.9
#
#    uninsured  total
# 0       18.2    100
# 1       22.7    100
# 2       20.1    100
# 3       23.1    100
# 4       21.6    100

# %%
# Reading the csv file into a pandas DataFrame
State_Values = pd.read_csv('../../output_file/state_X_values_proj3.csv')
State_Values.head()

# %%
# Checking dataframe rows
states_df.count()
# Out:
# year          550
# state         550
# id            550
# state_code    550
# latitude      550
# longitude     550
# dtype: int64

# %%
# Checking dataframe rows
CDC_MMR.count()
# Out:
# record_id                   308
# state                       308
# id                          308
# state_code                  308
# year                        308
# deaths                      308
# births                      308
# maternal_mortality_ratio    308
# population                  308
# dtype: int64

# %%
# Checking dataframe rows
US_Ins.count()
# Out:
# location     583
# year         583
# employer     583
# non_group    583
# medicaid     583
# medicare     583
# military     583
# uninsured    583
# total        583
# dtype: int64

# %% [markdown]
# ### Create new dataframes with select columns

# %%
# Filtering dataset by selecting columns needed
CDC_MMR_subset = CDC_MMR[["state", "year", "deaths", "births", "maternal_mortality_ratio", "population"]]
CDC_MMR_subset.head()
# Out:
#      state  year  deaths  births  maternal_mortality_ratio  population
# 0  Alabama  2015      12   59657                     20.11     2505795
# 1  Alabama  2016      35   59151                     59.17     2507714
# 2  Alabama  2017      41   58941                     69.56     2514911
# 3  Alabama  2018      31   57761                     53.67     2523756
# 4  Alabama  2019      35   58615                     59.71     2533668

# %%
# Filtering dataset by selecting columns needed
US_Ins_subset = US_Ins[["location", "year", "employer", "non_group", "medicaid", "medicare", "military", "uninsured"]]
US_Ins_subset.head()
# Out:
#      location  year  employer  non_group  medicaid  medicare  military  \
# 0     Alabama  2009      58.6        6.1      11.4       3.5       2.2
# 1      Alaska  2009      56.7        4.2      10.1       0.0       5.6
# 2     Arizona  2009      53.8        6.9      15.5       2.0       1.7
# 3    Arkansas  2009      54.1        5.8      11.8       3.6       1.5
# 4  California  2009      55.4        8.6      12.2       1.3       0.9
#
#    uninsured
# 0       18.2
# 1       22.7
# 2       20.1
# 3       23.1
# 4       21.6

# %%
# Renaming the subset dataframe column from location to state to join on
US_Ins_df = US_Ins_subset.rename(columns={'location': 'state'})
US_Ins_df.head()
# Out:
#         state  year  employer  non_group  medicaid  medicare  military  \
# 0     Alabama  2009      58.6        6.1      11.4       3.5       2.2
# 1      Alaska  2009      56.7        4.2      10.1       0.0       5.6
# 2     Arizona  2009      53.8        6.9      15.5       2.0       1.7
# 3    Arkansas  2009      54.1        5.8      11.8       3.6       1.5
# 4  California  2009      55.4        8.6      12.2       1.3       0.9
#
#    uninsured
# 0       18.2
# 1       22.7
# 2       20.1
# 3       23.1
# 4       21.6

# %% [markdown]
# ### Combine Dataframes on `state` and `year` Columns

# %%
# Combining the dataframes on `state` and `year` columns
combined_df1 = pd.merge(states_df, CDC_MMR_subset, how='left', left_on=['state', 'year'], right_on=['state', 'year']).dropna()
combined_df1
# Out:
#      year      state     id state_code   latitude  longitude  deaths   births  \
# 6    2015    Alabama  US.AL         AL  32.318231 -86.902298    12.0  59657.0
# 7    2016    Alabama  US.AL         AL  32.318231 -86.902298    35.0  59151.0
# 8    2017    Alabama  US.AL         AL  32.318231 -86.902298    41.0  58941.0
# 9    2018    Alabama  US.AL         AL  32.318231 -86.902298    31.0  57761.0
# 10   2019    Alabama  US.AL         AL  32.318231 -86.902298    35.0  58615.0
# ..    ...        ...    ...        ...        ...        ...     ...      ...
# 533  2014  Wisconsin  US.WI         WI  43.784440 -88.787868    16.0  67161.0
# 534  2015  Wisconsin  US.WI         WI  43.784440 -88.787868    11.0  67041.0
# 535  2016  Wisconsin  US.WI         WI  43.784440 -88.787868    15.0  66615.0
# 536  2017  Wisconsin  US.WI         WI  43.784440 -88.787868    12.0  64975.0
# 538  2019  Wisconsin  US.WI         WI  43.784440 -88.787868    13.0  63270.0
#
#      maternal_mortality_ratio  population
# 6                       20.11   2505795.0
# 7                       59.17   2507714.0
# 8                       69.56   2514911.0
# 9                       53.67   2523756.0
# 10                      59.71   2533668.0
# ..                        ...         ...
# 533                     23.82   2898057.0
# 534                     16.41   2903737.0
# 535                     22.52   2905282.0
# 536                     18.47   2912745.0
# 538                     20.55   2925225.0
#
# [308 rows x 10 columns]

# %%
# Combining the `combined_df1` to `US_Ins_df` on state` and `year` columns
combined_df2 = pd.merge(combined_df1, US_Ins_df, how='inner', left_on=['state', 'year'], right_on=['state', 'year']).dropna()
combined_df2
# Out:
#      year      state     id state_code   latitude  longitude  deaths   births  \
# 0    2015    Alabama  US.AL         AL  32.318231 -86.902298    12.0  59657.0
# 1    2016    Alabama  US.AL         AL  32.318231 -86.902298    35.0  59151.0
# 2    2017    Alabama  US.AL         AL  32.318231 -86.902298    41.0  58941.0
# 3    2018    Alabama  US.AL         AL  32.318231 -86.902298    31.0  57761.0
# 4    2019    Alabama  US.AL         AL  32.318231 -86.902298    35.0  58615.0
# ..    ...        ...    ...        ...        ...        ...     ...      ...
# 303  2014  Wisconsin  US.WI         WI  43.784440 -88.787868    16.0  67161.0
# 304  2015  Wisconsin  US.WI         WI  43.784440 -88.787868    11.0  67041.0
# 305  2016  Wisconsin  US.WI         WI  43.784440 -88.787868    15.0  66615.0
# 306  2017  Wisconsin  US.WI         WI  43.784440 -88.787868    12.0  64975.0
# 307  2019  Wisconsin  US.WI         WI  43.784440 -88.787868    13.0  63270.0
#
#      maternal_mortality_ratio  population  employer  non_group  medicaid  \
# 0                       20.11   2505795.0      57.4        8.9      13.6
# 1                       59.17   2507714.0      58.7        9.1      13.8
# 2                       69.56   2514911.0      58.0        8.6      13.6
# 3                       53.67   2523756.0      58.8        7.5      13.7
# 4                       59.71   2533668.0      58.8        7.8      13.9
# ..                        ...         ...       ...        ...       ...
# 303                     23.82   2898057.0      65.8        8.2      15.0
# 304                     16.41   2903737.0      67.5        8.9      15.0
# 305                     22.52   2905282.0      66.9        9.1      15.2
# 306                     18.47   2912745.0      67.8        8.9      15.1
# 307                     20.55   2925225.0      69.1        7.6      14.5
#
#      medicare  military  uninsured
# 0         4.0       2.2       13.9
# 1         3.8       1.9       12.7
# 2         4.2       2.3       13.3
# 3         3.6       2.5       13.9
# 4         3.8       2.4       13.3
# ..        ...       ...        ...
# 303       1.7       0.8        8.6
# 304       1.6       0.7        6.4
# 305       1.7       0.9        6.2
# 306       1.5       0.7        6.0
# 307       1.3       0.8        6.7
#
# [308 rows x 16 columns]
