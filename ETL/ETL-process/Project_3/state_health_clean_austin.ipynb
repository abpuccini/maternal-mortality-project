# %%
import pandas as pd
from functools import reduce

path2009 = "../../Resources/2009-Annual.csv"
path2010 = "../../Resources/2010-Annual.csv"
path2011 = "../../Resources/2011-Annual.csv"
path2012 = "../../Resources/2012-Annual.csv"
path2013 = "../../Resources/2013-Annual.csv"
path2014 = "../../Resources/2014-Annual.csv"
path2015 = "../../Resources/2015-Annual.csv"
path2016 = "../../Resources/2016-Annual.csv"
path2017 = "../../Resources/2017-Annual.csv"
path2018 = "../../Resources/2018-Annual.csv"
path2019 = "../../Resources/2019-Annual.csv"

data2009 = pd.read_csv(path2009)
data2010 = pd.read_csv(path2010)
data2011 = pd.read_csv(path2011)
data2012 = pd.read_csv(path2012)
data2013 = pd.read_csv(path2013)
data2014 = pd.read_csv(path2014)
data2015 = pd.read_csv(path2015)
data2016 = pd.read_csv(path2016)
data2017 = pd.read_csv(path2017)
data2018 = pd.read_csv(path2018)
data2019 = pd.read_csv(path2019)

data2009.head()
# Out:
#    Edition  Report Type   Measure Name  State Name  Rank  Value  Score  \
# 0     2009  2009 Annual  Air Pollution     Alabama  45.0   13.5   0.72
# 1     2009  2009 Annual  Air Pollution      Alaska   5.0    6.9  -1.92
# 2     2009  2009 Annual  Air Pollution     Arizona  22.0   10.5  -0.48
# 3     2009  2009 Annual  Air Pollution    Arkansas  32.0   11.8   0.04
# 4     2009  2009 Annual  Air Pollution  California  47.0   13.9   0.88
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 2       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 3       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 4       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
#
#   Source Year
# 0   2006-2008
# 1   2006-2008
# 2   2006-2008
# 3   2006-2008
# 4   2006-2008

# %%
data2009['Measure Name'].unique()
# Out:
# array(['Air Pollution', 'All Determinants', 'All Outcomes',
#        'Binge Drinking', 'Cancer Deaths',
#        'Cancer Deaths - American Indian/Alaska Native',
#        'Cancer Deaths - Asian/Pacific Islander',
#        'Cancer Deaths - Black/African American',
#        'Cancer Deaths - Crude Rate', 'Cancer Deaths - Female',
#        'Cancer Deaths - Hispanic/Latino', 'Cancer Deaths - Male',
#        'Cancer Deaths - Standard Age Adjustment', 'Cancer Deaths - White',
#        'Cardiovascular Deaths',
#        'Cardiovascular Deaths - American Indian/Alaska Native',
#        'Cardiovascular Deaths - Asian/Pacific Islander',
#        'Cardiovascular Deaths - Black/African American',
#        'Cardiovascular Deaths - Crude Rate',
#        'Cardiovascular Deaths - Female',
#        'Cardiovascular Deaths - Hispanic/Latino',
#        'Cardiovascular Deaths - Male',
#        'Cardiovascular Deaths - Standard Age Adjustment',
# ...

# %%
alldet2009 = data2009.loc[(data2009['Measure Name'] == 'All Determinants')]
alldet2009 = alldet2009[['Edition','State Name','Value']]
alldet2009 = alldet2009.rename(columns={'Value':'all_determs_val'})
alloutcomes2009 = data2009.loc[(data2009['Measure Name'] == 'All Outcomes')]
alloutcomes2009 = alloutcomes2009[['Edition','State Name','Value']]
alloutcomes2009 = alloutcomes2009.rename(columns={'Value':'all_outcomes_val'})
chlamydia2009 = data2009.loc[(data2009['Measure Name'] == 'Chlamydia')]
chlamydia2009 = chlamydia2009[['Edition','State Name','Value']]
chlamydia2009 = chlamydia2009.rename(columns={'Value':'chlamydia_val'})
premdeathri2009 = data2009.loc[(data2009['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2009 = premdeathri2009[['Edition','State Name','Value']]
premdeathri2009 = premdeathri2009.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2009 = data2009.loc[(data2009['Measure Name'] == 'Teen Births')]
teenbirth2009 = teenbirth2009[['Edition','State Name','Value']]
teenbirth2009 = teenbirth2009.rename(columns={'Value':'teen_birth_val'})
primcarephys2009 = data2009.loc[(data2009['Measure Name'] == 'Primary Care Physicians')]
primcarephys2009 = primcarephys2009[['Edition','State Name','Value']]
primcarephys2009 = primcarephys2009.rename(columns={'Value':'primary_care_val'})
ap2009 = data2009.loc[(data2009['Measure Name'] == 'Air Pollution')]
ap2009 = ap2009[['Edition','State Name','Value']]
ap2009 = ap2009.rename(columns={'Value':'air_pollution_val'})
cancer2009 = data2009.loc[(data2009['Measure Name'] == 'Cancer Deaths')]
cancer2009 = cancer2009[['Edition','State Name','Value']]
cancer2009 = cancer2009.rename(columns={'Value':'cancer_death_val'})
cardio2009 = data2009.loc[(data2009['Measure Name'] == 'Cardiovascular Deaths')]
cardio2009 = cardio2009[['Edition','State Name','Value']]
cardio2009 = cardio2009.rename(columns={'Value':'cardio_death_val'})
childpov2009 = data2009.loc[(data2009['Measure Name'] == 'Children in Poverty')]
childpov2009 = childpov2009[['Edition','State Name','Value']]
childpov2009 = childpov2009.rename(columns={'Value':'child_pov_val'})
choles2009 = data2009.loc[(data2009['Measure Name'] == 'Cholesterol Check')]
choles2009 = choles2009[['Edition','State Name','Value']]
choles2009 = choles2009.rename(columns={'Value':'choles_check_val'})
dentvis2009 = data2009.loc[(data2009['Measure Name'] == 'Dental Visit, Annual')]
dentvis2009 = dentvis2009[['Edition','State Name','Value']]
dentvis2009 = dentvis2009.rename(columns={'Value':'dent_vis_val'})
dentnum2009 = data2009.loc[(data2009['Measure Name'] == 'Dentists')]
dentnum2009 = dentnum2009[['Edition','State Name','Value']]
dentnum2009 = dentnum2009.rename(columns={'Value':'dentists_val'})
diabetes2009 = data2009.loc[(data2009['Measure Name'] == 'Diabetes')]
diabetes2009 = diabetes2009[['Edition','State Name','Value']]
diabetes2009 = diabetes2009.rename(columns={'Value':'diabetes_val'})
drug2009 = data2009.loc[(data2009['Measure Name'] == 'Drug Deaths')]
drug2009 = drug2009[['Edition','State Name','Value']]
drug2009 = drug2009.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2009 = data2009.loc[(data2009['Measure Name'] == 'Health Status - Female')]
healthstatfem2009 = healthstatfem2009[['Edition','State Name','Value']]
healthstatfem2009 = healthstatfem2009.rename(columns={'Value':'health_stat_fem_val'})
immunchild2009 = data2009.loc[(data2009['Measure Name'] == 'Immunizations - Children')]
immunchild2009 = immunchild2009[['Edition','State Name','Value']]
immunchild2009 = immunchild2009.rename(columns={'Value':'immun_child_val'})
incomeineq2009 = data2009.loc[(data2009['Measure Name'] == 'Income Inequality')]
incomeineq2009 = incomeineq2009[['Edition','State Name','Value']]
incomeineq2009 = incomeineq2009.rename(columns={'Value':'income_ineq_val'})
infantmort2009 = data2009.loc[(data2009['Measure Name'] == 'Infant Mortality')]
infantmort2009 = infantmort2009[['Edition','State Name','Value']]
infantmort2009 = infantmort2009.rename(columns={'Value':'infant_mort_val'})
infectdis2009 = data2009.loc[(data2009['Measure Name'] == 'Infectious Disease')]
infectdis2009 = infectdis2009[['Edition','State Name','Value']]
infectdis2009 = infectdis2009.rename(columns={'Value':'infect_dis_val'})
obesity2009 = data2009.loc[(data2009['Measure Name'] == 'Obesity')]
obesity2009 = obesity2009[['Edition','State Name','Value']]
obesity2009 = obesity2009.rename(columns={'Value':'obesity_val'})
physicalinac2009 = data2009.loc[(data2009['Measure Name'] == 'Physical Inactivity')]
physicalinac2009 = physicalinac2009[['Edition','State Name','Value']]
physicalinac2009 = physicalinac2009.rename(columns={'Value':'phys_inac_val'})
premdeath2009 = data2009.loc[(data2009['Measure Name'] == 'Premature Death')]
premdeath2009 = premdeath2009[['Edition','State Name','Value']]
premdeath2009 = premdeath2009.rename(columns={'Value':'prem_death_val'})
smoking2009 = data2009.loc[(data2009['Measure Name'] == 'Smoking')]
smoking2009 = smoking2009[['Edition','State Name','Value']]
smoking2009 = smoking2009.rename(columns={'Value':'smoking_val'})
uninsured2009 = data2009.loc[(data2009['Measure Name'] == 'Uninsured')]
uninsured2009 = uninsured2009[['Edition','State Name','Value']]
uninsured2009 = uninsured2009.rename(columns={'Value':'uninsured_val'})
uninsured2009.head()
# Out:
#        Edition  State Name  uninsured_val
# 12219     2009     Alabama           11.9
# 12220     2009      Alaska           19.0
# 12221     2009     Arizona           18.9
# 12222     2009    Arkansas           17.0
# 12223     2009  California           18.4

# %%
dfs_2009 = [ap2009, cancer2009, cardio2009, childpov2009, choles2009, dentvis2009, dentnum2009, diabetes2009, drug2009, healthstatfem2009, immunchild2009, incomeineq2009, infantmort2009, infectdis2009, obesity2009, physicalinac2009, premdeath2009, smoking2009, uninsured2009, alldet2009, alloutcomes2009, chlamydia2009, premdeathri2009, teenbirth2009, primcarephys2009]
nan_value = 0
clean2009 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2009)

clean2009 = clean2009.drop_duplicates(subset=['State Name'])

clean2009
# Out:
#      Edition            State Name  air_pollution_val  cancer_death_val  \
# 0       2009               Alabama               13.5             211.3
# 16      2009                Alaska                6.9             186.2
# 32      2009               Arizona               10.5             168.4
# 48      2009              Arkansas               11.8             213.1
# 64      2009            California               13.9             173.9
# 80      2009              Colorado                7.7             166.8
# 96      2009           Connecticut               11.5             187.7
# 112     2009              Delaware               13.9             206.7
# 128     2009               Florida                9.0             182.7
# 144     2009               Georgia               13.9             193.9
# 160     2009                Hawaii                4.8             159.0
# 176     2009                 Idaho                7.5             176.9
# ...

# %%
alldet2010 = data2010.loc[(data2010['Measure Name'] == 'All Determinants')]
alldet2010 = alldet2010[['Edition','State Name','Value']]
alldet2010 = alldet2010.rename(columns={'Value':'all_determs_val'})
alloutcomes2010 = data2010.loc[(data2010['Measure Name'] == 'All Outcomes')]
alloutcomes2010 = alloutcomes2010[['Edition','State Name','Value']]
alloutcomes2010 = alloutcomes2010.rename(columns={'Value':'all_outcomes_val'})
chlamydia2010 = data2010.loc[(data2010['Measure Name'] == 'Chlamydia')]
chlamydia2010 = chlamydia2010[['Edition','State Name','Value']]
chlamydia2010 = chlamydia2010.rename(columns={'Value':'chlamydia_val'})
premdeathri2010 = data2010.loc[(data2010['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2010 = premdeathri2010[['Edition','State Name','Value']]
premdeathri2010 = premdeathri2010.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2010 = data2010.loc[(data2010['Measure Name'] == 'Teen Births')]
teenbirth2010 = teenbirth2010[['Edition','State Name','Value']]
teenbirth2010 = teenbirth2010.rename(columns={'Value':'teen_birth_val'})
primcarephys2010 = data2010.loc[(data2010['Measure Name'] == 'Primary Care Physicians')]
primcarephys2010 = primcarephys2010[['Edition','State Name','Value']]
primcarephys2010 = primcarephys2010.rename(columns={'Value':'primary_care_val'})
ap2010 = data2010.loc[(data2010['Measure Name'] == 'Air Pollution')]
ap2010 = ap2010[['Edition','State Name','Value']]
ap2010 = ap2010.rename(columns={'Value':'air_pollution_val'})
cancer2010 = data2010.loc[(data2010['Measure Name'] == 'Cancer Deaths')]
cancer2010 = cancer2010[['Edition','State Name','Value']]
cancer2010 = cancer2010.rename(columns={'Value':'cancer_death_val'})
cardio2010 = data2010.loc[(data2010['Measure Name'] == 'Cardiovascular Deaths')]
cardio2010 = cardio2010[['Edition','State Name','Value']]
cardio2010 = cardio2010.rename(columns={'Value':'cardio_death_val'})
childpov2010 = data2010.loc[(data2010['Measure Name'] == 'Children in Poverty')]
childpov2010 = childpov2010[['Edition','State Name','Value']]
childpov2010 = childpov2010.rename(columns={'Value':'child_pov_val'})
choles2010 = data2010.loc[(data2010['Measure Name'] == 'Cholesterol Check')]
choles2010 = choles2010[['Edition','State Name','Value']]
choles2010 = choles2010.rename(columns={'Value':'choles_check_val'})
dentvis2010 = data2010.loc[(data2010['Measure Name'] == 'Dental Visit, Annual')]
dentvis2010 = dentvis2010[['Edition','State Name','Value']]
dentvis2010 = dentvis2010.rename(columns={'Value':'dent_vis_val'})
dentnum2010 = data2010.loc[(data2010['Measure Name'] == 'Dentists')]
dentnum2010 = dentnum2010[['Edition','State Name','Value']]
dentnum2010 = dentnum2010.rename(columns={'Value':'dentists_val'})
diabetes2010 = data2010.loc[(data2010['Measure Name'] == 'Diabetes')]
diabetes2010 = diabetes2010[['Edition','State Name','Value']]
diabetes2010 = diabetes2010.rename(columns={'Value':'diabetes_val'})
drug2010 = data2010.loc[(data2010['Measure Name'] == 'Drug Deaths')]
drug2010 = drug2010[['Edition','State Name','Value']]
drug2010 = drug2010.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2010 = data2010.loc[(data2010['Measure Name'] == 'Health Status - Female')]
healthstatfem2010 = healthstatfem2010[['Edition','State Name','Value']]
healthstatfem2010 = healthstatfem2010.rename(columns={'Value':'health_stat_fem_val'})
immunchild2010 = data2010.loc[(data2010['Measure Name'] == 'Immunizations - Children')]
immunchild2010 = immunchild2010[['Edition','State Name','Value']]
immunchild2010 = immunchild2010.rename(columns={'Value':'immun_child_val'})
incomeineq2010 = data2010.loc[(data2010['Measure Name'] == 'Income Inequality')]
incomeineq2010 = incomeineq2010[['Edition','State Name','Value']]
incomeineq2010 = incomeineq2010.rename(columns={'Value':'income_ineq_val'})
infantmort2010 = data2010.loc[(data2010['Measure Name'] == 'Infant Mortality')]
infantmort2010 = infantmort2010[['Edition','State Name','Value']]
infantmort2010 = infantmort2010.rename(columns={'Value':'infant_mort_val'})
infectdis2010 = data2010.loc[(data2010['Measure Name'] == 'Infectious Disease')]
infectdis2010 = infectdis2010[['Edition','State Name','Value']]
infectdis2010 = infectdis2010.rename(columns={'Value':'infect_dis_val'})
obesity2010 = data2010.loc[(data2010['Measure Name'] == 'Obesity')]
obesity2010 = obesity2010[['Edition','State Name','Value']]
obesity2010 = obesity2010.rename(columns={'Value':'obesity_val'})
physicalinac2010 = data2010.loc[(data2010['Measure Name'] == 'Physical Inactivity')]
physicalinac2010 = physicalinac2010[['Edition','State Name','Value']]
physicalinac2010 = physicalinac2010.rename(columns={'Value':'phys_inac_val'})
premdeath2010 = data2010.loc[(data2010['Measure Name'] == 'Premature Death')]
premdeath2010 = premdeath2010[['Edition','State Name','Value']]
premdeath2010 = premdeath2010.rename(columns={'Value':'prem_death_val'})
smoking2010 = data2010.loc[(data2010['Measure Name'] == 'Smoking')]
smoking2010 = smoking2010[['Edition','State Name','Value']]
smoking2010 = smoking2010.rename(columns={'Value':'smoking_val'})
uninsured2010 = data2010.loc[(data2010['Measure Name'] == 'Uninsured')]
uninsured2010 = uninsured2010[['Edition','State Name','Value']]
uninsured2010 = uninsured2010.rename(columns={'Value':'uninsured_val'})
uninsured2010.head()
# Out:
#        Edition            State Name  uninsured_val
# 12168     2010               Wyoming           14.7
# 12169     2010         United States           16.0
# 12170     2010  District of Columbia           11.2
# 12171     2010               Alabama           14.4
# 12172     2010                Alaska           18.8

# %%
dfs_2010 = [ap2010, cancer2010, cardio2010, childpov2010, choles2010, dentvis2010, dentnum2010, diabetes2010, drug2010, healthstatfem2010, immunchild2010, incomeineq2010, infantmort2010, infectdis2010, obesity2010, physicalinac2010, premdeath2010, smoking2010, uninsured2010, alldet2010, alloutcomes2010, chlamydia2010, premdeathri2010, teenbirth2010, primcarephys2010]
nan_value = 0
clean2010 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2010)

clean2010 = clean2010.drop_duplicates(subset=['State Name'])

clean2010
# Out:
#      Edition            State Name  air_pollution_val  cancer_death_val  \
# 0       2010               Alabama               12.5             211.7
# 16      2010                Alaska                7.3             192.0
# 32      2010               Arizona               10.0             166.7
# 48      2010              Arkansas               11.4             212.4
# 64      2010            California               15.2             173.3
# 80      2010              Colorado                7.4             163.9
# 96      2010           Connecticut               10.6             185.7
# 112     2010              Delaware               12.6             205.0
# 128     2010               Florida                8.3             182.3
# 144     2010               Georgia               12.9             190.5
# 160     2010                Hawaii                6.7             158.9
# 176     2010                 Idaho                8.2             175.8
# ...

# %%
alldet2011 = data2011.loc[(data2011['Measure Name'] == 'All Determinants')]
alldet2011 = alldet2011[['Edition','State Name','Value']]
alldet2011 = alldet2011.rename(columns={'Value':'all_determs_val'})
alloutcomes2011 = data2011.loc[(data2011['Measure Name'] == 'All Outcomes')]
alloutcomes2011 = alloutcomes2011[['Edition','State Name','Value']]
alloutcomes2011 = alloutcomes2011.rename(columns={'Value':'all_outcomes_val'})
chlamydia2011 = data2011.loc[(data2011['Measure Name'] == 'Chlamydia')]
chlamydia2011 = chlamydia2011[['Edition','State Name','Value']]
chlamydia2011 = chlamydia2011.rename(columns={'Value':'chlamydia_val'})
premdeathri2011 = data2011.loc[(data2011['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2011 = premdeathri2011[['Edition','State Name','Value']]
premdeathri2011 = premdeathri2011.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2011 = data2011.loc[(data2011['Measure Name'] == 'Teen Births')]
teenbirth2011 = teenbirth2011[['Edition','State Name','Value']]
teenbirth2011 = teenbirth2011.rename(columns={'Value':'teen_birth_val'})
primcarephys2011 = data2011.loc[(data2011['Measure Name'] == 'Primary Care Physicians')]
primcarephys2011 = primcarephys2011[['Edition','State Name','Value']]
primcarephys2011 = primcarephys2011.rename(columns={'Value':'primary_care_val'})
ap2011 = data2011.loc[(data2011['Measure Name'] == 'Air Pollution')]
ap2011 = ap2011[['Edition','State Name','Value']]
ap2011 = ap2011.rename(columns={'Value':'air_pollution_val'})
cancer2011 = data2011.loc[(data2011['Measure Name'] == 'Cancer Deaths')]
cancer2011 = cancer2011[['Edition','State Name','Value']]
cancer2011 = cancer2011.rename(columns={'Value':'cancer_death_val'})
cardio2011 = data2011.loc[(data2011['Measure Name'] == 'Cardiovascular Deaths')]
cardio2011 = cardio2011[['Edition','State Name','Value']]
cardio2011 = cardio2011.rename(columns={'Value':'cardio_death_val'})
childpov2011 = data2011.loc[(data2011['Measure Name'] == 'Children in Poverty')]
childpov2011 = childpov2011[['Edition','State Name','Value']]
childpov2011 = childpov2011.rename(columns={'Value':'child_pov_val'})
choles2011 = data2011.loc[(data2011['Measure Name'] == 'Cholesterol Check')]
choles2011 = choles2011[['Edition','State Name','Value']]
choles2011 = choles2011.rename(columns={'Value':'choles_check_val'})
dentvis2011 = data2011.loc[(data2011['Measure Name'] == 'Dental Visit, Annual')]
dentvis2011 = dentvis2011[['Edition','State Name','Value']]
dentvis2011 = dentvis2011.rename(columns={'Value':'dent_vis_val'})
dentnum2011 = data2011.loc[(data2011['Measure Name'] == 'Dentists')]
dentnum2011 = dentnum2011[['Edition','State Name','Value']]
dentnum2011 = dentnum2011.rename(columns={'Value':'dentists_val'})
diabetes2011 = data2011.loc[(data2011['Measure Name'] == 'Diabetes')]
diabetes2011 = diabetes2011[['Edition','State Name','Value']]
diabetes2011 = diabetes2011.rename(columns={'Value':'diabetes_val'})
drug2011 = data2011.loc[(data2011['Measure Name'] == 'Drug Deaths')]
drug2011 = drug2011[['Edition','State Name','Value']]
drug2011 = drug2011.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2011 = data2011.loc[(data2011['Measure Name'] == 'Health Status - Female')]
healthstatfem2011 = healthstatfem2011[['Edition','State Name','Value']]
healthstatfem2011 = healthstatfem2011.rename(columns={'Value':'health_stat_fem_val'})
immunchild2011 = data2011.loc[(data2011['Measure Name'] == 'Immunizations - Children')]
immunchild2011 = immunchild2011[['Edition','State Name','Value']]
immunchild2011 = immunchild2011.rename(columns={'Value':'immun_child_val'})
incomeineq2011 = data2011.loc[(data2011['Measure Name'] == 'Income Inequality')]
incomeineq2011 = incomeineq2011[['Edition','State Name','Value']]
incomeineq2011 = incomeineq2011.rename(columns={'Value':'income_ineq_val'})
infantmort2011 = data2011.loc[(data2011['Measure Name'] == 'Infant Mortality')]
infantmort2011 = infantmort2011[['Edition','State Name','Value']]
infantmort2011 = infantmort2011.rename(columns={'Value':'infant_mort_val'})
infectdis2011 = data2011.loc[(data2011['Measure Name'] == 'Infectious Disease')]
infectdis2011 = infectdis2011[['Edition','State Name','Value']]
infectdis2011 = infectdis2011.rename(columns={'Value':'infect_dis_val'})
obesity2011 = data2011.loc[(data2011['Measure Name'] == 'Obesity')]
obesity2011 = obesity2011[['Edition','State Name','Value']]
obesity2011 = obesity2011.rename(columns={'Value':'obesity_val'})
physicalinac2011 = data2011.loc[(data2011['Measure Name'] == 'Physical Inactivity')]
physicalinac2011 = physicalinac2011[['Edition','State Name','Value']]
physicalinac2011 = physicalinac2011.rename(columns={'Value':'phys_inac_val'})
premdeath2011 = data2011.loc[(data2011['Measure Name'] == 'Premature Death')]
premdeath2011 = premdeath2011[['Edition','State Name','Value']]
premdeath2011 = premdeath2011.rename(columns={'Value':'prem_death_val'})
smoking2011 = data2011.loc[(data2011['Measure Name'] == 'Smoking')]
smoking2011 = smoking2011[['Edition','State Name','Value']]
smoking2011 = smoking2011.rename(columns={'Value':'smoking_val'})
uninsured2011 = data2011.loc[(data2011['Measure Name'] == 'Uninsured')]
uninsured2011 = uninsured2011[['Edition','State Name','Value']]
uninsured2011 = uninsured2011.rename(columns={'Value':'uninsured_val'})
uninsured2011.head()
# Out:
#        Edition    State Name  uninsured_val
# 13156     2011    New Jersey           15.0
# 13157     2011  South Dakota           13.1
# 13158     2011        Nevada           21.0
# 13159     2011      Arkansas           18.9
# 13160     2011     Tennessee           14.9

# %%
dfs_2011 = [ap2011, cancer2011, cardio2011, childpov2011, choles2011, dentvis2011, dentnum2011, diabetes2011, drug2011, healthstatfem2011, immunchild2011, incomeineq2011, infantmort2011, infectdis2011, obesity2011, physicalinac2011, premdeath2011, smoking2011, uninsured2011, alldet2011, alloutcomes2011, chlamydia2011, premdeathri2011, teenbirth2011, primcarephys2011]
nan_value = 0
clean2011 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2011)

clean2011 = clean2011.drop_duplicates(subset=['State Name'])

clean2011
# Out:
#      Edition            State Name  air_pollution_val  cancer_death_val  \
# 0       2011              Nebraska                8.2             184.2
# 16      2011         United States               10.8             190.7
# 32      2011            Washington                9.6             189.5
# 48      2011                 Maine                8.2             201.7
# 64      2011                Alaska                6.3             194.3
# 80      2011            California               15.1             172.9
# 96      2011               Georgia               12.0             193.4
# 112     2011           Connecticut                9.9             178.3
# 128     2011              Illinois               11.8             199.8
# 144     2011         Massachusetts                8.9             191.2
# 160     2011         West Virginia               11.9             219.7
# 176     2011            New Jersey                9.8             188.8
# ...

# %%
alldet2012 = data2012.loc[(data2012['Measure Name'] == 'All Determinants')]
alldet2012 = alldet2012[['Edition','State Name','Value']]
alldet2012 = alldet2012.rename(columns={'Value':'all_determs_val'})
alloutcomes2012 = data2012.loc[(data2012['Measure Name'] == 'All Outcomes')]
alloutcomes2012 = alloutcomes2012[['Edition','State Name','Value']]
alloutcomes2012 = alloutcomes2012.rename(columns={'Value':'all_outcomes_val'})
chlamydia2012 = data2012.loc[(data2012['Measure Name'] == 'Chlamydia')]
chlamydia2012 = chlamydia2012[['Edition','State Name','Value']]
chlamydia2012 = chlamydia2012.rename(columns={'Value':'chlamydia_val'})
premdeathri2012 = data2012.loc[(data2012['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2012 = premdeathri2012[['Edition','State Name','Value']]
premdeathri2012 = premdeathri2012.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2012 = data2012.loc[(data2012['Measure Name'] == 'Teen Births')]
teenbirth2012 = teenbirth2012[['Edition','State Name','Value']]
teenbirth2012 = teenbirth2012.rename(columns={'Value':'teen_birth_val'})
primcarephys2012 = data2012.loc[(data2012['Measure Name'] == 'Primary Care Physicians')]
primcarephys2012 = primcarephys2012[['Edition','State Name','Value']]
primcarephys2012 = primcarephys2012.rename(columns={'Value':'primary_care_val'})
ap2012 = data2012.loc[(data2012['Measure Name'] == 'Air Pollution')]
ap2012 = ap2012[['Edition','State Name','Value']]
ap2012 = ap2012.rename(columns={'Value':'air_pollution_val'})
cancer2012 = data2012.loc[(data2012['Measure Name'] == 'Cancer Deaths')]
cancer2012 = cancer2012[['Edition','State Name','Value']]
cancer2012 = cancer2012.rename(columns={'Value':'cancer_death_val'})
cardio2012 = data2012.loc[(data2012['Measure Name'] == 'Cardiovascular Deaths')]
cardio2012 = cardio2012[['Edition','State Name','Value']]
cardio2012 = cardio2012.rename(columns={'Value':'cardio_death_val'})
childpov2012 = data2012.loc[(data2012['Measure Name'] == 'Children in Poverty')]
childpov2012 = childpov2012[['Edition','State Name','Value']]
childpov2012 = childpov2012.rename(columns={'Value':'child_pov_val'})
choles2012 = data2012.loc[(data2012['Measure Name'] == 'Cholesterol Check')]
choles2012 = choles2012[['Edition','State Name','Value']]
choles2012 = choles2012.rename(columns={'Value':'choles_check_val'})
dentvis2012 = data2012.loc[(data2012['Measure Name'] == 'Dental Visit, Annual')]
dentvis2012 = dentvis2012[['Edition','State Name','Value']]
dentvis2012 = dentvis2012.rename(columns={'Value':'dent_vis_val'})
dentnum2012 = data2012.loc[(data2012['Measure Name'] == 'Dentists')]
dentnum2012 = dentnum2012[['Edition','State Name','Value']]
dentnum2012 = dentnum2012.rename(columns={'Value':'dentists_val'})
diabetes2012 = data2012.loc[(data2012['Measure Name'] == 'Diabetes')]
diabetes2012 = diabetes2012[['Edition','State Name','Value']]
diabetes2012 = diabetes2012.rename(columns={'Value':'diabetes_val'})
drug2012 = data2012.loc[(data2012['Measure Name'] == 'Drug Deaths')]
drug2012 = drug2012[['Edition','State Name','Value']]
drug2012 = drug2012.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2012 = data2012.loc[(data2012['Measure Name'] == 'High Health Status - Female')]
healthstatfem2012 = healthstatfem2012[['Edition','State Name','Value']]
healthstatfem2012 = healthstatfem2012.rename(columns={'Value':'health_stat_fem_val'})
immunchild2012 = data2012.loc[(data2012['Measure Name'] == 'Immunizations - Children')]
immunchild2012 = immunchild2012[['Edition','State Name','Value']]
immunchild2012 = immunchild2012.rename(columns={'Value':'immun_child_val'})
incomeineq2012 = data2012.loc[(data2012['Measure Name'] == 'Income Inequality')]
incomeineq2012 = incomeineq2012[['Edition','State Name','Value']]
incomeineq2012 = incomeineq2012.rename(columns={'Value':'income_ineq_val'})
infantmort2012 = data2012.loc[(data2012['Measure Name'] == 'Infant Mortality')]
infantmort2012 = infantmort2012[['Edition','State Name','Value']]
infantmort2012 = infantmort2012.rename(columns={'Value':'infant_mort_val'})
infectdis2012 = data2012.loc[(data2012['Measure Name'] == 'Infectious Disease')]
infectdis2012 = infectdis2012[['Edition','State Name','Value']]
infectdis2012 = infectdis2012.rename(columns={'Value':'infect_dis_val'})
obesity2012 = data2012.loc[(data2012['Measure Name'] == 'Obesity')]
obesity2012 = obesity2012[['Edition','State Name','Value']]
obesity2012 = obesity2012.rename(columns={'Value':'obesity_val'})
physicalinac2012 = data2012.loc[(data2012['Measure Name'] == 'Physical Inactivity')]
physicalinac2012 = physicalinac2012[['Edition','State Name','Value']]
physicalinac2012 = physicalinac2012.rename(columns={'Value':'phys_inac_val'})
premdeath2012 = data2012.loc[(data2012['Measure Name'] == 'Premature Death')]
premdeath2012 = premdeath2012[['Edition','State Name','Value']]
premdeath2012 = premdeath2012.rename(columns={'Value':'prem_death_val'})
smoking2012 = data2012.loc[(data2012['Measure Name'] == 'Smoking')]
smoking2012 = smoking2012[['Edition','State Name','Value']]
smoking2012 = smoking2012.rename(columns={'Value':'smoking_val'})
uninsured2012 = data2012.loc[(data2012['Measure Name'] == 'Uninsured')]
uninsured2012 = uninsured2012[['Edition','State Name','Value']]
uninsured2012 = uninsured2012.rename(columns={'Value':'uninsured_val'})
premdeath2012.head()
# Out:
#        Edition  State Name  prem_death_val
# 17108     2012     Alabama         10496.0
# 17109     2012      Alaska          7761.0
# 17110     2012     Arizona          7107.0
# 17111     2012    Arkansas         10098.0
# 17112     2012  California          6190.0

# %%
dfs_2012 = [ap2012, cancer2012, cardio2012, childpov2012, choles2012, dentvis2012, dentnum2012, diabetes2012, drug2012, healthstatfem2012, immunchild2012, incomeineq2012, infantmort2012, infectdis2012, obesity2012, physicalinac2012, premdeath2012, smoking2012, uninsured2012, alldet2012, alloutcomes2012, chlamydia2012, premdeathri2012, teenbirth2012, primcarephys2012]
nan_value = 0
clean2012 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2012)

clean2012 = clean2012.drop_duplicates(subset=['State Name'])

clean2012
# Out:
#       Edition            State Name  air_pollution_val  cancer_death_val  \
# 0        2012               Alabama               11.0             214.1
# 64       2012                Alaska                6.0             195.0
# 128      2012               Arizona                9.4             171.1
# 192      2012              Arkansas               10.8             216.4
# 256      2012            California               15.3             172.3
# 320      2012              Colorado                6.7             164.3
# 384      2012           Connecticut                9.3             179.0
# 448      2012              Delaware               11.0             202.8
# 512      2012               Florida                7.6             184.0
# 576      2012               Georgia               11.5             191.9
# 640      2012                Hawaii                8.9             156.2
# 704      2012                 Idaho                8.7             176.7
# ...

# %%
alldet2013 = data2013.loc[(data2013['Measure Name'] == 'All Determinants')]
alldet2013 = alldet2013[['Edition','State Name','Value']]
alldet2013 = alldet2013.rename(columns={'Value':'all_determs_val'})
alloutcomes2013 = data2013.loc[(data2013['Measure Name'] == 'All Outcomes')]
alloutcomes2013 = alloutcomes2013[['Edition','State Name','Value']]
alloutcomes2013 = alloutcomes2013.rename(columns={'Value':'all_outcomes_val'})
chlamydia2013 = data2013.loc[(data2013['Measure Name'] == 'Chlamydia')]
chlamydia2013 = chlamydia2013[['Edition','State Name','Value']]
chlamydia2013 = chlamydia2013.rename(columns={'Value':'chlamydia_val'})
premdeathri2013 = data2013.loc[(data2013['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2013 = premdeathri2013[['Edition','State Name','Value']]
premdeathri2013 = premdeathri2013.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2013 = data2013.loc[(data2013['Measure Name'] == 'Teen Births')]
teenbirth2013 = teenbirth2013[['Edition','State Name','Value']]
teenbirth2013 = teenbirth2013.rename(columns={'Value':'teen_birth_val'})
primcarephys2013 = data2013.loc[(data2013['Measure Name'] == 'Primary Care Physicians')]
primcarephys2013 = primcarephys2013[['Edition','State Name','Value']]
primcarephys2013 = primcarephys2013.rename(columns={'Value':'primary_care_val'})
ap2013 = data2013.loc[(data2013['Measure Name'] == 'Air Pollution')]
ap2013 = ap2013[['Edition','State Name','Value']]
ap2013 = ap2013.rename(columns={'Value':'air_pollution_val'})
cancer2013 = data2013.loc[(data2013['Measure Name'] == 'Cancer Deaths')]
cancer2013 = cancer2013[['Edition','State Name','Value']]
cancer2013 = cancer2013.rename(columns={'Value':'cancer_death_val'})
cardio2013 = data2013.loc[(data2013['Measure Name'] == 'Cardiovascular Deaths')]
cardio2013 = cardio2013[['Edition','State Name','Value']]
cardio2013 = cardio2013.rename(columns={'Value':'cardio_death_val'})
childpov2013 = data2013.loc[(data2013['Measure Name'] == 'Children in Poverty')]
childpov2013 = childpov2013[['Edition','State Name','Value']]
childpov2013 = childpov2013.rename(columns={'Value':'child_pov_val'})
choles2013 = data2013.loc[(data2013['Measure Name'] == 'Cholesterol Check')]
choles2013 = choles2013[['Edition','State Name','Value']]
choles2013 = choles2013.rename(columns={'Value':'choles_check_val'})
dentvis2013 = data2013.loc[(data2013['Measure Name'] == 'Dental Visit')]
dentvis2013 = dentvis2013[['Edition','State Name','Value']]
dentvis2013 = dentvis2013.rename(columns={'Value':'dent_vis_val'})
dentnum2013 = data2013.loc[(data2013['Measure Name'] == 'Dentists')]
dentnum2013 = dentnum2013[['Edition','State Name','Value']]
dentnum2013 = dentnum2013.rename(columns={'Value':'dentists_val'})
diabetes2013 = data2013.loc[(data2013['Measure Name'] == 'Diabetes')]
diabetes2013 = diabetes2013[['Edition','State Name','Value']]
diabetes2013 = diabetes2013.rename(columns={'Value':'diabetes_val'})
drug2013 = data2013.loc[(data2013['Measure Name'] == 'Drug Deaths')]
drug2013 = drug2013[['Edition','State Name','Value']]
drug2013 = drug2013.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2013 = data2013.loc[(data2013['Measure Name'] == 'High Health Status - Female')]
healthstatfem2013 = healthstatfem2013[['Edition','State Name','Value']]
healthstatfem2013 = healthstatfem2013.rename(columns={'Value':'health_stat_fem_val'})
immunchild2013 = data2013.loc[(data2013['Measure Name'] == 'Immunizations - Children')]
immunchild2013 = immunchild2013[['Edition','State Name','Value']]
immunchild2013 = immunchild2013.rename(columns={'Value':'immun_child_val'})
incomeineq2013 = data2013.loc[(data2013['Measure Name'] == 'Income Inequality')]
incomeineq2013 = incomeineq2013[['Edition','State Name','Value']]
incomeineq2013 = incomeineq2013.rename(columns={'Value':'income_ineq_val'})
infantmort2013 = data2013.loc[(data2013['Measure Name'] == 'Infant Mortality')]
infantmort2013 = infantmort2013[['Edition','State Name','Value']]
infantmort2013 = infantmort2013.rename(columns={'Value':'infant_mort_val'})
infectdis2013 = data2013.loc[(data2013['Measure Name'] == 'Infectious Disease')]
infectdis2013 = infectdis2013[['Edition','State Name','Value']]
infectdis2013 = infectdis2013.rename(columns={'Value':'infect_dis_val'})
obesity2013 = data2013.loc[(data2013['Measure Name'] == 'Obesity')]
obesity2013 = obesity2013[['Edition','State Name','Value']]
obesity2013 = obesity2013.rename(columns={'Value':'obesity_val'})
physicalinac2013 = data2013.loc[(data2013['Measure Name'] == 'Physical Inactivity')]
physicalinac2013 = physicalinac2013[['Edition','State Name','Value']]
physicalinac2013 = physicalinac2013.rename(columns={'Value':'phys_inac_val'})
premdeath2013 = data2013.loc[(data2013['Measure Name'] == 'Premature Death')]
premdeath2013 = premdeath2013[['Edition','State Name','Value']]
premdeath2013 = premdeath2013.rename(columns={'Value':'prem_death_val'})
smoking2013 = data2013.loc[(data2013['Measure Name'] == 'Smoking')]
smoking2013 = smoking2013[['Edition','State Name','Value']]
smoking2013 = smoking2013.rename(columns={'Value':'smoking_val'})
uninsured2013 = data2013.loc[(data2013['Measure Name'] == 'Uninsured')]
uninsured2013 = uninsured2013[['Edition','State Name','Value']]
uninsured2013 = uninsured2013.rename(columns={'Value':'uninsured_val'})
uninsured2013.head()
# Out:
#        Edition  State Name  uninsured_val
# 25947     2013     Alabama           13.9
# 25948     2013      Alaska           18.6
# 25949     2013     Arizona           17.7
# 25950     2013    Arkansas           17.9
# 25951     2013  California           18.8

# %%
dfs_2013 = [ap2013, cancer2013, cardio2013, childpov2013, choles2013, dentvis2013, dentnum2013, diabetes2013, drug2013, healthstatfem2013, immunchild2013, incomeineq2013, infantmort2013, infectdis2013, obesity2013, physicalinac2013, premdeath2013, smoking2013, uninsured2013, alldet2013, alloutcomes2013, chlamydia2013, premdeathri2013, teenbirth2013, primcarephys2013]
nan_value = 0
clean2013 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2013)

clean2013 = clean2013.drop_duplicates(subset=['State Name'])

clean2013
# Out:
#      Edition            State Name  air_pollution_val  cancer_death_val  \
# 0       2013               Alabama               10.7             212.0
# 16      2013                Alaska                5.4             194.4
# 32      2013               Arizona                9.6             169.6
# 48      2013              Arkansas               10.7             214.2
# 64      2013            California               15.1             170.9
# 80      2013              Colorado                6.7             163.0
# 96      2013           Connecticut                9.0             178.0
# 112     2013              Delaware               10.6             199.7
# 128     2013               Florida                7.6             182.6
# 144     2013               Georgia               11.2             191.6
# 160     2013                Hawaii                9.1             155.7
# 176     2013                 Idaho                8.6             174.4
# ...

# %%
alldet2014 = data2014.loc[(data2014['Measure Name'] == 'All Determinants')]
alldet2014 = alldet2014[['Edition','State Name','Value']]
alldet2014 = alldet2014.rename(columns={'Value':'all_determs_val'})
alloutcomes2014 = data2014.loc[(data2014['Measure Name'] == 'All Outcomes')]
alloutcomes2014 = alloutcomes2014[['Edition','State Name','Value']]
alloutcomes2014 = alloutcomes2014.rename(columns={'Value':'all_outcomes_val'})
chlamydia2014 = data2014.loc[(data2014['Measure Name'] == 'Chlamydia')]
chlamydia2014 = chlamydia2014[['Edition','State Name','Value']]
chlamydia2014 = chlamydia2014.rename(columns={'Value':'chlamydia_val'})
premdeathri2014 = data2014.loc[(data2014['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2014 = premdeathri2014[['Edition','State Name','Value']]
premdeathri2014 = premdeathri2014.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2014 = data2014.loc[(data2014['Measure Name'] == 'Teen Births')]
teenbirth2014 = teenbirth2014[['Edition','State Name','Value']]
teenbirth2014 = teenbirth2014.rename(columns={'Value':'teen_birth_val'})
primcarephys2014 = data2014.loc[(data2014['Measure Name'] == 'Primary Care Physicians')]
primcarephys2014 = primcarephys2014[['Edition','State Name','Value']]
primcarephys2014 = primcarephys2014.rename(columns={'Value':'primary_care_val'})
ap2014 = data2014.loc[(data2014['Measure Name'] == 'Air Pollution')]
ap2014 = ap2014[['Edition','State Name','Value']]
ap2014 = ap2014.rename(columns={'Value':'air_pollution_val'})
cancer2014 = data2014.loc[(data2014['Measure Name'] == 'Cancer Deaths')]
cancer2014 = cancer2014[['Edition','State Name','Value']]
cancer2014 = cancer2014.rename(columns={'Value':'cancer_death_val'})
cardio2014 = data2014.loc[(data2014['Measure Name'] == 'Cardiovascular Deaths')]
cardio2014 = cardio2014[['Edition','State Name','Value']]
cardio2014 = cardio2014.rename(columns={'Value':'cardio_death_val'})
childpov2014 = data2014.loc[(data2014['Measure Name'] == 'Children in Poverty')]
childpov2014 = childpov2014[['Edition','State Name','Value']]
childpov2014 = childpov2014.rename(columns={'Value':'child_pov_val'})
choles2014 = data2014.loc[(data2014['Measure Name'] == 'Cholesterol Check')]
choles2014 = choles2014[['Edition','State Name','Value']]
choles2014 = choles2014.rename(columns={'Value':'choles_check_val'})
dentvis2014 = data2014.loc[(data2014['Measure Name'] == 'Dental Visit')]
dentvis2014 = dentvis2014[['Edition','State Name','Value']]
dentvis2014 = dentvis2014.rename(columns={'Value':'dent_vis_val'})
dentnum2014 = data2014.loc[(data2014['Measure Name'] == 'Dentists')]
dentnum2014 = dentnum2014[['Edition','State Name','Value']]
dentnum2014 = dentnum2014.rename(columns={'Value':'dentists_val'})
diabetes2014 = data2014.loc[(data2014['Measure Name'] == 'Diabetes')]
diabetes2014 = diabetes2014[['Edition','State Name','Value']]
diabetes2014 = diabetes2014.rename(columns={'Value':'diabetes_val'})
drug2014 = data2014.loc[(data2014['Measure Name'] == 'Drug Deaths')]
drug2014 = drug2014[['Edition','State Name','Value']]
drug2014 = drug2014.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2014 = data2014.loc[(data2014['Measure Name'] == 'High Health Status - Female')]
healthstatfem2014 = healthstatfem2014[['Edition','State Name','Value']]
healthstatfem2014 = healthstatfem2014.rename(columns={'Value':'health_stat_fem_val'})
immunchild2014 = data2014.loc[(data2014['Measure Name'] == 'Immunizations - Children')]
immunchild2014 = immunchild2014[['Edition','State Name','Value']]
immunchild2014 = immunchild2014.rename(columns={'Value':'immun_child_val'})
incomeineq2014 = data2014.loc[(data2014['Measure Name'] == 'Income Inequality')]
incomeineq2014 = incomeineq2014[['Edition','State Name','Value']]
incomeineq2014 = incomeineq2014.rename(columns={'Value':'income_ineq_val'})
infantmort2014 = data2014.loc[(data2014['Measure Name'] == 'Infant Mortality')]
infantmort2014 = infantmort2014[['Edition','State Name','Value']]
infantmort2014 = infantmort2014.rename(columns={'Value':'infant_mort_val'})
infectdis2014 = data2014.loc[(data2014['Measure Name'] == 'Infectious Disease')]
infectdis2014 = infectdis2014[['Edition','State Name','Score']]
infectdis2014 = infectdis2014.rename(columns={'Value':'infect_dis_val'})
obesity2014 = data2014.loc[(data2014['Measure Name'] == 'Obesity')]
obesity2014 = obesity2014[['Edition','State Name','Value']]
obesity2014 = obesity2014.rename(columns={'Value':'obesity_val'})
physicalinac2014 = data2014.loc[(data2014['Measure Name'] == 'Physical Inactivity')]
physicalinac2014 = physicalinac2014[['Edition','State Name','Value']]
physicalinac2014 = physicalinac2014.rename(columns={'Value':'phys_inac_val'})
premdeath2014 = data2014.loc[(data2014['Measure Name'] == 'Premature Death')]
premdeath2014 = premdeath2014[['Edition','State Name','Value']]
premdeath2014 = premdeath2014.rename(columns={'Value':'prem_death_val'})
smoking2014 = data2014.loc[(data2014['Measure Name'] == 'Smoking')]
smoking2014 = smoking2014[['Edition','State Name','Value']]
smoking2014 = smoking2014.rename(columns={'Value':'smoking_val'})
uninsured2014 = data2014.loc[(data2014['Measure Name'] == 'Uninsured')]
uninsured2014 = uninsured2014[['Edition','State Name','Value']]
uninsured2014 = uninsured2014.rename(columns={'Value':'uninsured_val'})
uninsured2014.head()
# Out:
#        Edition  State Name  uninsured_val
# 32770     2014     Alabama           13.4
# 32771     2014      Alaska           19.5
# 32772     2014     Arizona           17.3
# 32773     2014    Arkansas           16.2
# 32774     2014  California           17.5

# %%
dfs_2014 = [ap2014, cancer2014, cardio2014, childpov2014, choles2014, dentvis2014, dentnum2014, diabetes2014, drug2014, healthstatfem2014, immunchild2014, incomeineq2014, infantmort2014, infectdis2014, obesity2014, physicalinac2014, premdeath2014, smoking2014, uninsured2014, alldet2014, alloutcomes2014, chlamydia2014, premdeathri2014, teenbirth2014, primcarephys2014]
nan_value = 0
clean2014 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2014)

clean2014 = clean2014.drop_duplicates(subset=['State Name'])

clean2014
# Out:
#      Edition            State Name  air_pollution_val  cancer_death_val  \
# 0       2014               Alabama               10.0             211.5
# 16      2014                Alaska                4.9             191.8
# 32      2014               Arizona                9.9             170.2
# 48      2014              Arkansas               10.3             214.9
# 64      2014            California               13.9             171.0
# 80      2014              Colorado                6.8             163.0
# 96      2014           Connecticut                8.7             177.0
# 112     2014              Delaware               10.2             201.9
# 128     2014               Florida                7.4             182.7
# 144     2014               Georgia               10.3             192.3
# 160     2014                Hawaii                8.7             155.3
# 176     2014                 Idaho               10.4             174.6
# ...

# %%
alldet2015 = data2015.loc[(data2015['Measure Name'] == 'All Determinants')]
alldet2015 = alldet2015[['Edition','State Name','Value']]
alldet2015 = alldet2015.rename(columns={'Value':'all_determs_val'})
alloutcomes2015 = data2015.loc[(data2015['Measure Name'] == 'All Outcomes')]
alloutcomes2015 = alloutcomes2015[['Edition','State Name','Value']]
alloutcomes2015 = alloutcomes2015.rename(columns={'Value':'all_outcomes_val'})
chlamydia2015 = data2015.loc[(data2015['Measure Name'] == 'Chlamydia')]
chlamydia2015 = chlamydia2015[['Edition','State Name','Value']]
chlamydia2015 = chlamydia2015.rename(columns={'Value':'chlamydia_val'})
premdeathri2015 = data2015.loc[(data2015['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2015 = premdeathri2015[['Edition','State Name','Value']]
premdeathri2015 = premdeathri2015.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2015 = data2015.loc[(data2015['Measure Name'] == 'Teen Births')]
teenbirth2015 = teenbirth2015[['Edition','State Name','Value']]
teenbirth2015 = teenbirth2015.rename(columns={'Value':'teen_birth_val'})
primcarephys2015 = data2015.loc[(data2015['Measure Name'] == 'Primary Care Physicians')]
primcarephys2015 = primcarephys2015[['Edition','State Name','Value']]
primcarephys2015 = primcarephys2015.rename(columns={'Value':'primary_care_val'})
ap2015 = data2015.loc[(data2015['Measure Name'] == 'Air Pollution')]
ap2015 = ap2015[['Edition','State Name','Value']]
ap2015 = ap2015.rename(columns={'Value':'air_pollution_val'})
cancer2015 = data2015.loc[(data2015['Measure Name'] == 'Cancer Deaths')]
cancer2015 = cancer2015[['Edition','State Name','Value']]
cancer2015 = cancer2015.rename(columns={'Value':'cancer_death_val'})
cardio2015 = data2015.loc[(data2015['Measure Name'] == 'Cardiovascular Deaths')]
cardio2015 = cardio2015[['Edition','State Name','Value']]
cardio2015 = cardio2015.rename(columns={'Value':'cardio_death_val'})
childpov2015 = data2015.loc[(data2015['Measure Name'] == 'Children in Poverty')]
childpov2015 = childpov2015[['Edition','State Name','Value']]
childpov2015 = childpov2015.rename(columns={'Value':'child_pov_val'})
choles2015 = data2015.loc[(data2015['Measure Name'] == 'Cholesterol Check')]
choles2015 = choles2015[['Edition','State Name','Value']]
choles2015 = choles2015.rename(columns={'Value':'choles_check_val'})
dentvis2015 = data2015.loc[(data2015['Measure Name'] == 'Dental Visit')]
dentvis2015 = dentvis2015[['Edition','State Name','Value']]
dentvis2015 = dentvis2015.rename(columns={'Value':'dent_vis_val'})
dentnum2015 = data2015.loc[(data2015['Measure Name'] == 'Dentists')]
dentnum2015 = dentnum2015[['Edition','State Name','Value']]
dentnum2015 = dentnum2015.rename(columns={'Value':'dentists_val'})
diabetes2015 = data2015.loc[(data2015['Measure Name'] == 'Diabetes')]
diabetes2015 = diabetes2015[['Edition','State Name','Value']]
diabetes2015 = diabetes2015.rename(columns={'Value':'diabetes_val'})
drug2015 = data2015.loc[(data2015['Measure Name'] == 'Drug Deaths')]
drug2015 = drug2015[['Edition','State Name','Value']]
drug2015 = drug2015.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2015 = data2015.loc[(data2015['Measure Name'] == 'High Health Status - Female')]
healthstatfem2015 = healthstatfem2015[['Edition','State Name','Value']]
healthstatfem2015 = healthstatfem2015.rename(columns={'Value':'health_stat_fem_val'})
immunchild2015 = data2015.loc[(data2015['Measure Name'] == 'Immunizations - Children')]
immunchild2015 = immunchild2015[['Edition','State Name','Value']]
immunchild2015 = immunchild2015.rename(columns={'Value':'immun_child_val'})
incomeineq2015 = data2015.loc[(data2015['Measure Name'] == 'Income Inequality')]
incomeineq2015 = incomeineq2015[['Edition','State Name','Value']]
incomeineq2015 = incomeineq2015.rename(columns={'Value':'income_ineq_val'})
infantmort2015 = data2015.loc[(data2015['Measure Name'] == 'Infant Mortality')]
infantmort2015 = infantmort2015[['Edition','State Name','Value']]
infantmort2015 = infantmort2015.rename(columns={'Value':'infant_mort_val'})
infectdis2015 = data2015.loc[(data2015['Measure Name'] == 'Infectious Disease')]
infectdis2015 = infectdis2015[['Edition','State Name','Value']]
infectdis2015 = infectdis2015.rename(columns={'Value':'infect_dis_val'})
obesity2015 = data2015.loc[(data2015['Measure Name'] == 'Obesity')]
obesity2015 = obesity2015[['Edition','State Name','Value']]
obesity2015 = obesity2015.rename(columns={'Value':'obesity_val'})
physicalinac2015 = data2015.loc[(data2015['Measure Name'] == 'Physical Inactivity')]
physicalinac2015 = physicalinac2015[['Edition','State Name','Value']]
physicalinac2015 = physicalinac2015.rename(columns={'Value':'phys_inac_val'})
premdeath2015 = data2015.loc[(data2015['Measure Name'] == 'Premature Death')]
premdeath2015 = premdeath2015[['Edition','State Name','Value']]
premdeath2015 = premdeath2015.rename(columns={'Value':'prem_death_val'})
smoking2015 = data2015.loc[(data2015['Measure Name'] == 'Smoking')]
smoking2015 = smoking2015[['Edition','State Name','Value']]
smoking2015 = smoking2015.rename(columns={'Value':'smoking_val'})
uninsured2015 = data2015.loc[(data2015['Measure Name'] == 'Uninsured')]
uninsured2015 = uninsured2015[['Edition','State Name','Value']]
uninsured2015 = uninsured2015.rename(columns={'Value':'uninsured_val'})
uninsured2015.head()
# Out:
#        Edition  State Name  uninsured_val
# 41078     2015     Alabama           12.9
# 41079     2015      Alaska           17.8
# 41080     2015     Arizona           15.4
# 41081     2015    Arkansas           13.9
# 41082     2015  California           14.8

# %%
dfs_2015 = [ap2015, cancer2015, cardio2015, childpov2015, choles2015, dentvis2015, dentnum2015, diabetes2015, drug2015, healthstatfem2015, immunchild2015, incomeineq2015, infantmort2015, infectdis2015, obesity2015, physicalinac2015, premdeath2015, smoking2015, uninsured2015, alldet2015, alloutcomes2015, chlamydia2015, premdeathri2015, teenbirth2015, primcarephys2015]
nan_value = 0
clean2015 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2015)

clean2015 = clean2015.drop_duplicates(subset=['State Name'])

clean2015
# Out:
#      Edition            State Name  air_pollution_val  cancer_death_val  \
# 0       2015               Alabama                9.5             211.6
# 16      2015                Alaska                6.0             194.1
# 32      2015               Arizona                9.7             169.6
# 48      2015              Arkansas                9.7             216.9
# 64      2015            California               12.5             170.1
# 80      2015              Colorado                7.0             162.2
# 96      2015           Connecticut                8.8             174.6
# 112     2015              Delaware                9.7             199.1
# 128     2015               Florida                7.2             182.0
# 144     2015               Georgia                9.8             192.8
# 160     2015                Hawaii                7.6             155.4
# 176     2015                 Idaho               11.7             175.8
# ...

# %%
alldet2016 = data2016.loc[(data2016['Measure Name'] == 'All Determinants')]
alldet2016 = alldet2016[['Edition','State Name','Value']]
alldet2016 = alldet2016.rename(columns={'Value':'all_determs_val'})
alloutcomes2016 = data2016.loc[(data2016['Measure Name'] == 'All Outcomes')]
alloutcomes2016 = alloutcomes2016[['Edition','State Name','Value']]
alloutcomes2016 = alloutcomes2016.rename(columns={'Value':'all_outcomes_val'})
chlamydia2016 = data2016.loc[(data2016['Measure Name'] == 'Chlamydia')]
chlamydia2016 = chlamydia2016[['Edition','State Name','Value']]
chlamydia2016 = chlamydia2016.rename(columns={'Value':'chlamydia_val'})
premdeathri2016 = data2016.loc[(data2016['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2016 = premdeathri2016[['Edition','State Name','Value']]
premdeathri2016 = premdeathri2016.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2016 = data2016.loc[(data2016['Measure Name'] == 'Teen Births')]
teenbirth2016 = teenbirth2016[['Edition','State Name','Value']]
teenbirth2016 = teenbirth2016.rename(columns={'Value':'teen_birth_val'})
primcarephys2016 = data2016.loc[(data2016['Measure Name'] == 'Primary Care Physicians')]
primcarephys2016 = primcarephys2016[['Edition','State Name','Value']]
primcarephys2016 = primcarephys2016.rename(columns={'Value':'primary_care_val'})
ap2016 = data2016.loc[(data2016['Measure Name'] == 'Air Pollution')]
ap2016 = ap2016[['Edition','State Name','Value']]
ap2016 = ap2016.rename(columns={'Value':'air_pollution_val'})
cancer2016 = data2016.loc[(data2016['Measure Name'] == 'Cancer Deaths')]
cancer2016 = cancer2016[['Edition','State Name','Value']]
cancer2016 = cancer2016.rename(columns={'Value':'cancer_death_val'})
cardio2016 = data2016.loc[(data2016['Measure Name'] == 'Cardiovascular Deaths')]
cardio2016 = cardio2016[['Edition','State Name','Value']]
cardio2016 = cardio2016.rename(columns={'Value':'cardio_death_val'})
childpov2016 = data2016.loc[(data2016['Measure Name'] == 'Children in Poverty')]
childpov2016 = childpov2016[['Edition','State Name','Value']]
childpov2016 = childpov2016.rename(columns={'Value':'child_pov_val'})
choles2016 = data2016.loc[(data2016['Measure Name'] == 'Cholesterol Check')]
choles2016 = choles2016[['Edition','State Name','Value']]
choles2016 = choles2016.rename(columns={'Value':'choles_check_val'})
dentvis2016 = data2016.loc[(data2016['Measure Name'] == 'Dental Visit')]
dentvis2016 = dentvis2016[['Edition','State Name','Value']]
dentvis2016 = dentvis2016.rename(columns={'Value':'dent_vis_val'})
dentnum2016 = data2016.loc[(data2016['Measure Name'] == 'Dentists')]
dentnum2016 = dentnum2016[['Edition','State Name','Value']]
dentnum2016 = dentnum2016.rename(columns={'Value':'dentists_val'})
diabetes2016 = data2016.loc[(data2016['Measure Name'] == 'Diabetes')]
diabetes2016 = diabetes2016[['Edition','State Name','Value']]
diabetes2016 = diabetes2016.rename(columns={'Value':'diabetes_val'})
drug2016 = data2016.loc[(data2016['Measure Name'] == 'Drug Deaths')]
drug2016 = drug2016[['Edition','State Name','Value']]
drug2016 = drug2016.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2016 = data2016.loc[(data2016['Measure Name'] == 'High Health Status - Female')]
healthstatfem2016 = healthstatfem2016[['Edition','State Name','Value']]
healthstatfem2016 = healthstatfem2016.rename(columns={'Value':'health_stat_fem_val'})
immunchild2016 = data2016.loc[(data2016['Measure Name'] == 'Immunizations - Children')]
immunchild2016 = immunchild2016[['Edition','State Name','Value']]
immunchild2016 = immunchild2016.rename(columns={'Value':'immun_child_val'})
incomeineq2016 = data2016.loc[(data2016['Measure Name'] == 'Income Inequality')]
incomeineq2016 = incomeineq2016[['Edition','State Name','Value']]
incomeineq2016 = incomeineq2016.rename(columns={'Value':'income_ineq_val'})
infantmort2016 = data2016.loc[(data2016['Measure Name'] == 'Infant Mortality')]
infantmort2016 = infantmort2016[['Edition','State Name','Value']]
infantmort2016 = infantmort2016.rename(columns={'Value':'infant_mort_val'})
infectdis2016 = data2016.loc[(data2016['Measure Name'] == 'Infectious Disease')]
infectdis2016 = infectdis2016[['Edition','State Name','Value']]
infectdis2016 = infectdis2016.rename(columns={'Value':'infect_dis_val'})
obesity2016 = data2016.loc[(data2016['Measure Name'] == 'Obesity')]
obesity2016 = obesity2016[['Edition','State Name','Value']]
obesity2016 = obesity2016.rename(columns={'Value':'obesity_val'})
physicalinac2016 = data2016.loc[(data2016['Measure Name'] == 'Physical Inactivity')]
physicalinac2016 = physicalinac2016[['Edition','State Name','Value']]
physicalinac2016 = physicalinac2016.rename(columns={'Value':'phys_inac_val'})
premdeath2016 = data2016.loc[(data2016['Measure Name'] == 'Premature Death')]
premdeath2016 = premdeath2016[['Edition','State Name','Value']]
premdeath2016 = premdeath2016.rename(columns={'Value':'prem_death_val'})
smoking2016 = data2016.loc[(data2016['Measure Name'] == 'Smoking')]
smoking2016 = smoking2016[['Edition','State Name','Value']]
smoking2016 = smoking2016.rename(columns={'Value':'smoking_val'})
uninsured2016 = data2016.loc[(data2016['Measure Name'] == 'Uninsured')]
uninsured2016 = uninsured2016[['Edition','State Name','Value']]
uninsured2016 = uninsured2016.rename(columns={'Value':'uninsured_val'})
uninsured2016.head()
# Out:
#        Edition     State Name  uninsured_val
# 50790     2016         Alaska           16.1
# 50791     2016        Alabama           11.1
# 50792     2016  United States           10.6
# 50793     2016       Arkansas           10.7
# 50794     2016        Arizona           12.2

# %%
dfs_2016 = [ap2016, cancer2016, cardio2016, childpov2016, choles2016, dentvis2016, dentnum2016, diabetes2016, drug2016, healthstatfem2016, immunchild2016, incomeineq2016, infantmort2016, infectdis2016, obesity2016, physicalinac2016, premdeath2016, smoking2016, uninsured2016, alldet2016, alloutcomes2016, chlamydia2016, premdeathri2016, teenbirth2016, primcarephys2016]
nan_value = 0
clean2016 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2016)

clean2016 = clean2016.drop_duplicates(subset=['State Name'])

clean2016
# Out:
#      Edition            State Name  air_pollution_val  cancer_death_val  \
# 0       2016                Alaska                8.8             193.3
# 16      2016               Alabama                9.1             211.1
# 32      2016              Arkansas                7.5             218.1
# 48      2016               Arizona                9.3             170.0
# 64      2016            California               11.4             169.9
# 80      2016              Colorado                6.6             161.8
# 96      2016           Connecticut                8.8             173.2
# 112     2016              Delaware                9.5             198.5
# 128     2016               Florida                6.8             182.1
# 144     2016               Georgia                9.1             194.4
# 160     2016                Hawaii                7.0             158.4
# 176     2016                  Iowa                8.6             194.4
# ...

# %%
alldet2017 = data2017.loc[(data2017['Measure Name'] == 'All Determinants')]
alldet2017 = alldet2017[['Edition','State Name','Value']]
alldet2017 = alldet2017.rename(columns={'Value':'all_determs_val'})
alloutcomes2017 = data2017.loc[(data2017['Measure Name'] == 'All Outcomes')]
alloutcomes2017 = alloutcomes2017[['Edition','State Name','Value']]
alloutcomes2017 = alloutcomes2017.rename(columns={'Value':'all_outcomes_val'})
chlamydia2017 = data2017.loc[(data2017['Measure Name'] == 'Chlamydia')]
chlamydia2017 = chlamydia2017[['Edition','State Name','Value']]
chlamydia2017 = chlamydia2017.rename(columns={'Value':'chlamydia_val'})
premdeathri2017 = data2017.loc[(data2017['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2017 = premdeathri2017[['Edition','State Name','Value']]
premdeathri2017 = premdeathri2017.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2017 = data2017.loc[(data2017['Measure Name'] == 'Teen Births')]
teenbirth2017 = teenbirth2017[['Edition','State Name','Value']]
teenbirth2017 = teenbirth2017.rename(columns={'Value':'teen_birth_val'})
primcarephys2017 = data2017.loc[(data2017['Measure Name'] == 'Primary Care Physicians')]
primcarephys2017 = primcarephys2017[['Edition','State Name','Value']]
primcarephys2017 = primcarephys2017.rename(columns={'Value':'primary_care_val'})
ap2017 = data2017.loc[(data2017['Measure Name'] == 'Air Pollution')]
ap2017 = ap2017[['Edition','State Name','Value']]
ap2017 = ap2017.rename(columns={'Value':'air_pollution_val'})
cancer2017 = data2017.loc[(data2017['Measure Name'] == 'Cancer Deaths')]
cancer2017 = cancer2017[['Edition','State Name','Value']]
cancer2017 = cancer2017.rename(columns={'Value':'cancer_death_val'})
cardio2017 = data2017.loc[(data2017['Measure Name'] == 'Cardiovascular Deaths')]
cardio2017 = cardio2017[['Edition','State Name','Value']]
cardio2017 = cardio2017.rename(columns={'Value':'cardio_death_val'})
childpov2017 = data2017.loc[(data2017['Measure Name'] == 'Children in Poverty')]
childpov2017 = childpov2017[['Edition','State Name','Value']]
childpov2017 = childpov2017.rename(columns={'Value':'child_pov_val'})
choles2017 = data2017.loc[(data2017['Measure Name'] == 'Cholesterol Check')]
choles2017 = choles2017[['Edition','State Name','Value']]
choles2017 = choles2017.rename(columns={'Value':'choles_check_val'})
dentvis2017 = data2017.loc[(data2017['Measure Name'] == 'Dental Visit')]
dentvis2017 = dentvis2017[['Edition','State Name','Value']]
dentvis2017 = dentvis2017.rename(columns={'Value':'dent_vis_val'})
dentnum2017 = data2017.loc[(data2017['Measure Name'] == 'Dentists')]
dentnum2017 = dentnum2017[['Edition','State Name','Value']]
dentnum2017 = dentnum2017.rename(columns={'Value':'dentists_val'})
diabetes2017 = data2017.loc[(data2017['Measure Name'] == 'Diabetes')]
diabetes2017 = diabetes2017[['Edition','State Name','Value']]
diabetes2017 = diabetes2017.rename(columns={'Value':'diabetes_val'})
drug2017 = data2017.loc[(data2017['Measure Name'] == 'Drug Deaths')]
drug2017 = drug2017[['Edition','State Name','Value']]
drug2017 = drug2017.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2017 = data2017.loc[(data2017['Measure Name'] == 'High Health Status - Female')]
healthstatfem2017 = healthstatfem2017[['Edition','State Name','Value']]
healthstatfem2017 = healthstatfem2017.rename(columns={'Value':'health_stat_fem_val'})
immunchild2017 = data2017.loc[(data2017['Measure Name'] == 'Immunizations - Children')]
immunchild2017 = immunchild2017[['Edition','State Name','Value']]
immunchild2017 = immunchild2017.rename(columns={'Value':'immun_child_val'})
incomeineq2017 = data2017.loc[(data2017['Measure Name'] == 'Income Inequality')]
incomeineq2017 = incomeineq2017[['Edition','State Name','Value']]
incomeineq2017 = incomeineq2017.rename(columns={'Value':'income_ineq_val'})
infantmort2017 = data2017.loc[(data2017['Measure Name'] == 'Infant Mortality')]
infantmort2017 = infantmort2017[['Edition','State Name','Value']]
infantmort2017 = infantmort2017.rename(columns={'Value':'infant_mort_val'})
infectdis2017 = data2017.loc[(data2017['Measure Name'] == 'Infectious Disease')]
infectdis2017 = infectdis2017[['Edition','State Name','Value']]
infectdis2017 = infectdis2017.rename(columns={'Value':'infect_dis_val'})
obesity2017 = data2017.loc[(data2017['Measure Name'] == 'Obesity')]
obesity2017 = obesity2017[['Edition','State Name','Value']]
obesity2017 = obesity2017.rename(columns={'Value':'obesity_val'})
physicalinac2017 = data2017.loc[(data2017['Measure Name'] == 'Physical Inactivity')]
physicalinac2017 = physicalinac2017[['Edition','State Name','Value']]
physicalinac2017 = physicalinac2017.rename(columns={'Value':'phys_inac_val'})
premdeath2017 = data2017.loc[(data2017['Measure Name'] == 'Premature Death')]
premdeath2017 = premdeath2017[['Edition','State Name','Value']]
premdeath2017 = premdeath2017.rename(columns={'Value':'prem_death_val'})
smoking2017 = data2017.loc[(data2017['Measure Name'] == 'Smoking')]
smoking2017 = smoking2017[['Edition','State Name','Value']]
smoking2017 = smoking2017.rename(columns={'Value':'smoking_val'})
uninsured2017 = data2017.loc[(data2017['Measure Name'] == 'Uninsured')]
uninsured2017 = uninsured2017[['Edition','State Name','Value']]
uninsured2017 = uninsured2017.rename(columns={'Value':'uninsured_val'})
uninsured2017.head()
# Out:
#        Edition     State Name  uninsured_val
# 53702     2017         Alaska           14.5
# 53703     2017        Alabama            9.6
# 53704     2017  United States            9.0
# 53705     2017       Arkansas            8.7
# 53706     2017        Arizona           10.4

# %%
dfs_2017 = [ap2017, cancer2017, cardio2017, childpov2017, choles2017, dentvis2017, dentnum2017, diabetes2017, drug2017, healthstatfem2017, immunchild2017, incomeineq2017, infantmort2017, infectdis2017, obesity2017, physicalinac2017, premdeath2017, smoking2017, uninsured2017, alldet2017, alloutcomes2017, chlamydia2017, premdeathri2017, teenbirth2017, primcarephys2017]
nan_value = 0
clean2017 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2017)

clean2017 = clean2017.drop_duplicates(subset=['State Name'])

clean2017
# Out:
#      Edition            State Name  air_pollution_val  cancer_death_val  \
# 0       2017                Alaska                8.7             194.9
# 8       2017               Alabama                8.9             210.6
# 16      2017              Arkansas                7.2             219.5
# 24      2017               Arizona                9.7             169.6
# 32      2017            California               11.7             169.3
# 40      2017              Colorado                6.6             160.9
# 48      2017           Connecticut                8.6             173.7
# 56      2017              Delaware                9.1             197.2
# 64      2017               Florida                6.8             182.1
# 72      2017               Georgia                9.0             195.2
# 80      2017                Hawaii                5.9             161.0
# 88      2017                  Iowa                7.8             195.2
# ...

# %%
alldet2018 = data2018.loc[(data2018['Measure Name'] == 'All Determinants')]
alldet2018 = alldet2018[['Edition','State Name','Value']]
alldet2018 = alldet2018.rename(columns={'Value':'all_determs_val'})
alloutcomes2018 = data2018.loc[(data2018['Measure Name'] == 'All Outcomes')]
alloutcomes2018 = alloutcomes2018[['Edition','State Name','Value']]
alloutcomes2018 = alloutcomes2018.rename(columns={'Value':'all_outcomes_val'})
chlamydia2018 = data2018.loc[(data2018['Measure Name'] == 'Chlamydia')]
chlamydia2018 = chlamydia2018[['Edition','State Name','Value']]
chlamydia2018 = chlamydia2018.rename(columns={'Value':'chlamydia_val'})
premdeathri2018 = data2018.loc[(data2018['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2018 = premdeathri2018[['Edition','State Name','Value']]
premdeathri2018 = premdeathri2018.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2018 = data2018.loc[(data2018['Measure Name'] == 'Teen Births')]
teenbirth2018 = teenbirth2018[['Edition','State Name','Value']]
teenbirth2018 = teenbirth2018.rename(columns={'Value':'teen_birth_val'})
primcarephys2018 = data2018.loc[(data2018['Measure Name'] == 'Primary Care Physicians')]
primcarephys2018 = primcarephys2018[['Edition','State Name','Value']]
primcarephys2018 = primcarephys2018.rename(columns={'Value':'primary_care_val'})
ap2018 = data2018.loc[(data2018['Measure Name'] == 'Air Pollution')]
ap2018 = ap2018[['Edition','State Name','Value']]
ap2018 = ap2018.rename(columns={'Value':'air_pollution_val'})
cancer2018 = data2018.loc[(data2018['Measure Name'] == 'Cancer Deaths')]
cancer2018 = cancer2018[['Edition','State Name','Value']]
cancer2018 = cancer2018.rename(columns={'Value':'cancer_death_val'})
cardio2018 = data2018.loc[(data2018['Measure Name'] == 'Cardiovascular Deaths')]
cardio2018 = cardio2018[['Edition','State Name','Value']]
cardio2018 = cardio2018.rename(columns={'Value':'cardio_death_val'})
childpov2018 = data2018.loc[(data2018['Measure Name'] == 'Children in Poverty')]
childpov2018 = childpov2018[['Edition','State Name','Value']]
childpov2018 = childpov2018.rename(columns={'Value':'child_pov_val'})
choles2018 = data2018.loc[(data2018['Measure Name'] == 'Cholesterol Check')]
choles2018 = choles2018[['Edition','State Name','Value']]
choles2018 = choles2018.rename(columns={'Value':'choles_check_val'})
dentvis2018 = data2018.loc[(data2018['Measure Name'] == 'Dental Visit')]
dentvis2018 = dentvis2018[['Edition','State Name','Value']]
dentvis2018 = dentvis2018.rename(columns={'Value':'dent_vis_val'})
dentnum2018 = data2018.loc[(data2018['Measure Name'] == 'Dentists')]
dentnum2018 = dentnum2018[['Edition','State Name','Value']]
dentnum2018 = dentnum2018.rename(columns={'Value':'dentists_val'})
diabetes2018 = data2018.loc[(data2018['Measure Name'] == 'Diabetes')]
diabetes2018 = diabetes2018[['Edition','State Name','Value']]
diabetes2018 = diabetes2018.rename(columns={'Value':'diabetes_val'})
drug2018 = data2018.loc[(data2018['Measure Name'] == 'Drug Deaths')]
drug2018 = drug2018[['Edition','State Name','Value']]
drug2018 = drug2018.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2018 = data2018.loc[(data2018['Measure Name'] == 'High Health Status - Female')]
healthstatfem2018 = healthstatfem2018[['Edition','State Name','Value']]
healthstatfem2018 = healthstatfem2018.rename(columns={'Value':'health_stat_fem_val'})
immunchild2018 = data2018.loc[(data2018['Measure Name'] == 'Immunizations - Children')]
immunchild2018 = immunchild2018[['Edition','State Name','Value']]
immunchild2018 = immunchild2018.rename(columns={'Value':'immun_child_val'})
incomeineq2018 = data2018.loc[(data2018['Measure Name'] == 'Income Inequality')]
incomeineq2018 = incomeineq2018[['Edition','State Name','Value']]
incomeineq2018 = incomeineq2018.rename(columns={'Value':'income_ineq_val'})
infantmort2018 = data2018.loc[(data2018['Measure Name'] == 'Infant Mortality')]
infantmort2018 = infantmort2018[['Edition','State Name','Value']]
infantmort2018 = infantmort2018.rename(columns={'Value':'infant_mort_val'})
infectdis2018 = data2018.loc[(data2018['Measure Name'] == 'Infectious Disease')]
infectdis2018 = infectdis2018[['Edition','State Name','Value']]
infectdis2018 = infectdis2018.rename(columns={'Value':'infect_dis_val'})
obesity2018 = data2018.loc[(data2018['Measure Name'] == 'Obesity')]
obesity2018 = obesity2018[['Edition','State Name','Value']]
obesity2018 = obesity2018.rename(columns={'Value':'obesity_val'})
physicalinac2018 = data2018.loc[(data2018['Measure Name'] == 'Physical Inactivity')]
physicalinac2018 = physicalinac2018[['Edition','State Name','Value']]
physicalinac2018 = physicalinac2018.rename(columns={'Value':'phys_inac_val'})
premdeath2018 = data2018.loc[(data2018['Measure Name'] == 'Premature Death')]
premdeath2018 = premdeath2018[['Edition','State Name','Value']]
premdeath2018 = premdeath2018.rename(columns={'Value':'prem_death_val'})
smoking2018 = data2018.loc[(data2018['Measure Name'] == 'Smoking')]
smoking2018 = smoking2018[['Edition','State Name','Value']]
smoking2018 = smoking2018.rename(columns={'Value':'smoking_val'})
uninsured2018 = data2018.loc[(data2018['Measure Name'] == 'Uninsured')]
uninsured2018 = uninsured2018[['Edition','State Name','Value']]
uninsured2018 = uninsured2018.rename(columns={'Value':'uninsured_val'})
uninsured2018.head()
# Out:
#        Edition     State Name  uninsured_val
# 58690     2018         Alaska           13.9
# 58691     2018        Alabama            9.3
# 58692     2018  United States            8.7
# 58693     2018       Arkansas            7.9
# 58694     2018        Arizona           10.1

# %%
dfs_2018 = [ap2018, cancer2018, cardio2018, childpov2018, choles2018, dentvis2018, dentnum2018, diabetes2018, drug2018, healthstatfem2018, immunchild2018, incomeineq2018, infantmort2018, infectdis2018, obesity2018, physicalinac2018, premdeath2018, smoking2018, uninsured2018, alldet2018, alloutcomes2018, chlamydia2018, premdeathri2018, teenbirth2018, primcarephys2018]
nan_value = 0
clean2018 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2018)

clean2018 = clean2018.drop_duplicates(subset=['State Name'])

clean2018
# Out:
#      Edition            State Name  air_pollution_val  cancer_death_val  \
# 0       2018                Alaska                7.4             192.1
# 4       2018               Alabama                8.4             210.5
# 8       2018              Arkansas                7.1             218.6
# 12      2018               Arizona                9.7             168.4
# 16      2018            California               11.9             169.2
# 20      2018              Colorado                6.7             162.3
# 24      2018           Connecticut                7.7             174.7
# 28      2018              Delaware                8.6             200.8
# 32      2018               Florida                7.1             181.4
# 36      2018               Georgia                8.6             195.5
# 40      2018                Hawaii                5.8             161.1
# 44      2018                  Iowa                7.2             195.3
# ...

# %%
alldet2019 = data2019.loc[(data2019['Measure Name'] == 'All Determinants')]
alldet2019 = alldet2019[['Edition','State Name','Value']]
alldet2019 = alldet2019.rename(columns={'Value':'all_determs_val'})
alloutcomes2019 = data2019.loc[(data2019['Measure Name'] == 'All Outcomes')]
alloutcomes2019 = alloutcomes2019[['Edition','State Name','Value']]
alloutcomes2019 = alloutcomes2019.rename(columns={'Value':'all_outcomes_val'})
chlamydia2019 = data2019.loc[(data2019['Measure Name'] == 'Chlamydia')]
chlamydia2019 = chlamydia2019[['Edition','State Name','Value']]
chlamydia2019 = chlamydia2019.rename(columns={'Value':'chlamydia_val'})
premdeathri2019 = data2019.loc[(data2019['Measure Name'] == 'Premature Death Racial Inequality')]
premdeathri2019 = premdeathri2019[['Edition','State Name','Value']]
premdeathri2019 = premdeathri2019.rename(columns={'Value':'prem_death_ri_val'})
teenbirth2019 = data2019.loc[(data2019['Measure Name'] == 'Teen Births')]
teenbirth2019 = teenbirth2019[['Edition','State Name','Value']]
teenbirth2019 = teenbirth2019.rename(columns={'Value':'teen_birth_val'})
primcarephys2019 = data2019.loc[(data2019['Measure Name'] == 'Primary Care Physicians')]
primcarephys2019 = primcarephys2019[['Edition','State Name','Value']]
primcarephys2019 = primcarephys2019.rename(columns={'Value':'primary_care_val'})
ap2019 = data2019.loc[(data2019['Measure Name'] == 'Air Pollution')]
ap2019 = ap2019[['Edition','State Name','Value']]
ap2019 = ap2019.rename(columns={'Value':'air_pollution_val'})
cancer2019 = data2019.loc[(data2019['Measure Name'] == 'Cancer Deaths')]
cancer2019 = cancer2019[['Edition','State Name','Value']]
cancer2019 = cancer2019.rename(columns={'Value':'cancer_death_val'})
cardio2019 = data2019.loc[(data2019['Measure Name'] == 'Cardiovascular Deaths')]
cardio2019 = cardio2019[['Edition','State Name','Value']]
cardio2019 = cardio2019.rename(columns={'Value':'cardio_death_val'})
childpov2019 = data2019.loc[(data2019['Measure Name'] == 'Children in Poverty')]
childpov2019 = childpov2019[['Edition','State Name','Value']]
childpov2019 = childpov2019.rename(columns={'Value':'child_pov_val'})
choles2019 = data2019.loc[(data2019['Measure Name'] == 'Cholesterol Check')]
choles2019 = choles2019[['Edition','State Name','Value']]
choles2019 = choles2019.rename(columns={'Value':'choles_check_val'})
dentvis2019 = data2019.loc[(data2019['Measure Name'] == 'Dental Visit')]
dentvis2019 = dentvis2019[['Edition','State Name','Value']]
dentvis2019 = dentvis2019.rename(columns={'Value':'dent_vis_val'})
dentnum2019 = data2019.loc[(data2019['Measure Name'] == 'Dentists')]
dentnum2019 = dentnum2019[['Edition','State Name','Value']]
dentnum2019 = dentnum2019.rename(columns={'Value':'dentists_val'})
diabetes2019 = data2019.loc[(data2019['Measure Name'] == 'Diabetes')]
diabetes2019 = diabetes2019[['Edition','State Name','Value']]
diabetes2019 = diabetes2019.rename(columns={'Value':'diabetes_val'})
drug2019 = data2019.loc[(data2019['Measure Name'] == 'Drug Deaths')]
drug2019 = drug2019[['Edition','State Name','Value']]
drug2019 = drug2019.rename(columns={'Value':'drug_deaths_val'})
healthstatfem2019 = data2019.loc[(data2019['Measure Name'] == 'High Health Status - Female')]
healthstatfem2019 = healthstatfem2019[['Edition','State Name','Value']]
healthstatfem2019 = healthstatfem2019.rename(columns={'Value':'health_stat_fem_val'})
immunchild2019 = data2019.loc[(data2019['Measure Name'] == 'Immunizations - Children')]
immunchild2019 = immunchild2019[['Edition','State Name','Value']]
immunchild2019 = immunchild2019.rename(columns={'Value':'immun_child_val'})
incomeineq2019 = data2019.loc[(data2019['Measure Name'] == 'Income Inequality')]
incomeineq2019 = incomeineq2019[['Edition','State Name','Value']]
incomeineq2019 = incomeineq2019.rename(columns={'Value':'income_ineq_val'})
infantmort2019 = data2019.loc[(data2019['Measure Name'] == 'Infant Mortality')]
infantmort2019 = infantmort2019[['Edition','State Name','Value']]
infantmort2019 = infantmort2019.rename(columns={'Value':'infant_mort_val'})
infectdis2019 = data2019.loc[(data2019['Measure Name'] == 'Infectious Disease')]
infectdis2019 = infectdis2019[['Edition','State Name','Value']]
infectdis2019 = infectdis2019.rename(columns={'Value':'infect_dis_val'})
obesity2019 = data2019.loc[(data2019['Measure Name'] == 'Obesity')]
obesity2019 = obesity2019[['Edition','State Name','Value']]
obesity2019 = obesity2019.rename(columns={'Value':'obesity_val'})
physicalinac2019 = data2019.loc[(data2019['Measure Name'] == 'Physical Inactivity')]
physicalinac2019 = physicalinac2019[['Edition','State Name','Value']]
physicalinac2019 = physicalinac2019.rename(columns={'Value':'phys_inac_val'})
premdeath2019 = data2019.loc[(data2019['Measure Name'] == 'Premature Death')]
premdeath2019 = premdeath2019[['Edition','State Name','Value']]
premdeath2019 = premdeath2019.rename(columns={'Value':'prem_death_val'})
smoking2019 = data2019.loc[(data2019['Measure Name'] == 'Smoking')]
smoking2019 = smoking2019[['Edition','State Name','Value']]
smoking2019 = smoking2019.rename(columns={'Value':'smoking_val'})
uninsured2019 = data2019.loc[(data2019['Measure Name'] == 'Uninsured')]
uninsured2019 = uninsured2019[['Edition','State Name','Value']]
uninsured2019 = uninsured2019.rename(columns={'Value':'uninsured_val'})
uninsured2019.head()
# Out:
#        Edition     State Name  uninsured_val
# 57505     2019         Alaska           13.2
# 57506     2019        Alabama            9.7
# 57507     2019  United States            8.8
# 57508     2019       Arkansas            8.1
# 57509     2019        Arizona           10.4

# %%
dfs_2019 = [ap2019, cancer2019, cardio2019, childpov2019, choles2019, dentvis2019, dentnum2019, diabetes2019, drug2019, healthstatfem2019, immunchild2019, incomeineq2019, infantmort2019, infectdis2019, obesity2019, physicalinac2019, premdeath2019, smoking2019, uninsured2019, alldet2019, alloutcomes2019, chlamydia2019, premdeathri2019, teenbirth2019, primcarephys2019]
nan_value = 0
clean2019 = reduce(lambda  left,right: pd.merge(left,right,on=['Edition', 'State Name'],
                                           how='outer'), dfs_2019)

clean2019 = clean2019.drop_duplicates(subset=['State Name'])

clean2019
# Out:
#      Edition            State Name  air_pollution_val  cancer_death_val  \
# 0       2019                Alaska                6.4             185.4
# 4       2019               Alabama                8.1             210.8
# 8       2019              Arkansas                7.1             217.7
# 12      2019               Arizona                9.7             168.5
# 16      2019            California               12.8             168.9
# 20      2019              Colorado                6.7             163.1
# 24      2019           Connecticut                7.2             174.2
# 28      2019              Delaware                8.3             201.3
# 32      2019               Florida                7.4             181.1
# 36      2019               Georgia                8.3             194.8
# 40      2019                Hawaii                5.4             159.1
# 44      2019                  Iowa                7.1             195.3
# ...

# %%
cleanStateValues = pd.concat([clean2009, clean2010, clean2011, clean2012, clean2013, clean2014, clean2015, clean2016, clean2017, clean2018, clean2019])
cleanStateValues = cleanStateValues.rename(columns={'index': 'id'})
cleanStateValues = cleanStateValues.rename(columns={'Edition':'year','State Name': 'state'})
cleanStateValues
# Out:
#      year                 state  air_pollution_val  cancer_death_val  \
# 0    2009               Alabama               13.5             211.3
# 16   2009                Alaska                6.9             186.2
# 32   2009               Arizona               10.5             168.4
# 48   2009              Arkansas               11.8             213.1
# 64   2009            California               13.9             173.9
# ..    ...                   ...                ...               ...
# 188  2019             Wisconsin                6.8             190.4
# 192  2019         West Virginia                7.6             224.9
# 196  2019               Wyoming                5.0             169.5
# 200  2019         United States                8.4             189.3
# 204  2019  District of Columbia                9.8             195.7
#
#      cardio_death_val  child_pov_val  choles_check_val  dent_vis_val  \
# ...

# %%
cleanStateValues.reset_index(drop=True, inplace=True)
cleanStateValues.head()
# Out:
#    year       state  air_pollution_val  cancer_death_val  cardio_death_val  \
# 0  2009     Alabama               13.5             211.3             347.9
# 1  2009      Alaska                6.9             186.2             231.8
# 2  2009     Arizona               10.5             168.4             228.1
# 3  2009    Arkansas               11.8             213.1             327.4
# 4  2009  California               13.9             173.9             270.0
#
#    child_pov_val  choles_check_val  dent_vis_val  dentists_val  diabetes_val  \
# 0           23.7              77.7          65.0          41.4          11.2
# 1            9.6              71.2          66.3          72.8           6.6
# 2           26.2              71.9          68.2          51.0           7.7
# 3           20.8              70.3          63.5          38.6           9.5
# 4           20.2              74.7          70.3          75.9           8.5
#
# ...

# %%
cleanStateValues.to_csv('../../output_file/state_X_values_proj3.csv',index=False)
