# %%
# Dependencies
import pandas as pd

# %% [markdown]
# ## State Level (excluded race)

# %%
filepath = "../output_file/INS_MMR_by_Race_ML.csv"
race_df = pd.read_csv(filepath)
race_df.head()
# Out:
#      state  state_code  year                       race race_code  \
# 0  Alabama           1  2016  Black or African American    2054-5
# 1  Alabama           1  2016                      White    2106-3
# 2  Alabama           1  2017  Black or African American    2054-5
# 3  Alabama           1  2017                      White    2106-3
# 4  Alabama           1  2018  Black or African American    2054-5
#
#           hispanic_origin hispanic_origin_code  total_births  births_by_race  \
# 0  Not Hispanic or Latino               2186-2         59151           17989
# 1  Not Hispanic or Latino               2186-2         59151           35319
# 2  Not Hispanic or Latino               2186-2         58941           18354
# 3  Not Hispanic or Latino               2186-2         58941           34784
# 4  Not Hispanic or Latino               2186-2         57761           17939
#
#    total_deaths  ...  total_mmr  mmr_by_race  total_population  \
# ...

# %%
race_df.columns
# Out:
# Index(['state', 'state_code', 'year', 'race', 'race_code', 'hispanic_origin',
#        'hispanic_origin_code', 'total_births', 'births_by_race',
#        'total_deaths', 'deaths_by_race', 'total_mmr', 'mmr_by_race',
#        'total_population', 'population_by_race', 'employer', 'non_group',
#        'medicaid', 'medicare', 'military', 'uninsured'],
#       dtype='object')

# %%
cleaned_race_df = race_df[['state', 'state_code', 'year', 'race','hispanic_origin',
        'births_by_race', 'deaths_by_race', 'mmr_by_race', 'population_by_race']].copy()

cleaned_race_df.head()
# Out:
#      state  state_code  year                       race  \
# 0  Alabama           1  2016  Black or African American
# 1  Alabama           1  2016                      White
# 2  Alabama           1  2017  Black or African American
# 3  Alabama           1  2017                      White
# 4  Alabama           1  2018  Black or African American
#
#           hispanic_origin  births_by_race  deaths_by_race  mmr_by_race  \
# 0  Not Hispanic or Latino           17989              14        77.83
# 1  Not Hispanic or Latino           35319              18        50.96
# 2  Not Hispanic or Latino           18354              25       136.21
# 3  Not Hispanic or Latino           34784              15        43.12
# 4  Not Hispanic or Latino           17939              14        78.04
#
#    population_by_race
# 0                   0
# 1                   0
# 2              704201
# 3             1655605
# 4              706754

# %%
cleaned_race_df.to_csv('../../machine_learning/Resources/race_data.csv')
