# %%
import pandas as pd

path2009 = "../Resources/2009-Annual.csv"
path2010 = "../Resources/2010-Annual.csv"
path2011 = "../Resources/2011-Annual.csv"
path2012 = "../Resources/2012-Annual.csv"
path2013 = "../Resources/2013-Annual.csv"
path2014 = "../Resources/2014-Annual.csv"
path2015 = "../Resources/2015-Annual.csv"
path2016 = "../Resources/2016-Annual.csv"
path2017 = "../Resources/2017-Annual.csv"
path2018 = "../Resources/2018-Annual.csv"
path2019 = "../Resources/2019-Annual.csv"

data2009 = pd.read_csv(path2009)
data2010 = pd.read_csv(path2010)
data2011 = pd.read_csv(path2011)
data2012 = pd.read_csv(path2012)
data2013 = pd.read_csv(path2013)
data2014 = pd.read_csv(path2014)
data2015 = pd.read_csv(path2015)
data2016 = pd.read_csv(path2016)
data2017 = pd.read_csv(path2017)
data2018 = pd.read_csv(path2018)
data2019 = pd.read_csv(path2019)

data2009.head()
# Out:
#    Edition  Report Type   Measure Name  State Name  Rank  Value  Score  \
# 0     2009  2009 Annual  Air Pollution     Alabama  45.0   13.5   0.72
# 1     2009  2009 Annual  Air Pollution      Alaska   5.0    6.9  -1.92
# 2     2009  2009 Annual  Air Pollution     Arizona  22.0   10.5  -0.48
# 3     2009  2009 Annual  Air Pollution    Arkansas  32.0   11.8   0.04
# 4     2009  2009 Annual  Air Pollution  California  47.0   13.9   0.88
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 2       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 3       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 4       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
#
#   Source Year
# 0   2006-2008
# 1   2006-2008
# 2   2006-2008
# 3   2006-2008
# 4   2006-2008

# %%
data2016['Measure Name'].unique()
# Out:
# array(['Air Pollution', 'All Determinants', 'All Outcomes', 'Arthritis',
#        'Arthritis - $25-$49,999', 'Arthritis - $50-$74,999',
#        'Arthritis - $75,000 or More', 'Arthritis - Ages 18-44',
#        'Arthritis - Ages 45-64', 'Arthritis - Ages 65+',
#        'Arthritis - American Indian/Alaska Native', 'Arthritis - Asian',
#        'Arthritis - Black', 'Arthritis - College Grad',
#        'Arthritis - Female', 'Arthritis - Hawaiian/Pacific Islander',
#        'Arthritis - High School Grad', 'Arthritis - Hispanic',
#        'Arthritis - Less Than $25,000',
#        'Arthritis - Less Than High School', 'Arthritis - Male',
#        'Arthritis - Multiracial', 'Arthritis - Other Race',
#        'Arthritis - Some College', 'Arthritis - White', 'Asthma',
#        'Asthma - $25-$49,999', 'Asthma - $50-$74,999',
#        'Asthma - $75,000 or More', 'Asthma - Ages 18-44',
#        'Asthma - Ages 45-64', 'Asthma - Ages 65+',
#        'Asthma - American Indian/Alaska Native', 'Asthma - Asian',
#        'Asthma - Black', 'Asthma - College Grad', 'Asthma - Female',
#        'Asthma - Hawaiian/Pacific Islander', 'Asthma - High School Grad',
#        'Asthma - Hispanic', 'Asthma - Less Than $25,000',
#        'Asthma - Less Than High School', 'Asthma - Male',
#        'Asthma - Multiracial', 'Asthma - Other Race',
#        'Asthma - Some College', 'Asthma - White',
#        'Avoided Care Due to Cost',
#        'Avoided Care Due to Cost - American Indian/Alaska Native',
#        'Avoided Care Due to Cost - Asian',
#        'Avoided Care Due to Cost - Black',
#        'Avoided Care Due to Cost - Hawaiian/Pacific Islander',
#        'Avoided Care Due to Cost - Hispanic',
#        'Avoided Care Due to Cost - Multiracial',
#        'Avoided Care Due to Cost - Other Race',
#        'Avoided Care Due to Cost - White', 'Behaviors', 'Binge Drinking',
#        'Binge Drinking - $25-$49,999', 'Binge Drinking - $50-$74,999',
#        'Binge Drinking - $75,000 or More', 'Binge Drinking - Ages 18-44',
#        'Binge Drinking - Ages 45-64', 'Binge Drinking - Ages 65+',
#        'Binge Drinking - American Indian/Alaska Native',
#        'Binge Drinking - Asian', 'Binge Drinking - Black',
#        'Binge Drinking - College Grad', 'Binge Drinking - Female',
#        'Binge Drinking - Hawaiian/Pacific Islander',
#        'Binge Drinking - High School Grad', 'Binge Drinking - Hispanic',
#        'Binge Drinking - Less Than $25,000',
#        'Binge Drinking - Less Than High School', 'Binge Drinking - Male',
#        'Binge Drinking - Rural', 'Binge Drinking - Some College',
#        'Binge Drinking - Suburban', 'Binge Drinking - Urban',
#        'Binge Drinking - White', 'Cancer', 'Cancer - $25-$49,999',
#        'Cancer - $50-$74,999', 'Cancer - $75,000 or More',
#        'Cancer - Ages 18-44', 'Cancer - Ages 45-64', 'Cancer - Ages 65+',
#        'Cancer - American Indian/Alaska Native', 'Cancer - Asian',
#        'Cancer - Black', 'Cancer - College Grad', 'Cancer - Female',
#        'Cancer - Hawaiian/Pacific Islander', 'Cancer - High School Grad',
#        'Cancer - Hispanic', 'Cancer - Less Than $25,000',
#        'Cancer - Less Than High School', 'Cancer - Male',
#        'Cancer - Multiracial', 'Cancer - Other Race',
#        'Cancer - Some College', 'Cancer - White', 'Cancer Deaths',
#        'Cancer Deaths - American Indian/Alaska Native',
#        'Cancer Deaths - Asian/Pacific Islander',
#        'Cancer Deaths - Black/African American',
#        'Cancer Deaths - Crude Rate', 'Cancer Deaths - Female',
#        'Cancer Deaths - Hispanic/Latino', 'Cancer Deaths - Male',
#        'Cancer Deaths - Standard Age Adjustment', 'Cancer Deaths - White',
#        'Cardiovascular Deaths',
#        'Cardiovascular Deaths - American Indian/Alaska Native',
#        'Cardiovascular Deaths - Asian/Pacific Islander',
#        'Cardiovascular Deaths - Black/African American',
#        'Cardiovascular Deaths - Crude Rate',
#        'Cardiovascular Deaths - Female',
#        'Cardiovascular Deaths - Hispanic/Latino',
#        'Cardiovascular Deaths - Male',
#        'Cardiovascular Deaths - Standard Age Adjustment',
#        'Cardiovascular Deaths - White', 'Cardiovascular Diseases',
#        'Cardiovascular Diseases - $25-$49,999',
#        'Cardiovascular Diseases - $50-$74,999',
#        'Cardiovascular Diseases - $75,000 or More',
#        'Cardiovascular Diseases - Ages 18-44',
#        'Cardiovascular Diseases - Ages 45-64',
#        'Cardiovascular Diseases - Ages 65+',
#        'Cardiovascular Diseases - American Indian/Alaska Native',
#        'Cardiovascular Diseases - Asian',
#        'Cardiovascular Diseases - Black',
#        'Cardiovascular Diseases - College Grad',
#        'Cardiovascular Diseases - Female',
#        'Cardiovascular Diseases - Hawaiian/Pacific Islander',
#        'Cardiovascular Diseases - High School Grad',
#        'Cardiovascular Diseases - Hispanic',
#        'Cardiovascular Diseases - Less Than $25,000',
#        'Cardiovascular Diseases - Less Than High School',
#        'Cardiovascular Diseases - Male',
#        'Cardiovascular Diseases - Multiracial',
#        'Cardiovascular Diseases - Other Race',
#        'Cardiovascular Diseases - Some College',
#        'Cardiovascular Diseases - White', 'Children in Poverty',
#        'Children in Poverty - American Indian or Alaska Native',
#        'Children in Poverty - Asian', 'Children in Poverty - Black',
#        'Children in Poverty - Hawaiian/Pacific Islander',
#        'Children in Poverty - Hispanic',
#        'Children in Poverty - Multiracial', 'Children in Poverty - White',
#        'Chlamydia', 'Chlamydia - American Indian/Alaska Native',
#        'Chlamydia - Asian', 'Chlamydia - Black/African American',
#        'Chlamydia - Female', 'Chlamydia - Hispanic/Latino',
#        'Chlamydia - Male', 'Chlamydia - White', 'Cholesterol Check',
#        'Cholesterol Check - $25-$49,999',
#        'Cholesterol Check - $50-$74,999',
#        'Cholesterol Check - $75,000 or More',
#        'Cholesterol Check - Ages 18-44', 'Cholesterol Check - Ages 45-64',
#        'Cholesterol Check - Ages 65+',
#        'Cholesterol Check - American Indian/Alaska Native',
#        'Cholesterol Check - Asian', 'Cholesterol Check - Black',
#        'Cholesterol Check - College Grad', 'Cholesterol Check - Female',
#        'Cholesterol Check - Hawaiian/Pacific Islander',
#        'Cholesterol Check - High School Grad',
#        'Cholesterol Check - Hispanic',
#        'Cholesterol Check - Less Than $25,000',
#        'Cholesterol Check - Less Than High School',
#        'Cholesterol Check - Male', 'Cholesterol Check - Rural',
#        'Cholesterol Check - Some College', 'Cholesterol Check - Suburban',
#        'Cholesterol Check - Urban', 'Cholesterol Check - White',
#        'Chronic Drinking', 'Chronic Drinking - $25-$49,999',
#        'Chronic Drinking - $50-$74,999',
#        'Chronic Drinking - $75,000 or More',
#        'Chronic Drinking - Ages 18-44', 'Chronic Drinking - Ages 45-64',
#        'Chronic Drinking - Ages 65+',
#        'Chronic Drinking - American Indian/Alaska Native',
#        'Chronic Drinking - Asian', 'Chronic Drinking - Black',
#        'Chronic Drinking - College Grad', 'Chronic Drinking - Female',
#        'Chronic Drinking - Hawaiian/Pacific Islander',
#        'Chronic Drinking - High School Grad',
#        'Chronic Drinking - Hispanic',
#        'Chronic Drinking - Less Than $25,000',
#        'Chronic Drinking - Less Than High School',
#        'Chronic Drinking - Male', 'Chronic Drinking - Rural',
#        'Chronic Drinking - Some College', 'Chronic Drinking - Suburban',
#        'Chronic Drinking - Urban', 'Chronic Drinking - White',
#        'Chronic Kidney Disease', 'Chronic Kidney Disease - $25-$49,999',
#        'Chronic Kidney Disease - $50-$74,999',
#        'Chronic Kidney Disease - $75,000 or More',
#        'Chronic Kidney Disease - Ages 18-44',
#        'Chronic Kidney Disease - Ages 45-64',
#        'Chronic Kidney Disease - Ages 65+',
#        'Chronic Kidney Disease - American Indian/Alaska Native',
#        'Chronic Kidney Disease - Asian', 'Chronic Kidney Disease - Black',
#        'Chronic Kidney Disease - College Grad',
#        'Chronic Kidney Disease - Female',
#        'Chronic Kidney Disease - Hawaiian/Pacific Islander',
#        'Chronic Kidney Disease - High School Grad',
#        'Chronic Kidney Disease - Hispanic',
#        'Chronic Kidney Disease - Less Than $25,000',
#        'Chronic Kidney Disease - Less Than High School',
#        'Chronic Kidney Disease - Male',
#        'Chronic Kidney Disease - Multiracial',
#        'Chronic Kidney Disease - Other Race',
#        'Chronic Kidney Disease - Some College',
#        'Chronic Kidney Disease - White',
#        'Chronic Obstructive Pulmonary Disease',
#        'Chronic Obstructive Pulmonary Disease - $25-$49,999',
#        'Chronic Obstructive Pulmonary Disease - $50-$74,999',
#        'Chronic Obstructive Pulmonary Disease - $75,000 or More',
#        'Chronic Obstructive Pulmonary Disease - Ages 18-44',
#        'Chronic Obstructive Pulmonary Disease - Ages 45-64',
#        'Chronic Obstructive Pulmonary Disease - Ages 65+',
#        'Chronic Obstructive Pulmonary Disease - American Indian/Alaska Native',
#        'Chronic Obstructive Pulmonary Disease - Asian',
#        'Chronic Obstructive Pulmonary Disease - Black',
#        'Chronic Obstructive Pulmonary Disease - College Grad',
#        'Chronic Obstructive Pulmonary Disease - Female',
#        'Chronic Obstructive Pulmonary Disease - Hawaiian/Pacific Islander',
#        'Chronic Obstructive Pulmonary Disease - High School Grad',
#        'Chronic Obstructive Pulmonary Disease - Hispanic',
#        'Chronic Obstructive Pulmonary Disease - Less Than $25,000',
#        'Chronic Obstructive Pulmonary Disease - Less Than High School',
#        'Chronic Obstructive Pulmonary Disease - Male',
#        'Chronic Obstructive Pulmonary Disease - Multiracial',
#        'Chronic Obstructive Pulmonary Disease - Other Race',
#        'Chronic Obstructive Pulmonary Disease - Some College',
#        'Chronic Obstructive Pulmonary Disease - White', 'Clinical Care',
#        'Colorectal Cancer Screening',
#        'Colorectal Cancer Screening - $25-$49,999',
#        'Colorectal Cancer Screening - $50-$74,999',
#        'Colorectal Cancer Screening - $75,000 or More',
#        'Colorectal Cancer Screening - American Indian/Alaska Native',
#        'Colorectal Cancer Screening - Asian',
#        'Colorectal Cancer Screening - Black',
#        'Colorectal Cancer Screening - College Grad',
#        'Colorectal Cancer Screening - Female',
#        'Colorectal Cancer Screening - Hawaiian/Pacific Islander',
#        'Colorectal Cancer Screening - High School Grad',
#        'Colorectal Cancer Screening - Hispanic',
#        'Colorectal Cancer Screening - Less Than $25,000',
#        'Colorectal Cancer Screening - Less Than High School',
#        'Colorectal Cancer Screening - Male',
#        'Colorectal Cancer Screening - Rural',
#        'Colorectal Cancer Screening - Some College',
#        'Colorectal Cancer Screening - Suburban',
#        'Colorectal Cancer Screening - Urban',
#        'Colorectal Cancer Screening - White', 'Community & Environment',
#        'Dedicated HC Provider - $25-$49,999',
#        'Dedicated HC Provider - $50-$74,999',
#        'Dedicated HC Provider - $75,000 or More',
#        'Dedicated HC Provider - 18-44', 'Dedicated HC Provider - 45-64',
#        'Dedicated HC Provider - 65+',
#        'Dedicated HC Provider - American Indian/Alaska Native',
#        'Dedicated HC Provider - Asian', 'Dedicated HC Provider - Black',
#        'Dedicated HC Provider - College Grad',
#        'Dedicated HC Provider - Female',
#        'Dedicated HC Provider - Hawaiian/Pacific Islander',
#        'Dedicated HC Provider - High School Grad',
#        'Dedicated HC Provider - Hispanic',
#        'Dedicated HC Provider - Less Than $25,000',
#        'Dedicated HC Provider - Less Than High School',
#        'Dedicated HC Provider - Male', 'Dedicated HC Provider - Rural',
#        'Dedicated HC Provider - Some College',
#        'Dedicated HC Provider - Suburban',
#        'Dedicated HC Provider - Urban', 'Dedicated HC Provider - White',
#        'Dedicated Health Care Provider', 'Dental Visit',
#        'Dental Visit - $25-$49,999', 'Dental Visit - $50-$74,999',
#        'Dental Visit - $75,000 or More', 'Dental Visit - Ages 18-44',
#        'Dental Visit - Ages 45-64', 'Dental Visit - Ages 65+',
#        'Dental Visit - American Indian/Alaska Native',
#        'Dental Visit - Asian', 'Dental Visit - Black',
#        'Dental Visit - College Grad', 'Dental Visit - Female',
#        'Dental Visit - Hawaiian/Pacific Islander',
#        'Dental Visit - High School Grad', 'Dental Visit - Hispanic',
#        'Dental Visit - Less Than $25,000',
#        'Dental Visit - Less Than High School', 'Dental Visit - Male',
#        'Dental Visit - Rural', 'Dental Visit - Some College',
#        'Dental Visit - Suburban', 'Dental Visit - Urban',
#        'Dental Visit - White', 'Dentists', 'Depression',
#        'Depression - $25-$49,999', 'Depression - $50-$74,999',
#        'Depression - $75,000 or More', 'Depression - Ages 18-44',
#        'Depression - Ages 45-64', 'Depression - Ages 65+',
#        'Depression - American Indian/Alaska Native', 'Depression - Asian',
#        'Depression - Black', 'Depression - College Grad',
#        'Depression - Female', 'Depression - Hawaiian/Pacific Islander',
#        'Depression - High School Grad', 'Depression - Hispanic',
#        'Depression - Less Than $25,000',
#        'Depression - Less Than High School', 'Depression - Male',
#        'Depression - Multiracial', 'Depression - Other Race',
#        'Depression - Some College', 'Depression - White', 'Diabetes',
#        'Diabetes - $25-$49,999', 'Diabetes - $50-$74,999',
#        'Diabetes - $75,000 or More', 'Diabetes - Ages 18-44',
#        'Diabetes - Ages 45-64', 'Diabetes - Ages 65+',
#        'Diabetes - American Indian/Alaska Native', 'Diabetes - Asian',
#        'Diabetes - Black', 'Diabetes - College Grad', 'Diabetes - Female',
#        'Diabetes - Hawaiian/Pacific Islander',
#        'Diabetes - High School Grad', 'Diabetes - Hispanic',
#        'Diabetes - Less Than $25,000', 'Diabetes - Less Than High School',
#        'Diabetes - Male', 'Diabetes - Multiracial',
#        'Diabetes - Other Race', 'Diabetes - Rural',
#        'Diabetes - Some College', 'Diabetes - Suburban',
#        'Diabetes - Urban', 'Diabetes - White',
#        'Disparity in Health Status', 'Drug Deaths',
#        'Drug Deaths - American Indian/Alaska Native',
#        'Drug Deaths - Asian/Pacific Islander',
#        'Drug Deaths - Black/African American', 'Drug Deaths - Female',
#        'Drug Deaths - Hispanic/Latino', 'Drug Deaths - Male',
#        'Drug Deaths - White', 'Drug Deaths (1-year)',
#        'Drug Deaths (1-year) - Ages 15-24',
#        'Drug Deaths (1-year) - Ages 25-34',
#        'Drug Deaths (1-year) - Ages 35-44',
#        'Drug Deaths (1-year) - Ages 45-54',
#        'Drug Deaths (1-year) - Ages 55-64',
#        'Drug Deaths (1-year) - Ages 65-74',
#        'Drug Deaths (1-year) - American Indian/Alaska Native',
#        'Drug Deaths (1-year) - Asian/Pacific Islander',
#        'Drug Deaths (1-year) - Black/African American',
#        'Drug Deaths (1-year) - Female', 'Drug Deaths (1-year) - Hispanic',
#        'Drug Deaths (1-year) - Male', 'Drug Deaths (1-year) - White',
#        'Excessive Drinking', 'Excessive Drinking - $25-$49,999',
#        'Excessive Drinking - $50-$74,999',
#        'Excessive Drinking - $75,000 or More',
#        'Excessive Drinking - Ages 18-44',
#        'Excessive Drinking - Ages 45-64', 'Excessive Drinking - Ages 65+',
#        'Excessive Drinking - American Indian/Alaska Native',
#        'Excessive Drinking - Asian', 'Excessive Drinking - Black',
#        'Excessive Drinking - College Grad', 'Excessive Drinking - Female',
#        'Excessive Drinking - Hawaiian/Pacific Islander',
#        'Excessive Drinking - High School Grad',
#        'Excessive Drinking - Hispanic',
#        'Excessive Drinking - Less Than $25,000',
#        'Excessive Drinking - Less Than High School',
#        'Excessive Drinking - Male', 'Excessive Drinking - Rural',
#        'Excessive Drinking - Some College',
#        'Excessive Drinking - Suburban', 'Excessive Drinking - Urban',
#        'Excessive Drinking - White', 'Excessive Drinking Rate of Change',
#        'Excessive Drinking Rate of Change-College Graduate',
#        'Excessive Drinking Rate of Change-High School Grad',
#        'Excessive Drinking Rate of Change-Less Than High S',
#        'Excessive Drinking Rate of Change-Some College', 'Exercise',
#        'Exercise - $25-$49,999', 'Exercise - $50-$74,999',
#        'Exercise - $75,000 or More', 'Exercise - Ages 18-44',
#        'Exercise - Ages 45-64', 'Exercise - Ages 65+',
#        'Exercise - American Indian/Alaska Native', 'Exercise - Asian',
#        'Exercise - Black', 'Exercise - College Grad', 'Exercise - Female',
#        'Exercise - Hawaiian/Pacific Islander',
#        'Exercise - High School Grad', 'Exercise - Hispanic',
#        'Exercise - Less Than $25,000', 'Exercise - Less Than High School',
#        'Exercise - Male', 'Exercise - Multiracial',
#        'Exercise - Other Race', 'Exercise - Some College',
#        'Exercise - White', 'Flu Vaccination',
#        'Flu Vaccination - $25-$49,999', 'Flu Vaccination - $50-$74,999',
#        'Flu Vaccination - $75,000 or More', 'Flu Vaccination - 18-44',
#        'Flu Vaccination - 45-64', 'Flu Vaccination - 65+',
#        'Flu Vaccination - American Indian', 'Flu Vaccination - Asian',
#        'Flu Vaccination - Black', 'Flu Vaccination - College Grad',
#        'Flu Vaccination - Female', 'Flu Vaccination - Hawaiian PI',
#        'Flu Vaccination - High School Grad', 'Flu Vaccination - Hispanic',
#        'Flu Vaccination - Less Than $25,000',
#        'Flu Vaccination - Less Than HS', 'Flu Vaccination - Male',
#        'Flu Vaccination - Multiracial', 'Flu Vaccination - Other Race',
#        'Flu Vaccination - Some College', 'Flu Vaccination - White',
#        'Food Insecurity', 'Frequent Mental Distress',
#        'Frequent Mental Distress - $25-$49,999',
#        'Frequent Mental Distress - $50-$74,999',
#        'Frequent Mental Distress - $75,000 or More',
#        'Frequent Mental Distress - Ages 18-44',
#        'Frequent Mental Distress - Ages 45-64',
#        'Frequent Mental Distress - Ages 65+',
#        'Frequent Mental Distress - American Indian/Alaska Native',
#        'Frequent Mental Distress - Asian',
#        'Frequent Mental Distress - Black',
#        'Frequent Mental Distress - College Grad',
#        'Frequent Mental Distress - Female',
#        'Frequent Mental Distress - Hawaiian/Pacific Islander',
#        'Frequent Mental Distress - High School Grad',
#        'Frequent Mental Distress - Hispanic',
#        'Frequent Mental Distress - Less Than $25,000',
#        'Frequent Mental Distress - Less Than High School',
#        'Frequent Mental Distress - Male',
#        'Frequent Mental Distress - Rural',
#        'Frequent Mental Distress - Some College',
#        'Frequent Mental Distress - Suburban',
#        'Frequent Mental Distress - Urban',
#        'Frequent Mental Distress - White', 'Frequent Physical Distress',
#        'Frequent Physical Distress - $25-$49,999',
#        'Frequent Physical Distress - $50-$74,999',
#        'Frequent Physical Distress - $75,000 or More',
#        'Frequent Physical Distress - Ages 18-44',
#        'Frequent Physical Distress - Ages 45-64',
#        'Frequent Physical Distress - Ages 65+',
#        'Frequent Physical Distress - American Indian/Alaska Native',
#        'Frequent Physical Distress - Asian',
#        'Frequent Physical Distress - Black',
#        'Frequent Physical Distress - College Grad',
#        'Frequent Physical Distress - Female',
#        'Frequent Physical Distress - Hawaiian/Pacific Islander',
#        'Frequent Physical Distress - High School Grad',
#        'Frequent Physical Distress - Hispanic',
#        'Frequent Physical Distress - Less Than $25,000',
#        'Frequent Physical Distress - Less Than High School',
#        'Frequent Physical Distress - Male',
#        'Frequent Physical Distress - Rural',
#        'Frequent Physical Distress - Some College',
#        'Frequent Physical Distress - Suburban',
#        'Frequent Physical Distress - Urban',
#        'Frequent Physical Distress - White', 'Fruits', 'Heart Attack',
#        'Heart Attack - $25-$49,999', 'Heart Attack - $50-$74,999',
#        'Heart Attack - $75,000 or More', 'Heart Attack - Ages 18-44',
#        'Heart Attack - Ages 45-64', 'Heart Attack - Ages 65+',
#        'Heart Attack - American Indian/Alaska Native',
#        'Heart Attack - Asian', 'Heart Attack - Black',
#        'Heart Attack - College Grad', 'Heart Attack - Female',
#        'Heart Attack - Hawaiian/Pacific Islander',
#        'Heart Attack - High School Grad', 'Heart Attack - Hispanic',
#        'Heart Attack - Less Than $25,000',
#        'Heart Attack - Less Than High School', 'Heart Attack - Male',
#        'Heart Attack - Rural', 'Heart Attack - Some College',
#        'Heart Attack - Suburban', 'Heart Attack - Urban',
#        'Heart Attack - White', 'Heart Disease',
#        'Heart Disease - $25-$49,999', 'Heart Disease - $50-$74,999',
#        'Heart Disease - $75,000 or More', 'Heart Disease - Ages 18-44',
#        'Heart Disease - Ages 45-64', 'Heart Disease - Ages 65+',
#        'Heart Disease - American Indian/Alaska Native',
#        'Heart Disease - Asian', 'Heart Disease - Black',
#        'Heart Disease - College Grad', 'Heart Disease - Female',
#        'Heart Disease - Hawaiian/Pacific Islander',
#        'Heart Disease - High School Grad', 'Heart Disease - Hispanic',
#        'Heart Disease - Less Than $25,000',
#        'Heart Disease - Less Than High School', 'Heart Disease - Male',
#        'Heart Disease - Rural', 'Heart Disease - Some College',
#        'Heart Disease - Suburban', 'Heart Disease - Urban',
#        'Heart Disease - White', 'High Blood Pressure',
#        'High Blood Pressure - $25-$49,999',
#        'High Blood Pressure - $50-$74,999',
#        'High Blood Pressure - $75,000 or More',
#        'High Blood Pressure - Ages 18-44',
#        'High Blood Pressure - Ages 45-64',
#        'High Blood Pressure - Ages 65+',
#        'High Blood Pressure - American Indian/Alaska Native',
#        'High Blood Pressure - Asian', 'High Blood Pressure - Black',
#        'High Blood Pressure - College Grad',
#        'High Blood Pressure - Female',
#        'High Blood Pressure - Hawaiian/Pacific Islander',
#        'High Blood Pressure - High School Grad',
#        'High Blood Pressure - Hispanic',
#        'High Blood Pressure - Less Than $25,000',
#        'High Blood Pressure - Less Than High School',
#        'High Blood Pressure - Male', 'High Blood Pressure - Rural',
#        'High Blood Pressure - Some College',
#        'High Blood Pressure - Suburban', 'High Blood Pressure - Urban',
#        'High Blood Pressure - White', 'High Cholesterol',
#        'High Cholesterol - $25-$49,999', 'High Cholesterol - $50-$74,999',
#        'High Cholesterol - $75,000 or More',
#        'High Cholesterol - Ages 18-44', 'High Cholesterol - Ages 45-64',
#        'High Cholesterol - Ages 65+',
#        'High Cholesterol - American Indian/Alaska Native',
#        'High Cholesterol - Asian', 'High Cholesterol - Black',
#        'High Cholesterol - College Grad', 'High Cholesterol - Female',
#        'High Cholesterol - Hawaiian/Pacific Islander',
#        'High Cholesterol - High School Grad',
#        'High Cholesterol - Hispanic',
#        'High Cholesterol - Less Than $25,000',
#        'High Cholesterol - Less Than High School',
#        'High Cholesterol - Male', 'High Cholesterol - Some College',
#        'High Cholesterol - White', 'High Health Status',
#        'High Health Status - $25-$49,999',
#        'High Health Status - $50-$74,999',
#        'High Health Status - $75,000 or More',
#        'High Health Status - Ages 18-44',
#        'High Health Status - Ages 45-64', 'High Health Status - Ages 65+',
#        'High Health Status - American Indian/Alaska Native',
#        'High Health Status - Asian', 'High Health Status - Black',
#        'High Health Status - College Grad', 'High Health Status - Female',
#        'High Health Status - Hawaiian/Pacific Islander',
#        'High Health Status - High School Grad',
#        'High Health Status - Hispanic',
#        'High Health Status - Less Than $25,000',
#        'High Health Status - Less Than High School',
#        'High Health Status - Male', 'High Health Status - Rural',
#        'High Health Status - Some College',
#        'High Health Status - Suburban', 'High Health Status - Urban',
#        'High Health Status - White', 'High School Graduation',
#        'High School Graduation - American Indian/Alaska Native',
#        'High School Graduation - Asian/Pacific Islander',
#        'High School Graduation - Black',
#        'High School Graduation - Hispanic',
#        'High School Graduation - White', 'High-speed Internet',
#        'High-speed Internet - American Indian/Alaska Native',
#        'High-speed Internet - Asian', 'High-speed Internet - Black',
#        'High-speed Internet - Hawaiian/Pacific Islander',
#        'High-speed Internet - Hispanic',
#        'High-speed Internet - Multiracial',
#        'High-speed Internet - Other Race', 'High-speed Internet - White',
#        'Immunization HPV Females',
#        'Immunization HPV Females - Above Poverty',
#        'Immunization HPV Females - Below Poverty',
#        'Immunization HPV Females - Black',
#        'Immunization HPV Females - Hispanic',
#        'Immunization HPV Females - White', 'Immunization HPV Males',
#        'Immunization HPV Males - Above Poverty',
#        'Immunization HPV Males - Below Poverty',
#        'Immunization HPV Males - Black',
#        'Immunization HPV Males - Hispanic',
#        'Immunization HPV Males - White', 'Immunizations - Adolescents',
#        'Immunizations - Children', 'Income Inequality',
#        'Income Inequality - Gini Index', 'Infant Mortality',
#        'Infant Mortality - American Indian/Alaska Native',
#        'Infant Mortality - Asian', 'Infant Mortality - Black',
#        'Infant Mortality - Hispanic',
#        'Infant Mortality - Mother Ages 15-19',
#        'Infant Mortality - Mother Ages 20-24',
#        'Infant Mortality - Mother Ages 25-29',
#        'Infant Mortality - Mother Ages 30-34',
#        'Infant Mortality - Mother Ages 35-39',
#        'Infant Mortality - Mother Ages 40-44', 'Infant Mortality - White',
#        'Infectious Disease', 'Injury Deaths',
#        'Injury Deaths - Ages 15-24', 'Injury Deaths - Ages 25-34',
#        'Injury Deaths - Ages 35-44', 'Injury Deaths - Ages 45-54',
#        'Injury Deaths - Ages 5-14', 'Injury Deaths - Ages 55-64',
#        'Injury Deaths - Ages 65-74',
#        'Injury Deaths - American Indian/Alaska Native',
#        'Injury Deaths - Asian/Pacific Islander', 'Injury Deaths - Black',
#        'Injury Deaths - Female', 'Injury Deaths - Hispanic',
#        'Injury Deaths - Male', 'Injury Deaths - White',
#        'Insufficient Sleep', 'Insufficient Sleep - $25-$49,999',
#        'Insufficient Sleep - $50-$74,999',
#        'Insufficient Sleep - $75,000 or More',
#        'Insufficient Sleep - Ages 18-44',
#        'Insufficient Sleep - Ages 45-64', 'Insufficient Sleep - Ages 65+',
#        'Insufficient Sleep - American Indian/Alaska Native',
#        'Insufficient Sleep - Asian', 'Insufficient Sleep - Black',
#        'Insufficient Sleep - College Grad', 'Insufficient Sleep - Female',
#        'Insufficient Sleep - Hawaiian/Pacific Islander',
#        'Insufficient Sleep - High School Grad',
#        'Insufficient Sleep - Hispanic',
#        'Insufficient Sleep - Less Than $25,000',
#        'Insufficient Sleep - Less Than High School',
#        'Insufficient Sleep - Male', 'Insufficient Sleep - Rural',
#        'Insufficient Sleep - Some College',
#        'Insufficient Sleep - Suburban', 'Insufficient Sleep - Urban',
#        'Insufficient Sleep - White', 'Low Birthweight',
#        'Low Birthweight - American Indian/Alaska Native',
#        'Low Birthweight - Asian/Pacific Islander',
#        'Low Birthweight - Black/African American',
#        'Low Birthweight - College Graduate',
#        'Low Birthweight - High School Graduate',
#        'Low Birthweight - Hispanic',
#        'Low Birthweight - Less Than High School',
#        'Low Birthweight - Mother Ages 15-19',
#        'Low Birthweight - Mother Ages 20-24',
#        'Low Birthweight - Mother Ages 25-29',
#        'Low Birthweight - Mother Ages 30-34',
#        'Low Birthweight - Mother Ages 35-39',
#        'Low Birthweight - Mother Ages 40-44',
#        'Low Birthweight - Some College', 'Low Birthweight - White',
#        'Median Household Income', 'Meningococcal Immunizations',
#        'Multiple Chronic Conditions',
#        'Multiple Chronic Conditions - $25-$49,999',
#        'Multiple Chronic Conditions - $50-$74,999',
#        'Multiple Chronic Conditions - $75,000 or More',
#        'Multiple Chronic Conditions - Ages 18-44',
#        'Multiple Chronic Conditions - Ages 45-64',
#        'Multiple Chronic Conditions - Ages 65+',
#        'Multiple Chronic Conditions - American Indian/Alaska Native',
#        'Multiple Chronic Conditions - Asian',
#        'Multiple Chronic Conditions - Black',
#        'Multiple Chronic Conditions - College Grad',
#        'Multiple Chronic Conditions - Female',
#        'Multiple Chronic Conditions - Hawaiian/Pacific Islander',
#        'Multiple Chronic Conditions - High School Grad',
#        'Multiple Chronic Conditions - Hispanic',
#        'Multiple Chronic Conditions - Less Than $25,000',
#        'Multiple Chronic Conditions - Less Than High School',
#        'Multiple Chronic Conditions - Male',
#        'Multiple Chronic Conditions - Multiracial',
#        'Multiple Chronic Conditions - Other Race',
#        'Multiple Chronic Conditions - Some College',
#        'Multiple Chronic Conditions - White', 'Obesity',
#        'Obesity - $25-$49,999', 'Obesity - $50-$74,999',
#        'Obesity - $75,000 or More', 'Obesity - Ages 18-44',
#        'Obesity - Ages 45-64', 'Obesity - Ages 65+',
#        'Obesity - American Indian/Alaska Native', 'Obesity - Asian',
#        'Obesity - Black', 'Obesity - College Grad', 'Obesity - Female',
#        'Obesity - Hawaiian/Pacific Islander',
#        'Obesity - High School Grad', 'Obesity - Hispanic',
#        'Obesity - Less Than $25,000', 'Obesity - Less Than High School',
#        'Obesity - Male', 'Obesity - Rural', 'Obesity - Some College',
#        'Obesity - Suburban', 'Obesity - Urban', 'Obesity - White',
#        'Obesity Rate of Change',
#        'Obesity Rate of Change-College Graduate',
#        'Obesity Rate of Change-High School Graduate',
#        'Obesity Rate of Change-Less Than High School',
#        'Obesity Rate of Change-Some College', 'Occupational Fatalities',
#        'Overall', 'Personal Income, Per Capita ', 'Pertussis',
#        'Physical Inactivity', 'Physical Inactivity - $25-$49,999',
#        'Physical Inactivity - $50-$74,999',
#        'Physical Inactivity - $75,000 or More',
#        'Physical Inactivity - Ages 18-44',
#        'Physical Inactivity - Ages 45-64',
#        'Physical Inactivity - Ages 65+',
#        'Physical Inactivity - American Indian/Alaska Native',
#        'Physical Inactivity - Asian', 'Physical Inactivity - Black',
#        'Physical Inactivity - College Grad',
#        'Physical Inactivity - Female',
#        'Physical Inactivity - Hawaiian/Pacific Islander',
#        'Physical Inactivity - High School Grad',
#        'Physical Inactivity - Hispanic',
#        'Physical Inactivity - Less Than $25,000',
#        'Physical Inactivity - Less Than High School',
#        'Physical Inactivity - Male', 'Physical Inactivity - Rural',
#        'Physical Inactivity - Some College',
#        'Physical Inactivity - Suburban', 'Physical Inactivity - Urban',
#        'Physical Inactivity - White', 'Policy', 'Poor Mental Health Days',
#        'Poor Mental Health Days - $25-$49,999',
#        'Poor Mental Health Days - $50-$74,999',
#        'Poor Mental Health Days - $75,000 or More',
#        'Poor Mental Health Days - Ages 18-44',
#        'Poor Mental Health Days - Ages 45-64',
#        'Poor Mental Health Days - Ages 65+',
#        'Poor Mental Health Days - American Indian/Alaska Native',
#        'Poor Mental Health Days - Asian',
#        'Poor Mental Health Days - Black',
#        'Poor Mental Health Days - College Grad',
#        'Poor Mental Health Days - Female',
#        'Poor Mental Health Days - Hawaiian/Pacific Islander',
#        'Poor Mental Health Days - High School Grad',
#        'Poor Mental Health Days - Hispanic',
#        'Poor Mental Health Days - Less Than $25,000',
#        'Poor Mental Health Days - Less Than High School',
#        'Poor Mental Health Days - Male',
#        'Poor Mental Health Days - Rural',
#        'Poor Mental Health Days - Some College',
#        'Poor Mental Health Days - Suburban',
#        'Poor Mental Health Days - Urban',
#        'Poor Mental Health Days - White', 'Poor Physical Health Days',
#        'Poor Physical Health Days - $25-$49,999',
#        'Poor Physical Health Days - $50-$74,999',
#        'Poor Physical Health Days - $75,000 or More',
#        'Poor Physical Health Days - Ages 18-44',
#        'Poor Physical Health Days - Ages 45-64',
#        'Poor Physical Health Days - Ages 65+',
#        'Poor Physical Health Days - American Indian/Alaska Native',
#        'Poor Physical Health Days - Asian',
#        'Poor Physical Health Days - Black',
#        'Poor Physical Health Days - College Grad',
#        'Poor Physical Health Days - Female',
#        'Poor Physical Health Days - Hawaiian/Pacific Islander',
#        'Poor Physical Health Days - High School Grad',
#        'Poor Physical Health Days - Hispanic',
#        'Poor Physical Health Days - Less Than $25,000',
#        'Poor Physical Health Days - Less Than High School',
#        'Poor Physical Health Days - Male',
#        'Poor Physical Health Days - Rural',
#        'Poor Physical Health Days - Some College',
#        'Poor Physical Health Days - Suburban',
#        'Poor Physical Health Days - Urban',
#        'Poor Physical Health Days - White', 'Premature Death',
#        'Premature Death - American Indian/Alaska Native',
#        'Premature Death - Asian/Pacific Islander',
#        'Premature Death - Black', 'Premature Death - Hispanic',
#        'Premature Death - White', 'Premature Death Racial Inequality',
#        'Preterm Birth', 'Preventable Hospitalizations',
#        'Preventable Hospitalizations - American Indian or Alaska Native',
#        'Preventable Hospitalizations - Asian/Pacific Islander',
#        'Preventable Hospitalizations - Black',
#        'Preventable Hospitalizations - Female',
#        'Preventable Hospitalizations - Hispanic',
#        'Preventable Hospitalizations - Male',
#        'Preventable Hospitalizations - Other Race',
#        'Preventable Hospitalizations - White', 'Primary Care Physicians',
#        'Public Health Funding', 'Residential Segregation', 'Salmonella',
#        'Seat Belt Use', 'Seat Belt Use - $25-$49,999',
#        'Seat Belt Use - $50-$74,999', 'Seat Belt Use - $75,000 or More',
#        'Seat Belt Use - Ages 18 to 44', 'Seat Belt Use - Ages 45 to 64',
#        'Seat Belt Use - Ages 65+', 'Seat Belt Use - Am. Indian',
#        'Seat Belt Use - Asian', 'Seat Belt Use - Black',
#        'Seat Belt Use - College Grad', 'Seat Belt Use - Female',
#        'Seat Belt Use - Hawaiian PI', 'Seat Belt Use - High School Grad',
#        'Seat Belt Use - Hispanic', 'Seat Belt Use - Less Than $25,000',
#        'Seat Belt Use - Less Than High School', 'Seat Belt Use - Male',
#        'Seat Belt Use - Rural', 'Seat Belt Use - Some College',
#        'Seat Belt Use - Suburban', 'Seat Belt Use - Urban',
#        'Seat Belt Use - White', 'Severe Housing Problems',
#        'Severe Housing Problems - American Indian/Alaska Native',
#        'Severe Housing Problems - Asian/Pacific Islander',
#        'Severe Housing Problems - Black',
#        'Severe Housing Problems - Hispanic',
#        'Severe Housing Problems - White', 'Smoking',
#        'Smoking - $25-$49,999', 'Smoking - $50-$74,999',
#        'Smoking - $75,000 or More', 'Smoking - Ages 18-44',
#        'Smoking - Ages 45-64', 'Smoking - Ages 65+',
#        'Smoking - American Indian/Alaska Native', 'Smoking - Asian',
#        'Smoking - Black', 'Smoking - College Grad', 'Smoking - Female',
#        'Smoking - Hawaiian/Pacific Islander',
#        'Smoking - High School Grad', 'Smoking - Hispanic',
#        'Smoking - Less Than $25,000', 'Smoking - Less Than High School',
#        'Smoking - Male', 'Smoking - Rural', 'Smoking - Some College',
#        'Smoking - Suburban', 'Smoking - Urban', 'Smoking - White',
#        'Smoking Rate of Change',
#        'Smoking Rate of Change-College Graduate',
#        'Smoking Rate of Change-High School Graduate',
#        'Smoking Rate of Change-Less Than High School',
#        'Smoking Rate of Change-Some College', 'Stroke',
#        'Stroke - $25-$49,999', 'Stroke - $50-$74,999',
#        'Stroke - $75,000 or More', 'Stroke - Ages 18-44',
#        'Stroke - Ages 45-64', 'Stroke - Ages 65+',
#        'Stroke - American Indian/Alaska Native', 'Stroke - Asian',
#        'Stroke - Black', 'Stroke - College Grad', 'Stroke - Female',
#        'Stroke - Hawaiian/Pacific Islander', 'Stroke - High School Grad',
#        'Stroke - Hispanic', 'Stroke - Less Than $25,000',
#        'Stroke - Less Than High School', 'Stroke - Male',
#        'Stroke - Rural', 'Stroke - Some College', 'Stroke - Suburban',
#        'Stroke - Urban', 'Stroke - White', 'Suicide',
#        'Suicide - Ages 15-24', 'Suicide - Ages 25-34',
#        'Suicide - Ages 35-44', 'Suicide - Ages 45-54',
#        'Suicide - Ages 55-64', 'Suicide - Ages 65-74',
#        'Suicide - Ages 75-84', 'Suicide - Ages 85+',
#        'Suicide - American Indian/Alaska Native', 'Suicide - Asian',
#        'Suicide - Black', 'Suicide - Female', 'Suicide - Hispanic',
#        'Suicide - Male', 'Suicide - White', 'Tdap Immunizations',
#        'Teen Births', 'Teen Births - American Indian or Alaska Native',
#        'Teen Births - Asian or Pacific Islander',
#        'Teen Births - Black/African American', 'Teen Births - Hispanic',
#        'Teen Births - White', 'Underemployment Rate',
#        'Unemployment Rate, Annual', 'Uninsured', 'Vegetables',
#        'Violent Crime', 'Voter Participation (Midterm)',
#        'Voter Participation (Midterm) - Asian',
#        'Voter Participation (Midterm) - Black',
#        'Voter Participation (Midterm) - Hispanic',
#        'Voter Participation (Midterm) - White',
#        'Voter Participation (Presidential)',
#        'Voter Participation (Presidential) - Asian',
#        'Voter Participation (Presidential) - Black',
#        'Voter Participation (Presidential) - Hispanic',
#        'Voter Participation (Presidential) - White', 'Voter Registration',
#        'Voter Registration - Ages 18-24 ',
#        'Voter Registration - Ages 25-34',
#        'Voter Registration - Ages 35-44',
#        'Voter Registration - Ages 45-64', 'Voter Registration - Ages 65+',
#        'Voter Registration - Asian', 'Voter Registration - Black',
#        'Voter Registration - Female', 'Voter Registration - Hispanic',
#        'Voter Registration - Male', 'Voter Registration - White',
#        'Water Fluoridation'], dtype=object)

# %%
clean2009 = data2009.loc[(data2009['Measure Name'] == 'Overall') | (data2009['Measure Name'] == 'All Determinants') | (data2009['Measure Name'] == 'Primary Care Physicians') | (data2009['Measure Name'] == 'Health Status - Female')]
clean2009 = clean2009.replace(to_replace='Health Status - Female', value='High Health Status - Female')
clean2009 = clean2009[['Edition','Measure Name','State Name','Rank','Value']]
clean2009 = clean2009.rename(columns={'Edition':'Year'})
clean2009.head()
# Out:
#     Year      Measure Name  State Name  Rank  Value
# 52  2009  All Determinants      Alaska  34.0 -0.121
# 53  2009  All Determinants     Arizona  27.0 -0.037
# 54  2009  All Determinants    Arkansas  41.0 -0.264
# 55  2009  All Determinants  California  24.0  0.134
# 56  2009  All Determinants     Alabama  43.0 -0.306

# %%
clean2010 = data2010.loc[(data2010['Measure Name'] == 'Overall') | (data2010['Measure Name'] == 'All Determinants') | (data2010['Measure Name'] == 'Primary Care Physicians') | (data2010['Measure Name'] == 'Health Status - Female')]
clean2010 = clean2010.replace(to_replace='Health Status - Female', value='High Health Status - Female')
clean2010 = clean2010[['Edition','Measure Name','State Name','Rank','Value']]
clean2010 = clean2010.rename(columns={'Edition':'Year'})
clean2010.head()
# Out:
#     Year      Measure Name      State Name  Rank  Value
# 52  2010  All Determinants      New Mexico  34.0 -0.108
# 53  2010  All Determinants        New York  26.0  0.042
# 54  2010  All Determinants  North Carolina  35.0 -0.123
# 55  2010  All Determinants    North Dakota  11.0  0.365
# 56  2010  All Determinants            Ohio  30.0 -0.039

# %%
clean2011 = data2011.loc[(data2011['Measure Name'] == 'Overall') | (data2011['Measure Name'] == 'All Determinants') | (data2011['Measure Name'] == 'Primary Care Physicians') | (data2011['Measure Name'] == 'Health Status - Female')]
clean2011 = clean2011.replace(to_replace='Health Status - Female', value='High Health Status - Female')
clean2011 = clean2011[['Edition','Measure Name','State Name','Rank','Value']]
clean2011 = clean2011.rename(columns={'Edition':'Year'})
clean2011
# Out:
#        Year             Measure Name     State Name  Rank    Value
# 52     2011         All Determinants          Texas  49.0   -0.539
# 53     2011         All Determinants           Ohio  36.0   -0.190
# 54     2011         All Determinants        Vermont   1.0    0.904
# 55     2011         All Determinants  New Hampshire   3.0    0.723
# 56     2011         All Determinants   Rhode Island   9.0    0.397
# ...     ...                      ...            ...   ...      ...
# 10499  2011  Primary Care Physicians        Arizona  44.0   92.600
# 10500  2011  Primary Care Physicians        Indiana  36.0  102.500
# 10501  2011  Primary Care Physicians     California  22.0  119.000
# 10502  2011  Primary Care Physicians       Arkansas  41.0   99.500
# 10503  2011  Primary Care Physicians           Iowa  47.0   84.200
#
# [208 rows x 5 columns]

# %%
clean2012 = data2012.loc[(data2012['Measure Name'] == 'Overall') | (data2012['Measure Name'] == 'All Determinants') | (data2012['Measure Name'] == 'Primary Care Physicians') | (data2012['Measure Name'] == 'High Health Status - Female')]
clean2012 = clean2012[['Edition','Measure Name','State Name','Rank','Value']]
clean2012 = clean2012.rename(columns={'Edition':'Year'})
clean2012.head()
# Out:
#     Year      Measure Name     State Name  Rank  Value
# 52  2012  All Determinants         Alaska  26.0  0.068
# 53  2012  All Determinants        Alabama  44.0 -0.389
# 54  2012  All Determinants  United States   NaN    NaN
# 55  2012  All Determinants       Arkansas  48.0 -0.586
# 56  2012  All Determinants        Arizona  29.0  0.006

# %%
clean2013 = data2013.loc[(data2013['Measure Name'] == 'Overall') | (data2013['Measure Name'] == 'All Determinants') | (data2013['Measure Name'] == 'Primary Care Physicians') | (data2013['Measure Name'] == 'High Health Status - Female')]
clean2013 = clean2013[['Edition','Measure Name','State Name','Rank','Value']]
clean2013 = clean2013.rename(columns={'Edition':'Year'})
clean2013.head()
# Out:
#     Year      Measure Name     State Name  Rank  Value
# 52  2013  All Determinants         Alaska  26.0  0.053
# 53  2013  All Determinants        Alabama  46.0 -0.449
# 54  2013  All Determinants  United States   NaN    NaN
# 55  2013  All Determinants       Arkansas  50.0 -0.627
# 56  2013  All Determinants        Arizona  29.0  0.002

# %%
clean2014 = data2014.loc[(data2014['Measure Name'] == 'Overall') | (data2014['Measure Name'] == 'All Determinants') | (data2014['Measure Name'] == 'Primary Care Physicians') | (data2014['Measure Name'] == 'High Health Status - Female')]
clean2014 = clean2014[['Edition','Measure Name','State Name','Rank','Value']]
clean2014 = clean2014.rename(columns={'Edition':'Year'})
clean2014.head()
# Out:
#     Year      Measure Name     State Name Rank  Value
# 52  2014  All Determinants         Alaska   29 -0.058
# 53  2014  All Determinants        Alabama   41 -0.335
# 54  2014  All Determinants  United States  NaN    NaN
# 55  2014  All Determinants       Arkansas   49 -0.655
# 56  2014  All Determinants        Arizona   28 -0.008

# %%
clean2015 = data2015.loc[(data2015['Measure Name'] == 'Overall') | (data2015['Measure Name'] == 'All Determinants') | (data2015['Measure Name'] == 'Primary Care Physicians') | (data2015['Measure Name'] == 'High Health Status - Female')]
clean2015 = clean2015[['Edition','Measure Name','State Name','Rank','Value']]
clean2015 = clean2015.rename(columns={'Edition':'Year'})
clean2015.head()
# Out:
#     Year      Measure Name     State Name  Rank  Value
# 52  2015  All Determinants         Alaska  30.0 -0.114
# 53  2015  All Determinants        Alabama  43.0 -0.371
# 54  2015  All Determinants  United States   NaN    NaN
# 55  2015  All Determinants       Arkansas  48.0 -0.584
# 56  2015  All Determinants        Arizona  32.0 -0.141

# %%
clean2016 = data2016.loc[(data2016['Measure Name'] == 'Overall') | (data2016['Measure Name'] == 'All Determinants') | (data2016['Measure Name'] == 'Primary Care Physicians') | (data2016['Measure Name'] == 'High Health Status - Female')]
clean2016 = clean2016[['Edition','Measure Name','State Name','Rank','Value']]
clean2016 = clean2016.rename(columns={'Edition':'Year'})
clean2016.head()
# Out:
#     Year      Measure Name  State Name  Rank  Value
# 52  2016  All Determinants      Alaska  33.0 -0.139
# 53  2016  All Determinants     Alabama  46.0 -0.427
# 54  2016  All Determinants    Arkansas  48.0 -0.506
# 55  2016  All Determinants     Arizona  30.0 -0.062
# 56  2016  All Determinants  California  16.0  0.277

# %%
clean2017 = data2017.loc[(data2017['Measure Name'] == 'Overall') | (data2017['Measure Name'] == 'All Determinants') | (data2017['Measure Name'] == 'Primary Care Physicians') | (data2017['Measure Name'] == 'High Health Status - Female')]
clean2017 = clean2017[['Edition','Measure Name','State Name','Rank','Value']]
clean2017 = clean2017.rename(columns={'Edition':'Year'})
clean2017.head()
# Out:
#     Year      Measure Name  State Name  Rank  Value
# 52  2017  All Determinants      Alaska  34.0 -0.190
# 53  2017  All Determinants     Alabama  47.0 -0.427
# 54  2017  All Determinants    Arkansas  48.0 -0.449
# 55  2017  All Determinants     Arizona  33.0 -0.157
# 56  2017  All Determinants  California  18.0  0.245

# %%
clean2018 = data2018.loc[(data2018['Measure Name'] == 'Overall') | (data2018['Measure Name'] == 'All Determinants') | (data2018['Measure Name'] == 'Primary Care Physicians') | (data2018['Measure Name'] == 'High Health Status - Female')]
clean2018 = clean2018[['Edition','Measure Name','State Name','Rank','Value']]
clean2018 = clean2018.rename(columns={'Edition':'Year'})
clean2018.head()
# Out:
#      Year      Measure Name  State Name  Rank  Value
# 156  2018  All Determinants      Alaska  35.0 -0.227
# 157  2018  All Determinants     Alabama  48.0 -0.483
# 158  2018  All Determinants    Arkansas  45.0 -0.361
# 159  2018  All Determinants     Arizona  33.0 -0.168
# 160  2018  All Determinants  California  15.0  0.312

# %%
clean2019 = data2019.loc[(data2019['Measure Name'] == 'Overall') | (data2019['Measure Name'] == 'All Determinants') | (data2019['Measure Name'] == 'Primary Care Physicians') | (data2019['Measure Name'] == 'High Health Status - Female')]
clean2019 = clean2019[['Edition','Measure Name','State Name','Rank','Value']]
clean2019 = clean2019.rename(columns={'Edition':'Year'})
clean2019.head()
# Out:
#      Year      Measure Name  State Name  Rank  Value
# 104  2019  All Determinants      Alaska  29.0 -0.027
# 105  2019  All Determinants     Alabama  46.0 -0.437
# 106  2019  All Determinants    Arkansas  48.0 -0.478
# 107  2019  All Determinants     Arizona  34.0 -0.187
# 108  2019  All Determinants  California  16.0  0.272

# %%
cleanRankings = pd.concat([clean2009, clean2010, clean2011, clean2012, clean2013, clean2014, clean2015, clean2016, clean2017, clean2018, clean2019])
cleanRankings = cleanRankings.rename(columns={'index': 'id'})
cleanRankings = cleanRankings.rename(columns={'Year':'year','Measure Name':'measure_name','State Name':'state','Rank':'rank','Value':'value'})
cleanRankings.head()
# Out:
#     year      measure_name       state rank  value
# 52  2009  All Determinants      Alaska   34 -0.121
# 53  2009  All Determinants     Arizona   27 -0.037
# 54  2009  All Determinants    Arkansas   41 -0.264
# 55  2009  All Determinants  California   24  0.134
# 56  2009  All Determinants     Alabama   43 -0.306

# %%
cleanRankings.reset_index(drop=True, inplace=True)
cleanRankings.head()
# Out:
#    year      measure_name       state rank  value
# 0  2009  All Determinants      Alaska   34 -0.121
# 1  2009  All Determinants     Arizona   27 -0.037
# 2  2009  All Determinants    Arkansas   41 -0.264
# 3  2009  All Determinants  California   24  0.134
# 4  2009  All Determinants     Alabama   43 -0.306

# %%
cleanRankings.to_csv('../output_file/state_health_rankings.csv',index=False)
