# %% [markdown]
# ***
# # Machine Learning Linear Regression Model 3
# ### Time-Series Forecast of the Average-Annual of Maternal Mortality & Associated Impacts in USA (2009-2030)
# ***

# %% [markdown]
# ### Importing Dependencies

# %%
# Importing dependencies:
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read the CSV and Perform Basic Data Cleaning

# %%
# Reading the csv file into a pandas DataFrame
mmr_without_race = pd.read_csv('../Resources/non_race_data.csv')
mmr_without_race
# Out:
#      year      state     id state_code   latitude  longitude  deaths   births  \
# 0    2015    Alabama  US.AL         AL  32.318231 -86.902298    12.0  59657.0
# 1    2016    Alabama  US.AL         AL  32.318231 -86.902298    35.0  59151.0
# 2    2017    Alabama  US.AL         AL  32.318231 -86.902298    41.0  58941.0
# 3    2018    Alabama  US.AL         AL  32.318231 -86.902298    31.0  57761.0
# 4    2019    Alabama  US.AL         AL  32.318231 -86.902298    35.0  58615.0
# ..    ...        ...    ...        ...        ...        ...     ...      ...
# 303  2014  Wisconsin  US.WI         WI  43.784440 -88.787868    16.0  67161.0
# 304  2015  Wisconsin  US.WI         WI  43.784440 -88.787868    11.0  67041.0
# 305  2016  Wisconsin  US.WI         WI  43.784440 -88.787868    15.0  66615.0
# 306  2017  Wisconsin  US.WI         WI  43.784440 -88.787868    12.0  64975.0
# 307  2019  Wisconsin  US.WI         WI  43.784440 -88.787868    13.0  63270.0
#
# ...

# %%
mmr_without_race.columns
# Out:
# Index(['year', 'state', 'id', 'state_code', 'latitude', 'longitude', 'deaths',
#        'births', 'maternal_mortality_ratio', 'population', 'employer',
#        'non_group', 'medicaid', 'medicare', 'military', 'uninsured',
#        'air_pollution_val', 'cancer_death_val', 'cardio_death_val',
#        'child_pov_val', 'choles_check_val', 'dent_vis_val', 'dentists_val',
#        'diabetes_val', 'drug_deaths_val', 'health_stat_fem_val',
#        'immun_child_val', 'income_ineq_val', 'infant_mort_val',
#        'infect_dis_val', 'obesity_val', 'phys_inac_val', 'prem_death_val',
#        'smoking_val', 'uninsured_val', 'all_determs_val', 'all_outcomes_val',
#        'chlamydia_val', 'prem_death_ri_val', 'teen_birth_val',
#        'primary_care_val', 'low_birthweight_val'],
#       dtype='object')

# %% [markdown]
# ### Grouping DataFrame by `year` and Calculating the Average

# %%
# Setting y value for grouping
y = 'maternal_mortality_ratio'

# Grouping by year
AVG_MMR_USA = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA.reset_index()
# Out:
#     year  maternal_mortality_ratio
# 0   2009                 26.747083
# 1   2010                 25.715417
# 2   2011                 27.871481
# 3   2012                 29.929583
# 4   2013                 31.729333
# 5   2014                 32.339259
# 6   2015                 31.944074
# 7   2016                 35.440968
# 8   2017                 34.208889
# 9   2018                 31.526071
# 10  2019                 34.073333

# %%
# Setting y value for grouping
y = 'diabetes_val'

# Grouping by year
AVG_MMR_USA_1 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_1.reset_index()

# Merging with mmr_predictions 
df_1 = pd.merge(AVG_MMR_USA, AVG_MMR_USA_1, how='inner', left_on=['year'], right_on=['year'])
df_1.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val
# 0   2009                 26.747083      8.920833
# 1   2010                 25.715417      9.291667
# 2   2011                 27.871481      9.229630
# 3   2012                 29.929583     10.208333
# 4   2013                 31.729333     10.200000
# 5   2014                 32.339259     10.070370
# 6   2015                 31.944074     10.677778
# 7   2016                 35.440968     10.670968
# 8   2017                 34.208889     10.869444
# 9   2018                 31.526071     11.514286
# 10  2019                 34.073333     11.653333

# %%
# Setting y value for grouping
y = 'prem_death_val'

# Grouping by year
AVG_MMR_USA_2 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_2.reset_index()

# Merging with mmr_predictions 
df_2 = pd.merge(df_1, AVG_MMR_USA_2, how='inner', left_on=['year'], right_on=['year'])
df_2.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667

# %%
# Setting y value for grouping
y = 'phys_inac_val'

# Grouping by year
AVG_MMR_USA_3 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_3.reset_index()

# Merging with mmr_predictions 
df_3 = pd.merge(df_2, AVG_MMR_USA_3, how='inner', left_on=['year'], right_on=['year'])
df_3.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val
# 0       25.879167
# 1       25.350000
# 2       24.644444
# 3       27.183333
# 4       23.720000
# 5       26.818519
# 6       24.177778
# 7       27.041935
# ...

# %%
# Setting y value for grouping
y = 'low_birthweight_val'

# Grouping by year
AVG_MMR_USA_4 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_4.reset_index()

# Merging with mmr_predictions 
df_4 = pd.merge(df_3, AVG_MMR_USA_4, how='inner', left_on=['year'], right_on=['year'])
df_4.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val
# 0       25.879167             8.475000
# 1       25.350000             8.383333
# 2       24.644444             8.303704
# ...

# %%
# Setting y value for grouping
y = 'obesity_val'

# Grouping by year
AVG_MMR_USA_5 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_5.reset_index()

# Merging with mmr_predictions 
df_5 = pd.merge(df_4, AVG_MMR_USA_5, how='inner', left_on=['year'], right_on=['year'])
df_5.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val
# 0       25.879167             8.475000    27.845833
# 1       25.350000             8.383333    28.670833
# ...

# %%
# Setting y value for grouping
y = 'cardio_death_val'

# Grouping by year
AVG_MMR_USA_6 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_6.reset_index()

# Merging with mmr_predictions 
df_6 = pd.merge(df_5, AVG_MMR_USA_6, how='inner', left_on=['year'], right_on=['year'])
df_6.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'medicare'

# Grouping by year
AVG_MMR_USA_7 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_7.reset_index()

# Merging with mmr_predictions 
df_7 = pd.merge(df_6, AVG_MMR_USA_7, how='inner', left_on=['year'], right_on=['year'])
df_7.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'cancer_death_val'

# Grouping by year
AVG_MMR_USA_8 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_8.reset_index()

# Merging with mmr_predictions 
df_8 = pd.merge(df_7, AVG_MMR_USA_8, how='inner', left_on=['year'], right_on=['year'])
df_8.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'chlamydia_val'

# Grouping by year
AVG_MMR_USA_9 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_9.reset_index()

# Merging with mmr_predictions 
df_9 = pd.merge(df_8, AVG_MMR_USA_9, how='inner', left_on=['year'], right_on=['year'])
df_9.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'child_pov_val'

# Grouping by year
AVG_MMR_USA_10 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_10.reset_index()

# Merging with mmr_predictions 
df_10 = pd.merge(df_9, AVG_MMR_USA_10, how='inner', left_on=['year'], right_on=['year'])
df_10.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'smoking_val'

# Grouping by year
AVG_MMR_USA_11 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_11.reset_index()

# Merging with mmr_predictions 
df_11 = pd.merge(df_10, AVG_MMR_USA_11, how='inner', left_on=['year'], right_on=['year'])
df_11.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'infant_mort_val'

# Grouping by year
AVG_MMR_USA_12 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_12.reset_index()

# Merging with mmr_predictions 
df_12 = pd.merge(df_11, AVG_MMR_USA_12, how='inner', left_on=['year'], right_on=['year'])
df_12.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'income_ineq_val'

# Grouping by year
AVG_MMR_USA_13 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_13.reset_index()

# Merging with mmr_predictions 
df_13 = pd.merge(df_12, AVG_MMR_USA_13, how='inner', left_on=['year'], right_on=['year'])
df_13.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'dentists_val'

# Grouping by year
AVG_MMR_USA_14 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_14.reset_index()

# Merging with mmr_predictions 
df_14 = pd.merge(df_13, AVG_MMR_USA_14, how='inner', left_on=['year'], right_on=['year'])
df_14.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'prem_death_ri_val'

# Grouping by year
AVG_MMR_USA_15 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_15.reset_index()

# Merging with mmr_predictions 
df_15 = pd.merge(df_14, AVG_MMR_USA_15, how='inner', left_on=['year'], right_on=['year'])
df_15.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'dent_vis_val'

# Grouping by year
AVG_MMR_USA_16 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_16.reset_index()

# Merging with mmr_predictions 
df_16 = pd.merge(df_15, AVG_MMR_USA_16, how='inner', left_on=['year'], right_on=['year'])
df_16.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'all_outcomes_val'

# Grouping by year
AVG_MMR_USA_17 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_17.reset_index()

# Merging with mmr_predictions 
df_17 = pd.merge(df_16, AVG_MMR_USA_17, how='inner', left_on=['year'], right_on=['year'])
df_17.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'all_determs_val'

# Grouping by year
AVG_MMR_USA_18 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_18.reset_index()

# Merging with mmr_predictions 
df_18 = pd.merge(df_17, AVG_MMR_USA_18, how='inner', left_on=['year'], right_on=['year'])
df_18.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'health_stat_fem_val'

# Grouping by year
AVG_MMR_USA_19 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_19.reset_index()

# Merging with mmr_predictions 
df_19 = pd.merge(df_18, AVG_MMR_USA_19, how='inner', left_on=['year'], right_on=['year'])
df_19.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'population'

# Grouping by year
AVG_MMR_USA_20 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_20.reset_index()

# Merging with mmr_predictions 
df_20 = pd.merge(df_19, AVG_MMR_USA_20, how='inner', left_on=['year'], right_on=['year'])
df_20.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'employer'

# Grouping by year
AVG_MMR_USA_21 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_21.reset_index()

# Merging with mmr_predictions 
df_21 = pd.merge(df_20, AVG_MMR_USA_21, how='inner', left_on=['year'], right_on=['year'])
df_21.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'non_group'

# Grouping by year
AVG_MMR_USA_22 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_22.reset_index()

# Merging with mmr_predictions 
df_22 = pd.merge(df_21, AVG_MMR_USA_22, how='inner', left_on=['year'], right_on=['year'])
df_22.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'medicaid'

# Grouping by year
AVG_MMR_USA_23 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_23.reset_index()

# Merging with mmr_predictions 
df_23 = pd.merge(df_22, AVG_MMR_USA_23, how='inner', left_on=['year'], right_on=['year'])
df_23.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'military'

# Grouping by year
AVG_MMR_USA_24 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_24.reset_index()

# Merging with mmr_predictions 
df_24 = pd.merge(df_23, AVG_MMR_USA_24, how='inner', left_on=['year'], right_on=['year'])
df_24.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'uninsured'

# Grouping by year
AVG_MMR_USA_25 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_25.reset_index()

# Merging with mmr_predictions 
df_25 = pd.merge(df_24, AVG_MMR_USA_25, how='inner', left_on=['year'], right_on=['year'])
df_25.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'air_pollution_val'

# Grouping by year
AVG_MMR_USA_26 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_26.reset_index()

# Merging with mmr_predictions 
df_26 = pd.merge(df_25, AVG_MMR_USA_26, how='inner', left_on=['year'], right_on=['year'])
df_26.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'choles_check_val'

# Grouping by year
AVG_MMR_USA_27 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_27.reset_index()

# Merging with mmr_predictions 
df_27 = pd.merge(df_26, AVG_MMR_USA_27, how='inner', left_on=['year'], right_on=['year'])
df_27.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'drug_deaths_val'

# Grouping by year
AVG_MMR_USA_28 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_28.reset_index()

# Merging with mmr_predictions 
df_28 = pd.merge(df_27, AVG_MMR_USA_28, how='inner', left_on=['year'], right_on=['year'])
df_28.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'immun_child_val'

# Grouping by year
AVG_MMR_USA_29 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_29.reset_index()

# Merging with mmr_predictions 
df_29 = pd.merge(df_28, AVG_MMR_USA_29, how='inner', left_on=['year'], right_on=['year'])
df_29.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'infect_dis_val'

# Grouping by year
AVG_MMR_USA_30 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_30.reset_index()

# Merging with mmr_predictions 
df_30 = pd.merge(df_29, AVG_MMR_USA_30, how='inner', left_on=['year'], right_on=['year'])
df_30.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'uninsured_val'

# Grouping by year
AVG_MMR_USA_31 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_31.reset_index()

# Merging with mmr_predictions 
df_31 = pd.merge(df_30, AVG_MMR_USA_31, how='inner', left_on=['year'], right_on=['year'])
df_31.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'teen_birth_val'

# Grouping by year
AVG_MMR_USA_32 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_32.reset_index()

# Merging with mmr_predictions 
df_32 = pd.merge(df_31, AVG_MMR_USA_32, how='inner', left_on=['year'], right_on=['year'])
df_32.reset_index()
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
# Setting y value for grouping
y = 'primary_care_val'

# Grouping by year
AVG_MMR_USA_33 = mmr_without_race.groupby('year').mean()[y]
AVG_MMR_USA_33.reset_index()

# Merging with mmr_predictions 
df_33 = pd.merge(df_32, AVG_MMR_USA_33, how='inner', left_on=['year'], right_on=['year'])
Combined_AVG_df = df_33.reset_index()
Combined_AVG_df
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       25.879167             8.475000    27.845833        289.720833
# ...

# %%
Combined_AVG_df.count()
# Out:
# year                        11
# maternal_mortality_ratio    11
# diabetes_val                11
# prem_death_val              11
# phys_inac_val               11
# low_birthweight_val         11
# obesity_val                 11
# cardio_death_val            11
# medicare                    11
# cancer_death_val            11
# chlamydia_val               11
# child_pov_val               11
# smoking_val                 11
# infant_mort_val             11
# income_ineq_val             11
# dentists_val                11
# prem_death_ri_val           11
# dent_vis_val                11
# all_outcomes_val            11
# all_determs_val             11
# health_stat_fem_val         11
# population                  11
# employer                    11
# non_group                   11
# medicaid                    11
# military                    11
# uninsured                   11
# air_pollution_val           11
# choles_check_val            11
# drug_deaths_val             11
# ...

# %%
Combined_AVG_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      11 non-null     int64
#  1   maternal_mortality_ratio  11 non-null     float64
#  2   diabetes_val              11 non-null     float64
#  3   prem_death_val            11 non-null     float64
#  4   phys_inac_val             11 non-null     float64
#  5   low_birthweight_val       11 non-null     float64
#  6   obesity_val               11 non-null     float64
#  7   cardio_death_val          11 non-null     float64
#  8   medicare                  11 non-null     float64
#  9   cancer_death_val          11 non-null     float64
#  10  chlamydia_val             11 non-null     float64
#  11  child_pov_val             11 non-null     float64
#  12  smoking_val               11 non-null     float64
# ...

# %% [markdown]
# ### Saving Final DataFrame to CSV

# %%
# Saving merged dataframe into a csv file
Combined_AVG_df.to_csv("../Resources/combined_avg_2009_2019.csv", index=False, header=True, float_format='%.2f')

# %% [markdown]
# ***
# ### Performing Time-Series Forecast of Average Annual predictions of all other variables in USA (2020-2030)
# ***

# %% [markdown]
# #### Simple Time-Series Forecast of Average Annual Maternal Mortality in USA

# %%
# Importing ML linear regression dependency
from sklearn.linear_model import LinearRegression

# Selecting and assigning the X and y values
X1 = AVG_MMR_USA.reset_index().year.values.reshape(-1,1)
y1 = AVG_MMR_USA.reset_index()['maternal_mortality_ratio'].values

# Steps 1 & 2: Creating and Fitting our model to the data
reg_model = LinearRegression().fit(X1, y1)

# Obtaining the coefficient of determination (R2)
r_square = reg_model.score(X1, y1)

# Setting predictions dictionary to hold variables
predictions=[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values=reg_model.predict(np.array([i]).reshape(1, -1))
    predictions.append(y_values[0])

# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold mmmr values with 10 years predictions
mmr_predict_df = pd.DataFrame(list(zip(years, predictions)), 
               columns =['year', 'maternal_mortality_ratio']) 


# DataFrame with the future predictions
mmr_predict_df
# Out:
#     year  maternal_mortality_ratio
# 0   2020                 35.963605
# 1   2021                 36.782910
# 2   2022                 37.602216
# 3   2023                 38.421521
# 4   2024                 39.240827
# 5   2025                 40.060132
# 6   2026                 40.879438
# 7   2027                 41.698743
# 8   2028                 42.518049
# 9   2029                 43.337354
# 10  2030                 44.156659

# %%
# Selecting y value
y = 'diabetes_val'
# Grouping by year
AVG_MMR_USA_diabetes = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X2 = AVG_MMR_USA_diabetes.reset_index().year.values.reshape(-1,1)
y2 = AVG_MMR_USA_diabetes.reset_index()['diabetes_val'].values

# Creating and Fitting our model to the data
model2 = LinearRegression().fit(X2, y2)
r_sq_2 = model2.score(X2, y2)
# print(r_sq_2)

# Setting predictions dictionary to hold variables
diabetes=[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model2.predict(np.array([i]).reshape(1, -1))
    diabetes.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions2 = pd.DataFrame(list(zip(years, diabetes)), 
               columns =['year', 'diabetes_val']) 

# DataFrame with the future predictions
predictions2

# Merging with mmr_predictions 
combined1 = pd.merge(mmr_predict_df, predictions2, how='inner', left_on=['year'], right_on=['year'])
combined1
# Out:
#     year  maternal_mortality_ratio  diabetes_val
# 0   2020                 35.963605     11.875629
# 1   2021                 36.782910     12.138134
# 2   2022                 37.602216     12.400638
# 3   2023                 38.421521     12.663142
# 4   2024                 39.240827     12.925646
# 5   2025                 40.060132     13.188151
# 6   2026                 40.879438     13.450655
# 7   2027                 41.698743     13.713159
# 8   2028                 42.518049     13.975663
# 9   2029                 43.337354     14.238168
# 10  2030                 44.156659     14.500672

# %%
# Selecting y value
y = 'prem_death_val'
# Grouping by year
AVG_MMR_USA_prem = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X3 = AVG_MMR_USA_prem.reset_index().year.values.reshape(-1,1)
y3 = AVG_MMR_USA_prem.reset_index()['prem_death_val'].values

# Creating and Fitting our model to the data
model3 = LinearRegression().fit(X3, y3)
r_sq_3 = model3.score(X3, y3)
# print(r_sq_3)

# Setting predictions dictionary to hold variables
premature =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model3.predict(np.array([i]).reshape(1, -1))
    premature.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions3 = pd.DataFrame(list(zip(years, premature)), 
               columns =['year', 'prem_death_val']) 

# DataFrame with the future predictions
predictions3

# Merging with mmr_predictions 
combined2 = pd.merge(combined1, predictions3, how='inner', left_on=['year'], right_on=['year'])
combined2
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629

# %%
# Selecting y value
y = 'phys_inac_val'
# Grouping by year
AVG_MMR_USA_phys = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X4 = AVG_MMR_USA_phys.reset_index().year.values.reshape(-1,1)
y4 = AVG_MMR_USA_phys.reset_index()['phys_inac_val'].values

# Creating and Fitting our model to the data
model4 = LinearRegression().fit(X4, y4)
r_sq_4 = model4.score(X4, y4)
# print(r_sq_4)

# Setting predictions dictionary to hold variables
physical_inactivity =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model4.predict(np.array([i]).reshape(1, -1))
    physical_inactivity.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions4 = pd.DataFrame(list(zip(years, physical_inactivity)), 
               columns =['year', 'phys_inac_val']) 

# DataFrame with the future predictions
predictions4

# Merging with mmr_predictions 
combined3 = pd.merge(combined2, predictions4, how='inner', left_on=['year'], right_on=['year'])
combined3
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val
# 0       26.032977
# 1       26.092960
# 2       26.152944
# 3       26.212928
# 4       26.272911
# 5       26.332895
# 6       26.392878
# 7       26.452862
# ...

# %%
# Selecting y value
y = 'low_birthweight_val'
# Grouping by year
AVG_MMR_USA_lbw = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X5= AVG_MMR_USA_lbw.reset_index().year.values.reshape(-1,1)
y5 = AVG_MMR_USA_lbw.reset_index()['low_birthweight_val'].values

# Creating and Fitting our model to the data
model5 = LinearRegression().fit(X5, y5)
r_sq_5 = model5.score(X5, y5)
# print(r_sq_5)

# Setting predictions dictionary to hold variables
low_birthweight =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model5.predict(np.array([i]).reshape(1, -1))
    low_birthweight.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions5 = pd.DataFrame(list(zip(years, low_birthweight)), 
               columns =['year', 'low_birthweight_val']) 

# DataFrame with the future predictions
predictions5

# Merging with mmr_predictions 
combined4 = pd.merge(combined3, predictions5, how='inner', left_on=['year'], right_on=['year'])
combined4
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val
# 0       26.032977             8.419778
# 1       26.092960             8.427422
# 2       26.152944             8.435067
# ...

# %%
# Selecting y value
y = 'obesity_val'
# Grouping by year
AVG_MMR_USA_ob = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X6 = AVG_MMR_USA_ob.reset_index().year.values.reshape(-1,1)
y6 = AVG_MMR_USA_ob.reset_index()['obesity_val'].values

# Creating and Fitting our model to the data
model6 = LinearRegression().fit(X6, y6)
r_sq_6 = model6.score(X6, y6)
# print(r_sq_6)

# Setting predictions dictionary to hold variables
obesity_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model6.predict(np.array([i]).reshape(1, -1))
    obesity_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions6 = pd.DataFrame(list(zip(years, obesity_val)), 
               columns =['year', 'obesity_val']) 

# DataFrame with the future predictions
predictions6

# Merging with mmr_predictions 
combined5 = pd.merge(combined4, predictions6, how='inner', left_on=['year'], right_on=['year'])
combined5
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val
# 0       26.032977             8.419778    32.006807
# 1       26.092960             8.427422    32.406575
# ...

# %%
# Selecting y value
y = 'cardio_death_val'
# Grouping by year
AVG_MMR_USA_cd = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X7 = AVG_MMR_USA_cd.reset_index().year.values.reshape(-1,1)
y7 = AVG_MMR_USA_cd.reset_index()['cardio_death_val'].values

# Creating and Fitting our model to the data
model7 = LinearRegression().fit(X7, y7)
r_sq_7 = model7.score(X7, y7)
# print(r_sq_7)

# Setting predictions dictionary to hold variables
cardio_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model7.predict(np.array([i]).reshape(1, -1))
    cardio_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions7 = pd.DataFrame(list(zip(years, cardio_val)), 
               columns =['year', 'cardio_death_val']) 

# DataFrame with the future predictions
predictions7

# Merging with mmr_predictions 
combined6 = pd.merge(combined5, predictions7, how='inner', left_on=['year'], right_on=['year'])
combined6
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'medicare'
# Grouping by year
AVG_MMR_USA_med = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X8 = AVG_MMR_USA_med.reset_index().year.values.reshape(-1,1)
y8 = AVG_MMR_USA_med.reset_index()['medicare'].values

# Creating and Fitting our model to the data
model8 = LinearRegression().fit(X8, y8)
r_sq_8 = model8.score(X8, y8)
# print(r_sq_8)

# Setting predictions dictionary to hold variables
medicare =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model8.predict(np.array([i]).reshape(1, -1))
    medicare.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions8 = pd.DataFrame(list(zip(years, medicare)), 
               columns =['year', 'medicare']) 

# DataFrame with the future predictions
predictions8

# Merging with mmr_predictions 
combined7 = pd.merge(combined6, predictions8, how='inner', left_on=['year'], right_on=['year'])
combined7
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'cancer_death_val'
# Grouping by year
AVG_MMR_USA_cancer = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X9 = AVG_MMR_USA_cancer.reset_index().year.values.reshape(-1,1)
y9 = AVG_MMR_USA_cancer.reset_index()['cancer_death_val'].values

# Creating and Fitting our model to the data
model9 = LinearRegression().fit(X9, y9)
r_sq_9 = model9.score(X9, y9)
# print(r_sq_9)

# Setting predictions dictionary to hold variables
cancer_death_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model9.predict(np.array([i]).reshape(1, -1))
    cancer_death_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions9 = pd.DataFrame(list(zip(years, cancer_death_val)), 
               columns =['year', 'cancer_death_val']) 

# DataFrame with the future predictions
predictions9

# Merging with mmr_predictions 
combined8 = pd.merge(combined7, predictions9, how='inner', left_on=['year'], right_on=['year'])
combined8
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'chlamydia_val'
# Grouping by year
AVG_MMR_USA_chlamydia = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X10 = AVG_MMR_USA_chlamydia.reset_index().year.values.reshape(-1,1)
y10 = AVG_MMR_USA_chlamydia.reset_index()['chlamydia_val'].values

# Creating and Fitting our model to the data
model10 = LinearRegression().fit(X10, y10)
r_sq_10 = model10.score(X10, y10)
# print(r_sq_10)

# Setting predictions dictionary to hold variables
chlamydia_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model10.predict(np.array([i]).reshape(1, -1))
    chlamydia_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions10 = pd.DataFrame(list(zip(years, chlamydia_val)), 
               columns =['year', 'chlamydia_val']) 

# DataFrame with the future predictions
predictions10

# Merging with mmr_predictions 
combined9 = pd.merge(combined8, predictions10, how='inner', left_on=['year'], right_on=['year'])
combined9
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'child_pov_val'
# Grouping by year
AVG_MMR_USA_child = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X11 = AVG_MMR_USA_child.reset_index().year.values.reshape(-1,1)
y11 = AVG_MMR_USA_child.reset_index()['child_pov_val'].values

# Creating and Fitting our model to the data
model11 = LinearRegression().fit(X11, y11)
r_sq_11 = model11.score(X11, y11)
# print(r_sq_11)

# Setting predictions dictionary to hold variables
child_pov_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model11.predict(np.array([i]).reshape(1, -1))
    child_pov_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions11 = pd.DataFrame(list(zip(years, child_pov_val)), 
               columns =['year', 'child_pov_val']) 

# DataFrame with the future predictions
predictions11

# Merging with mmr_predictions 
combined10 = pd.merge(combined9, predictions11, how='inner', left_on=['year'], right_on=['year'])
combined10
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'smoking_val'
# Grouping by year
AVG_MMR_USA_smoking = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X12 = AVG_MMR_USA_smoking.reset_index().year.values.reshape(-1,1)
y12 = AVG_MMR_USA_smoking.reset_index()['smoking_val'].values

# Creating and Fitting our model to the data
model12 = LinearRegression().fit(X12, y12)
r_sq_12 = model12.score(X12, y12)
# print(r_sq_12)

# Setting predictions dictionary to hold variables
smoking_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model12.predict(np.array([i]).reshape(1, -1))
    smoking_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions12 = pd.DataFrame(list(zip(years, smoking_val)), 
               columns =['year', 'smoking_val']) 

# DataFrame with the future predictions
predictions12

# Merging with mmr_predictions 
combined11 = pd.merge(combined10, predictions12, how='inner', left_on=['year'], right_on=['year'])
combined11
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'infant_mort_val'
# Grouping by year
AVG_MMR_USA_infant = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X13 = AVG_MMR_USA_infant.reset_index().year.values.reshape(-1,1)
y13 = AVG_MMR_USA_infant.reset_index()['infant_mort_val'].values

# Creating and Fitting our model to the data
model13 = LinearRegression().fit(X13, y13)
r_sq_13 = model13.score(X13, y13)
# print(r_sq_13)

# Setting predictions dictionary to hold variables
infant_mort_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model13.predict(np.array([i]).reshape(1, -1))
    infant_mort_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions13 = pd.DataFrame(list(zip(years, infant_mort_val)), 
               columns =['year', 'infant_mort_val']) 

# DataFrame with the future predictions
predictions13

# Merging with mmr_predictions 
combined12 = pd.merge(combined11, predictions13, how='inner', left_on=['year'], right_on=['year'])
combined12
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'income_ineq_val'
# Grouping by year
AVG_MMR_USA_income = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X14 = AVG_MMR_USA_income.reset_index().year.values.reshape(-1,1)
y14 = AVG_MMR_USA_income.reset_index()['income_ineq_val'].values

# Creating and Fitting our model to the data
model14 = LinearRegression().fit(X14, y14)
r_sq_14 = model14.score(X14, y14)
# print(r_sq_14)

# Setting predictions dictionary to hold variables
income_ineq_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model14.predict(np.array([i]).reshape(1, -1))
    income_ineq_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions14 = pd.DataFrame(list(zip(years, income_ineq_val)), 
               columns =['year', 'income_ineq_val']) 

# DataFrame with the future predictions
predictions14

# Merging with mmr_predictions 
combined13 = pd.merge(combined12, predictions14, how='inner', left_on=['year'], right_on=['year'])
combined13
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'dentists_val'
# Grouping by year
AVG_MMR_USA_dentist = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X15 = AVG_MMR_USA_dentist.reset_index().year.values.reshape(-1,1)
y15 = AVG_MMR_USA_dentist.reset_index()['dentists_val'].values

# Creating and Fitting our model to the data
model15 = LinearRegression().fit(X15, y15)
r_sq_15 = model15.score(X15, y15)
# print(r_sq_15)

# Setting predictions dictionary to hold variables
dentists_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model15.predict(np.array([i]).reshape(1, -1))
    dentists_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions15 = pd.DataFrame(list(zip(years, dentists_val)), 
               columns =['year', 'dentists_val']) 

# DataFrame with the future predictions
predictions15

# Merging with mmr_predictions 
combined14 = pd.merge(combined13, predictions15, how='inner', left_on=['year'], right_on=['year'])
combined14
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'prem_death_ri_val'
# Grouping by year
AVG_MMR_USA_prem = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X16 = AVG_MMR_USA_prem.reset_index().year.values.reshape(-1,1)
y16 = AVG_MMR_USA_prem.reset_index()['prem_death_ri_val'].values

# Creating and Fitting our model to the data
model16 = LinearRegression().fit(X16, y16)
r_sq_16 = model16.score(X16, y16)
# print(r_sq_16)

# Setting predictions dictionary to hold variables
prem_death_ri_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model16.predict(np.array([i]).reshape(1, -1))
    prem_death_ri_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions16 = pd.DataFrame(list(zip(years, prem_death_ri_val)), 
               columns =['year', 'prem_death_ri_val']) 

# DataFrame with the future predictions
predictions16

# Merging with mmr_predictions 
combined15 = pd.merge(combined14, predictions16, how='inner', left_on=['year'], right_on=['year'])
combined15
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'dent_vis_val'
# Grouping by year
AVG_MMR_USA_dent = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X17 = AVG_MMR_USA_dent.reset_index().year.values.reshape(-1,1)
y17 = AVG_MMR_USA_dent.reset_index()['dent_vis_val'].values

# Creating and Fitting our model to the data
model17 = LinearRegression().fit(X17, y17)
r_sq_17 = model17.score(X17, y17)
# print(r_sq_17)

# Setting predictions dictionary to hold variables
dent_vis_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model17.predict(np.array([i]).reshape(1, -1))
    dent_vis_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions17 = pd.DataFrame(list(zip(years, dent_vis_val)), 
               columns =['year', 'dent_vis_val']) 

# DataFrame with the future predictions
predictions17

# Merging with mmr_predictions 
combined16 = pd.merge(combined15, predictions17, how='inner', left_on=['year'], right_on=['year'])
combined16
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'all_outcomes_val'
# Grouping by year
AVG_MMR_USA_outcomes = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X18 = AVG_MMR_USA_outcomes.reset_index().year.values.reshape(-1,1)
y18 = AVG_MMR_USA_outcomes.reset_index()['all_outcomes_val'].values

# Creating and Fitting our model to the data
model18 = LinearRegression().fit(X18, y18)
r_sq_18 = model18.score(X18, y18)
# print(r_sq_18)

# Setting predictions dictionary to hold variables
all_outcomes_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model18.predict(np.array([i]).reshape(1, -1))
    all_outcomes_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions18 = pd.DataFrame(list(zip(years, all_outcomes_val)), 
               columns =['year', 'all_outcomes_val']) 

# DataFrame with the future predictions
predictions18

# Merging with mmr_predictions 
combined17 = pd.merge(combined16, predictions18, how='inner', left_on=['year'], right_on=['year'])
combined17
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'all_determs_val'
# Grouping by year
AVG_MMR_USA_determs = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X19 = AVG_MMR_USA_determs.reset_index().year.values.reshape(-1,1)
y19 = AVG_MMR_USA_determs.reset_index()['all_determs_val'].values

# Creating and Fitting our model to the data
model19 = LinearRegression().fit(X19, y19)
r_sq_19 = model19.score(X19, y19)
# print(r_sq_19)

# Setting predictions dictionary to hold variables
all_determs_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model19.predict(np.array([i]).reshape(1, -1))
    all_determs_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions19 = pd.DataFrame(list(zip(years, all_determs_val)), 
               columns =['year', 'all_determs_val']) 

# DataFrame with the future predictions
predictions19

# Merging with mmr_predictions 
combined18 = pd.merge(combined17, predictions19, how='inner', left_on=['year'], right_on=['year'])
combined18
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'health_stat_fem_val'
# Grouping by year
AVG_MMR_USA_health = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X20 = AVG_MMR_USA_health.reset_index().year.values.reshape(-1,1)
y20 = AVG_MMR_USA_health.reset_index()['health_stat_fem_val'].values

# Creating and Fitting our model to the data
model20 = LinearRegression().fit(X20, y20)
r_sq_20 = model20.score(X20, y20)
# print(r_sq_20)

# Setting predictions dictionary to hold variables
health_stat_fem_val =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model20.predict(np.array([i]).reshape(1, -1))
    health_stat_fem_val.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions20 = pd.DataFrame(list(zip(years, health_stat_fem_val)), 
               columns =['year', 'health_stat_fem_val']) 

# DataFrame with the future predictions
predictions20

# Merging with mmr_predictions 
combined19 = pd.merge(combined18, predictions20, how='inner', left_on=['year'], right_on=['year'])
combined19
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'population'
# Grouping by year
AVG_MMR_USA_population = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X21 = AVG_MMR_USA_population.reset_index().year.values.reshape(-1,1)
y21 = AVG_MMR_USA_population.reset_index()['population'].values

# Creating and Fitting our model to the data
model21 = LinearRegression().fit(X21, y21)
r_sq_21 = model21.score(X21, y21)
# print(r_sq_21)

# Setting predictions dictionary to hold variables
population =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model21.predict(np.array([i]).reshape(1, -1))
    population.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions21 = pd.DataFrame(list(zip(years, population)), 
               columns =['year', 'population']) 

# DataFrame with the future predictions
predictions21

# Merging with mmr_predictions 
combined20 = pd.merge(combined19, predictions21, how='inner', left_on=['year'], right_on=['year'])
combined20
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'employer'
# Grouping by year
AVG_MMR_USA_employer = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X22 = AVG_MMR_USA_employer.reset_index().year.values.reshape(-1,1)
y22 = AVG_MMR_USA_employer.reset_index()['employer'].values

# Creating and Fitting our model to the data
model22 = LinearRegression().fit(X22, y22)
r_sq_22 = model22.score(X22, y22)
# print(r_sq_22)

# Setting predictions dictionary to hold variables
employer =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model22.predict(np.array([i]).reshape(1, -1))
    employer.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions22 = pd.DataFrame(list(zip(years, employer)), 
               columns =['year', 'employer']) 

# DataFrame with the future predictions
predictions22

# Merging with mmr_predictions 
combined21 = pd.merge(combined20, predictions22, how='inner', left_on=['year'], right_on=['year'])
combined21
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'non_group'
# Grouping by year
AVG_MMR_USA_non_group = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X23 = AVG_MMR_USA_non_group.reset_index().year.values.reshape(-1,1)
y23 = AVG_MMR_USA_non_group.reset_index()['non_group'].values

# Creating and Fitting our model to the data
model23 = LinearRegression().fit(X23, y23)
r_sq_23 = model22.score(X23, y23)
# print(r_sq_23)

# Setting predictions dictionary to hold variables
non_group =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model23.predict(np.array([i]).reshape(1, -1))
    non_group.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions23 = pd.DataFrame(list(zip(years, non_group)), 
               columns =['year', 'non_group']) 

# DataFrame with the future predictions
predictions23

# Merging with mmr_predictions 
combined22 = pd.merge(combined21, predictions23, how='inner', left_on=['year'], right_on=['year'])
combined22
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2020                 35.963605     11.875629     7870.161716
# 1   2021                 36.782910     12.138134     7889.917107
# 2   2022                 37.602216     12.400638     7909.672499
# 3   2023                 38.421521     12.663142     7929.427890
# 4   2024                 39.240827     12.925646     7949.183281
# 5   2025                 40.060132     13.188151     7968.938673
# 6   2026                 40.879438     13.450655     7988.694064
# 7   2027                 41.698743     13.713159     8008.449455
# 8   2028                 42.518049     13.975663     8028.204847
# 9   2029                 43.337354     14.238168     8047.960238
# 10  2030                 44.156659     14.500672     8067.715629
#
#     phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0       26.032977             8.419778    32.006807        260.587473
# ...

# %%
# Selecting y value
y = 'medicaid'
# Grouping by year
AVG_MMR_USA_medicaid = mmr_without_race.groupby('year').mean()[y]

# Selecting and assigning the X and y values
X23 = AVG_MMR_USA_medicaid.reset_index().year.values.reshape(-1,1)
y23 = AVG_MMR_USA_medicaid.reset_index()['medicaid'].values

# Creating and Fitting our model to the data
model23 = LinearRegression().fit(X23, y23)
r_sq_23 = model22.score(X23, y23)
# print(r_sq_23)

# Setting predictions dictionary to hold variables
medicaid =[]

# Creating a for-loop to return predictions from model
for i in range(2020,2031):
    y_values = model23.predict(np.array([i]).reshape(1, -1))
    medicaid.append(y_values[0])
    
# Creating a year range to hold years values with the future predictions
years = [i for i in range(2020,2031)] 

# Creating a new DataFrame to hold values with 10 years predictions
predictions23 = pd.DataFrame(list(zip(years, medicaid)), 
               columns =['year', 'non_group']) 

# DataFrame with the future predictions
predictions23

# Merging with mmr_predictions 
combined22 = pd.merge(combined21, predictions23, how='inner', left_on=['year'], right_on=['year'])
combined22

# %%
combined19.count()
# Out:
# year                        11
# maternal_mortality_ratio    11
# diabetes_val                11
# prem_death_val              11
# phys_inac_val               11
# low_birthweight_val         11
# obesity_val                 11
# cardio_death_val            11
# medicare                    11
# cancer_death_val            11
# chlamydia_val               11
# child_pov_val               11
# smoking_val                 11
# infant_mort_val             11
# income_ineq_val             11
# dentists_val                11
# prem_death_ri_val           11
# dent_vis_val                11
# all_outcomes_val            11
# all_determs_val             11
# health_stat_fem_val         11
# dtype: int64

# %% [markdown]
# ### Saving Final DataFrame to CSV

# %%
# Saving merged dataframe into a csv file
combined19.to_csv("../Resources/combined_avg_2020_2030.csv", index=False, header=True, float_format='%.2f')

# %% [markdown]
# ***
# ## Combining Both Annual Average Dataframes
# ***
# Using Pandas `concat()` function to concatenate the two dataframes along rows

# %%
# Combining the two annual average dataframes with pandas `concat()`
USA_Annual_AVG_df = pd.concat([Combined_AVG_df, combined19], ignore_index=True)
USA_Annual_AVG_df
# Out:
#     year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0   2009                 26.747083      8.920833     7845.041667
# 1   2010                 25.715417      9.291667     7816.875000
# 2   2011                 27.871481      9.229630     7603.666667
# 3   2012                 29.929583     10.208333     8014.041667
# 4   2013                 31.729333     10.200000     7635.300000
# 5   2014                 32.339259     10.070370     7233.481481
# 6   2015                 31.944074     10.677778     7530.666667
# 7   2016                 35.440968     10.670968     7582.193548
# 8   2017                 34.208889     10.869444     7658.861111
# 9   2018                 31.526071     11.514286     8270.428571
# 10  2019                 34.073333     11.653333     8077.366667
# 11  2020                 35.963605     11.875629     7870.161716
# 12  2021                 36.782910     12.138134     7889.917107
# ...

# %%
# Checking data types and columns
USA_Annual_AVG_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      22 non-null     int64
#  1   maternal_mortality_ratio  22 non-null     float64
#  2   diabetes_val              22 non-null     float64
#  3   prem_death_val            22 non-null     float64
#  4   phys_inac_val             22 non-null     float64
#  5   low_birthweight_val       22 non-null     float64
#  6   obesity_val               22 non-null     float64
#  7   cardio_death_val          22 non-null     float64
#  8   medicare                  22 non-null     float64
#  9   cancer_death_val          22 non-null     float64
#  10  chlamydia_val             22 non-null     float64
#  11  child_pov_val             22 non-null     float64
#  12  smoking_val               22 non-null     float64
# ...

# %% [markdown]
# ### Saving Final Combined Annual Averages DataFrame to CSV

# %%
# Saving concatenated dataframes into a csv file
USA_Annual_AVG_df.to_csv("../Resources/final_combined_avg_2009_2030.csv", index=False, header=True, float_format='%.2f')
