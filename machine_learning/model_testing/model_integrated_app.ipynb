# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /Users/abpuccini/opt/anaconda3/envs/finalproject/lib/python3.6/site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /Users/abpuccini/opt/anaconda3/envs/finalproject/lib/python3.6/site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /Users/abpuccini/opt/anaconda3/envs/finalproject/lib/python3.6/site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /Users/abpuccini/opt/anaconda3/envs/finalproject/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.17.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /Users/abpuccini/opt/anaconda3/envs/finalproject/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.5.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /Users/abpuccini/opt/anaconda3/envs/finalproject/lib/python3.6/site-packages (from scikit-learn->sklearn) (2.1.0)

# %%
from joblib import load
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../Resources/combined_avg_2009_2019.csv")

print(data.columns, len(data.columns))
# Out:
# Index(['year', 'maternal_mortality_ratio', 'diabetes_val', 'prem_death_val',
#        'phys_inac_val', 'low_birthweight_val', 'obesity_val',
#        'cardio_death_val', 'medicare', 'cancer_death_val', 'chlamydia_val',
#        'child_pov_val', 'smoking_val', 'infant_mort_val', 'income_ineq_val',
#        'dentists_val', 'prem_death_ri_val', 'dent_vis_val', 'all_outcomes_val',
#        'all_determs_val', 'health_stat_fem_val'],
#       dtype='object') 21

# %%
def forecast_graph(diabetes, prem_death, phys_inac, low_birthweight, obesity):

    # Samples
    data = pd.read_csv("../Resources/combined_avg_2009_2019.csv")
    stat_data = data.describe()
    stat_data = stat_data.loc['mean'][['population', 'employer',
       'non_group', 'medicaid', 'medicare', 'military', 'uninsured',
       'air_pollution_val', 'cancer_death_val', 'cardio_death_val',
       'child_pov_val', 'choles_check_val', 'dent_vis_val', 'dentists_val',
       'diabetes_val', 'drug_deaths_val', 'health_stat_fem_val',
       'immun_child_val', 'income_ineq_val', 'infant_mort_val',
       'infect_dis_val', 'obesity_val', 'phys_inac_val', 'prem_death_val',
       'smoking_val', 'uninsured_val', 'all_determs_val', 'all_outcomes_val',
       'chlamydia_val', 'prem_death_ri_val', 'teen_birth_val',
       'primary_care_val', 'low_birthweight_val']]

    health_data = stat_data.copy()
    health_data['diabetes_val'] = diabetes
    health_data['prem_death_val'] = prem_death
    health_data['phys_inac_val'] = phys_inac
    health_data['low_birthweight_val'] = low_birthweight
    health_data['obesity_val'] = obesity

    # input data to predict MMR
    inputValue = np.array(health_data).reshape(1, -1)

    # load the saved pipleine model
    pipeline = load("../models/LR_model1_Chahnaz.sav")

    # predict on the sample data
    predicted_mmr_list = pipeline.predict(inputValue)
    predicted_mmr = predicted_mmr_list[0][0]

    return predicted_mmr

# %%
data = pd.read_csv("../Resources/combined_avg_2009_2019.csv")

# %%
stat_data = data.describe()
stat_data = stat_data.loc['mean'][['population', 'employer',
       'non_group', 'medicaid', 'medicare', 'military', 'uninsured',
       'air_pollution_val', 'cancer_death_val', 'cardio_death_val',
       'child_pov_val', 'choles_check_val', 'dent_vis_val', 'dentists_val',
       'diabetes_val', 'drug_deaths_val', 'health_stat_fem_val',
       'immun_child_val', 'income_ineq_val', 'infant_mort_val',
       'infect_dis_val', 'obesity_val', 'phys_inac_val', 'prem_death_val',
       'smoking_val', 'uninsured_val', 'all_determs_val', 'all_outcomes_val',
       'chlamydia_val', 'prem_death_ri_val', 'teen_birth_val',
       'primary_care_val', 'low_birthweight_val']]

stat_data
# Out:
# population             4.890733e+06
# employer               5.973214e+01
# non_group              7.511688e+00
# medicaid               1.444968e+01
# medicare               2.226948e+00
# military               1.621753e+00
# uninsured              1.445519e+01
# air_pollution_val      9.537662e+00
# cancer_death_val       1.952091e+02
# cardio_death_val       2.681013e+02
# child_pov_val          2.000325e+01
# choles_check_val       7.856331e+01
# dent_vis_val           6.612662e+01
# dentists_val           5.677143e+01
# diabetes_val           1.036234e+01
# drug_deaths_val        1.466623e+01
# health_stat_fem_val    5.031753e+01
# immun_child_val        7.598224e+01
# income_ineq_val        4.757597e+00
# infant_mort_val        6.526948e+00
# infect_dis_val         4.528450e+00
# obesity_val            2.969286e+01
# phys_inac_val          2.561981e+01
# prem_death_val         7.746341e+03
# smoking_val            1.873701e+01
# uninsured_val          1.246883e+01
# all_determs_val       -5.562662e-02
# all_outcomes_val      -3.586039e-02
# chlamydia_val          4.552328e+02
# prem_death_ri_val      1.480844e+00
# teen_birth_val         3.109221e+01
# primary_care_val       1.301084e+02
# low_birthweight_val    8.368506e+00
# Name: mean, dtype: float64

# %%
pipeline = load("../../machine_learning/models/LR_model2_Chahnaz.sav")
# Out:
# /Users/abpuccini/opt/anaconda3/envs/finalproject/lib/python3.6/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator LinearRegression from version 0.23.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
health_data = stat_data.copy()
health_data['diabetes_val'] = input('diabetes')
health_data['prem_death_val'] = input('diabetes')
health_data['phys_inac_val'] = input('diabetes')
health_data['low_birthweight_val'] = input('diabetes')
health_data['obesity_val'] = input('diabetes')
# Out:
# diabetes1
# diabetes1
# diabetes1
# diabetes1
# diabetes1

# %%
inputValue = np.array(health_data).reshape(1, -1)

predicted_mmr = pipeline.predict(inputValue)

# %%
predicted_mmr
# 32.11739427
# Out:
# array([[-35.37210432]])

# %%
data = pd.read_csv(
        "../Resources/combined_avg_2009_2019.csv")
print(len(data.columns))
data.head()
# Out:
# 35
#    year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0  2009                     26.75          8.92         7845.04
# 1  2010                     25.72          9.29         7816.88
# 2  2011                     27.87          9.23         7603.67
# 3  2012                     29.93         10.21         8014.04
# 4  2013                     31.73         10.20         7635.30
#
#    phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0          25.88                 8.47        27.85            289.72
# 1          25.35                 8.38        28.67            280.81
# 2          24.64                 8.30        28.41            269.24
# 3          27.18                 8.52        28.70            271.80
# 4          23.72                 8.29        28.69            257.98
#
#    medicare  cancer_death_val  ...  military  uninsured  air_pollution_val  \
# 0      2.04            197.73  ...      1.55      17.66              11.89
# 1      2.06            195.58  ...      1.50      19.57              11.39
# 2      2.09            194.28  ...      1.60      18.74              10.50
# 3      2.22            196.87  ...      1.66      19.11              10.43
# 4      2.21            193.13  ...      1.75      18.50               9.92
#
#    choles_check_val  drug_deaths_val  immun_child_val  infect_dis_val  \
# 0             76.13            11.09            77.93           18.13
# 1             76.73            12.12            89.86           15.82
# 2             77.16            12.63            90.42            9.94
# 3             75.54            12.50            90.22           12.62
# 4             75.01            13.33            68.63            0.03
#
#    uninsured_val  teen_birth_val  primary_care_val
# 0          14.43           43.22            117.89
# 1          15.68           45.61            113.01
# 2          15.87           43.19            119.17
# 3          16.03           36.42            116.88
# 4          15.06           32.90            116.73
#
# [5 rows x 35 columns]

# %%
stat_data = data.describe()
stat_data = stat_data.loc['mean']

# %%
stat_data.index
# Out:
# Index(['year', 'maternal_mortality_ratio', 'diabetes_val', 'prem_death_val',
#        'phys_inac_val', 'low_birthweight_val', 'obesity_val',
#        'cardio_death_val', 'medicare', 'cancer_death_val', 'chlamydia_val',
#        'child_pov_val', 'smoking_val', 'infant_mort_val', 'income_ineq_val',
#        'dentists_val', 'prem_death_ri_val', 'dent_vis_val', 'all_outcomes_val',
#        'all_determs_val', 'health_stat_fem_val', 'population', 'employer',
#        'non_group', 'medicaid', 'military', 'uninsured', 'air_pollution_val',
#        'choles_check_val', 'drug_deaths_val', 'immun_child_val',
#        'infect_dis_val', 'uninsured_val', 'teen_birth_val',
#        'primary_care_val'],
#       dtype='object')

# %%
data_predict = pd.read_csv('../Resources/combined_avg_2020_2030.csv')
data_predict.head()
# Out:
#    year  maternal_mortality_ratio  diabetes_val  prem_death_val  \
# 0  2020                     35.96         11.88         7870.16
# 1  2021                     36.78         12.14         7889.92
# 2  2022                     37.60         12.40         7909.67
# 3  2023                     38.42         12.66         7929.43
# 4  2024                     39.24         12.93         7949.18
#
#    phys_inac_val  low_birthweight_val  obesity_val  cardio_death_val  \
# 0          26.03                 8.42        32.01            260.59
# 1          26.09                 8.43        32.41            259.22
# 2          26.15                 8.44        32.81            257.85
# 3          26.21                 8.44        33.21            256.48
# 4          26.27                 8.45        33.61            255.11
#
#    medicare  cancer_death_val  ...  military  uninsured  air_pollution_val  \
# 0      2.40            195.33  ...      1.66       8.45               7.29
# 1      2.43            195.33  ...      1.66       7.39               6.90
# 2      2.46            195.34  ...      1.67       6.34               6.50
# 3      2.49            195.34  ...      1.68       5.28               6.11
# 4      2.52            195.35  ...      1.68       4.23               5.71
#
#    choles_check_val  drug_deaths_val  immun_child_val  infect_dis_val  \
# 0             83.91            19.25            65.40           -6.20
# 1             84.82            20.04            63.53           -8.09
# 2             85.73            20.84            61.66           -9.99
# 3             86.64            21.63            59.79          -11.88
# 4             87.55            22.42            57.92          -13.77
#
#    uninsured_val  teen_birth_val  primary_care_val
# 0           7.66           15.78            153.95
# 1           6.81           13.10            158.13
# 2           5.96           10.42            162.31
# 3           5.12            7.75            166.49
# 4           4.27            5.07            170.67
#
# [5 rows x 35 columns]

# %%
model = load("../../machine_learning/models/LR_model1_Chahnaz.sav")
# Out:
# /Users/abpuccini/opt/anaconda3/envs/project3/lib/python3.6/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator LinearRegression from version 0.23.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
mmr_without_race = data_predict.copy()[['maternal_mortality_ratio', 'population', 'employer',
       'non_group', 'medicaid', 'medicare', 'military', 'uninsured',
       'air_pollution_val', 'cancer_death_val', 'cardio_death_val',
       'child_pov_val', 'choles_check_val', 'dent_vis_val', 'dentists_val',
       'diabetes_val', 'drug_deaths_val', 'health_stat_fem_val',
       'immun_child_val', 'income_ineq_val', 'infant_mort_val',
       'infect_dis_val', 'obesity_val', 'phys_inac_val', 'prem_death_val',
       'smoking_val', 'uninsured_val', 'all_determs_val', 'all_outcomes_val',
       'chlamydia_val', 'prem_death_ri_val', 'teen_birth_val',
       'primary_care_val', 'low_birthweight_val']]
mmr_without_race.head()
# Out:
#    maternal_mortality_ratio  population  employer  non_group  medicaid  \
# 0                     35.96  4753694.66     60.46       8.92     18.13
# 1                     36.78  4726357.38     60.59       9.17     18.78
# 2                     37.60  4699020.11     60.71       9.41     19.42
# 3                     38.42  4671682.84     60.84       9.66     20.07
# 4                     39.24  4644345.56     60.97       9.91     20.71
#
#    medicare  military  uninsured  air_pollution_val  cancer_death_val  ...  \
# 0      2.40      1.66       8.45               7.29            195.33  ...
# 1      2.43      1.66       7.39               6.90            195.33  ...
# 2      2.46      1.67       6.34               6.50            195.34  ...
# 3      2.49      1.68       5.28               6.11            195.34  ...
# 4      2.52      1.68       4.23               5.71            195.35  ...
#
#    prem_death_val  smoking_val  uninsured_val  all_determs_val  \
# 0         7870.16        17.27           7.66            -0.06
# 1         7889.92        17.01           6.81            -0.06
# 2         7909.67        16.75           5.96            -0.06
# 3         7929.43        16.49           5.12            -0.06
# 4         7949.18        16.23           4.27            -0.06
#
#    all_outcomes_val  chlamydia_val  prem_death_ri_val  teen_birth_val  \
# 0             -0.09         526.79               1.40           15.78
# 1             -0.10         539.22               1.39           13.10
# 2             -0.11         551.64               1.38           10.42
# 3             -0.12         564.06               1.36            7.75
# 4             -0.13         576.48               1.35            5.07
#
#    primary_care_val  low_birthweight_val
# 0            153.95                 8.42
# 1            158.13                 8.43
# 2            162.31                 8.44
# 3            166.49                 8.44
# 4            170.67                 8.45
#
# [5 rows x 34 columns]

# %%
# Selecting and assigning the X & y values
y = mmr_without_race['maternal_mortality_ratio'].values.reshape(-1,1)
X = mmr_without_race.drop(columns=['maternal_mortality_ratio'], axis=1)

# %%
prediction = model.predict(X)
prediction
# Out:
# array([[36.86073591],
#        [37.65220664],
#        [38.53091902],
#        [39.33864413],
#        [40.15759162],
#        [41.07313768],
#        [41.95947714],
#        [42.56637132],
#        [43.39326199],
#        [44.3191345 ],
#        [45.20094787]])

# %%
prediction_list = [round(item[0],2) for item in prediction]
year = [2019 + i for i in range(1,12)]
data_prediction_df = pd.DataFrame({'year': year, 'mmr_prediction': prediction_list})

data_prediction_df
# Out:
#     year  mmr_prediction
# 0   2020           36.86
# 1   2021           37.65
# 2   2022           38.53
# 3   2023           39.34
# 4   2024           40.16
# 5   2025           41.07
# 6   2026           41.96
# 7   2027           42.57
# 8   2028           43.39
# 9   2029           44.32
# 10  2030           45.20

# %%
actual_predict_df = data_prediction_df.merge(data_predict, on='year')
actual_predict_df
# Out:
#     year  mmr_prediction  maternal_mortality_ratio  diabetes_val  \
# 0   2020           36.86                     35.96         11.88
# 1   2021           37.65                     36.78         12.14
# 2   2022           38.53                     37.60         12.40
# 3   2023           39.34                     38.42         12.66
# 4   2024           40.16                     39.24         12.93
# 5   2025           41.07                     40.06         13.19
# 6   2026           41.96                     40.88         13.45
# 7   2027           42.57                     41.70         13.71
# 8   2028           43.39                     42.52         13.98
# 9   2029           44.32                     43.34         14.24
# 10  2030           45.20                     44.16         14.50
#
#     prem_death_val  phys_inac_val  low_birthweight_val  obesity_val  \
# 0          7870.16          26.03                 8.42        32.01
# 1          7889.92          26.09                 8.43        32.41
# 2          7909.67          26.15                 8.44        32.81
# 3          7929.43          26.21                 8.44        33.21
# 4          7949.18          26.27                 8.45        33.61
# 5          7968.94          26.33                 8.46        34.01
# 6          7988.69          26.39                 8.47        34.41
# 7          8008.45          26.45                 8.47        34.81
# 8          8028.20          26.51                 8.48        35.20
# 9          8047.96          26.57                 8.49        35.60
# 10         8067.72          26.63                 8.50        36.00
#
#     cardio_death_val  medicare  ...  military  uninsured  air_pollution_val  \
# 0             260.59      2.40  ...      1.66       8.45               7.29
# 1             259.22      2.43  ...      1.66       7.39               6.90
# 2             257.85      2.46  ...      1.67       6.34               6.50
# 3             256.48      2.49  ...      1.68       5.28               6.11
# 4             255.11      2.52  ...      1.68       4.23               5.71
# 5             253.74      2.55  ...      1.69       3.17               5.32
# 6             252.37      2.58  ...      1.69       2.12               4.92
# 7             251.00      2.61  ...      1.70       1.07               4.53
# 8             249.63      2.64  ...      1.71       0.01               4.14
# 9             248.26      2.67  ...      1.71      -1.04               3.74
# 10            246.89      2.70  ...      1.72      -2.10               3.35
#
#     choles_check_val  drug_deaths_val  immun_child_val  infect_dis_val  \
# 0              83.91            19.25            65.40           -6.20
# 1              84.82            20.04            63.53           -8.09
# 2              85.73            20.84            61.66           -9.99
# 3              86.64            21.63            59.79          -11.88
# 4              87.55            22.42            57.92          -13.77
# 5              88.46            23.22            56.05          -15.67
# 6              89.37            24.01            54.18          -17.56
# 7              90.28            24.81            52.31          -19.46
# 8              91.19            25.60            50.45          -21.35
# 9              92.10            26.39            48.58          -23.24
# 10             93.01            27.19            46.71          -25.14
#
#     uninsured_val  teen_birth_val  primary_care_val
# 0            7.66           15.78            153.95
# 1            6.81           13.10            158.13
# 2            5.96           10.42            162.31
# 3            5.12            7.75            166.49
# 4            4.27            5.07            170.67
# 5            3.43            2.39            174.85
# 6            2.58           -0.29            179.03
# 7            1.74           -2.97            183.21
# 8            0.89           -5.65            187.39
# 9            0.04           -8.33            191.58
# 10          -0.80          -11.00            195.76
#
# [11 rows x 36 columns]

# %%
actual_predict_df.to_csv('../Resources/predition_api_df.csv', index=False)
