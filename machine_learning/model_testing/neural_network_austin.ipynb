# %%
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from sklearn) (0.24.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (0.17.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\austi\appdata\roaming\python\python36\site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.5.0)

# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (0.17.0)

# %%
import pandas as pd

# %%
#X_values_raw = pd.read_csv("../../ETL/output_file/state_X_values_proj3.csv")

#X_values_raw

df = pd.read_csv("../Resources/non_race_data.csv")
df
# Out:
#      year      state     id state_code   latitude  longitude  deaths   births  \
# 0    2015    Alabama  US.AL         AL  32.318231 -86.902298    12.0  59657.0
# 1    2016    Alabama  US.AL         AL  32.318231 -86.902298    35.0  59151.0
# 2    2017    Alabama  US.AL         AL  32.318231 -86.902298    41.0  58941.0
# 3    2018    Alabama  US.AL         AL  32.318231 -86.902298    31.0  57761.0
# 4    2019    Alabama  US.AL         AL  32.318231 -86.902298    35.0  58615.0
# ..    ...        ...    ...        ...        ...        ...     ...      ...
# 303  2014  Wisconsin  US.WI         WI  43.784440 -88.787868    16.0  67161.0
# 304  2015  Wisconsin  US.WI         WI  43.784440 -88.787868    11.0  67041.0
# 305  2016  Wisconsin  US.WI         WI  43.784440 -88.787868    15.0  66615.0
# 306  2017  Wisconsin  US.WI         WI  43.784440 -88.787868    12.0  64975.0
# 307  2019  Wisconsin  US.WI         WI  43.784440 -88.787868    13.0  63270.0
#
#      maternal_mortality_ratio  population  ...  prem_death_val  smoking_val  \
# 0                       20.11   2505795.0  ...         10095.0         21.1
# 1                       59.17   2507714.0  ...         10097.0         21.4
# 2                       69.56   2514911.0  ...         10321.0         21.5
# 3                       53.67   2523756.0  ...         10720.0         20.9
# 4                       59.71   2533668.0  ...         10435.0         19.2
# ..                        ...         ...  ...             ...          ...
# 303                     23.82   2898057.0  ...          6207.0         18.7
# 304                     16.41   2903737.0  ...          6365.0         17.4
# 305                     22.52   2905282.0  ...          6324.0         17.3
# 306                     18.47   2912745.0  ...          6437.0         17.1
# 307                     20.55   2925225.0  ...          6800.0         16.4
#
#      uninsured_val  all_determs_val  all_outcomes_val  chlamydia_val  \
# 0             12.9           -0.371            -0.325          611.0
# 1             11.1           -0.427            -0.366          600.2
# 2              9.6           -0.427            -0.335          543.6
# 3              9.3           -0.483            -0.356          553.6
# 4              9.7           -0.437            -0.383          614.1
# ..             ...              ...               ...            ...
# 303            9.0            0.165             0.067          415.4
# 304            8.2            0.146             0.046          411.6
# 305            6.5            0.114             0.106          403.2
# 306            5.5            0.201             0.072          423.5
# 307            5.5            0.129             0.074          478.6
#
#      prem_death_ri_val  teen_birth_val  primary_care_val  low_birthweight_val
# 0                  1.2            34.3             103.5                 10.0
# 1                  1.1            32.0             116.4                 10.1
# 2                  1.2            30.1             119.3                 10.4
# 3                  1.1            28.4             122.8                 10.3
# 4                  1.2            27.0             122.8                 10.3
# ..                 ...             ...               ...                  ...
# 303                2.0            21.9             125.0                  7.1
# 304                1.9            19.6             125.3                  7.0
# 305                1.9            18.0             140.3                  7.3
# 306                1.9            16.2             145.2                  7.3
# 307                2.0            13.8             152.4                  7.7
#
# [308 rows x 42 columns]

# %%
X = df.drop(columns=["year", "state", "id", "state_code", "latitude", "longitude", "deaths", "births", "maternal_mortality_ratio", "population", "employer", "non_group", "medicaid", "medicare", "military", "uninsured"]).values
X
# Out:
# array([[  9.5, 211.6, 330.1, ...,  34.3, 103.5,  10. ],
#        [  9.1, 211.1, 332.9, ...,  32. , 116.4,  10.1],
#        [  8.9, 210.6, 339.6, ...,  30.1, 119.3,  10.4],
#        ...,
#        [  7.9, 191.6, 236.8, ...,  18. , 140.3,   7.3],
#        [  7.4, 191.7, 238.1, ...,  16.2, 145.2,   7.3],
#        [  6.8, 190.4, 242.6, ...,  13.8, 152.4,   7.7]])

# %%
y = df['maternal_mortality_ratio'].values
y
# Out:
# array([20.11, 59.17, 69.56, 53.67, 59.71, 19.43, 17.54, 28.92, 26.87,
#        27.62, 23.43, 29.58, 29.31, 29.73, 40.31, 50.24, 33.73, 25.83,
#        46.94, 39.65, 59.72, 41.15, 44.42, 37.31, 62.13, 38.29, 20.3 ,
#        16.07, 14.14, 16.08, 15.56, 17.5 , 17.08, 18.62, 19.08, 17.81,
#        15.9 , 18.46, 24.31, 15.02, 24.02, 27.96, 23.86, 37.55, 31.23,
#        32.07, 21.9 , 23.43, 30.03, 38.53, 28.18, 30.32, 22.22, 21.46,
#        24.37, 31.36, 25.46, 28.37, 36.25, 30.7 , 63.69, 79.42, 74.58,
#        56.14, 57.26, 49.14, 50.64, 43.11, 20.45, 17.55, 27.9 , 21.99,
#        17.21, 20.18, 25.3 , 18.13, 26.11, 15.19, 14.27, 18.46, 16.68,
#        51.37, 43.26, 42.12, 45.2 , 54.74, 60.17, 48.68, 28.17, 40.81,
#        27.72, 30.45, 31.23, 31.4 , 27.06, 38.62, 28.91, 27.38, 36.73,
#        30.47, 19.87, 34.12, 30.37, 52.3 , 32.88, 53.78, 39.57, 44.7 ,
#        74.37, 62.02, 68.01, 88.64, 67.19, 36.9 , 44.11, 23.98, 35.23,
#        32.83, 27.44, 20.85, 29.76, 21.73, 17.78, 34.9 , 23.92, 31.35,
#        25.24, 19.8 , 21.7 , 28.99, 41.04, 28.95, 25.64, 31.72, 25.36,
#        23.83, 35.3 , 21.54, 29.08, 31.51, 15.57, 19.  , 21.81, 15.91,
#        14.31, 20.07, 26.24, 14.85, 16.66, 32.63, 29.97, 45.16, 38.79,
#        33.65, 36.91, 32.12, 40.54, 60.05, 22.81, 15.63, 22.33, 45.07,
#        39.84, 45.12, 43.96, 36.14, 38.34, 32.76, 22.18, 30.76, 33.54,
#        28.06, 45.33, 34.54, 55.57, 53.24, 37.82, 41.89, 43.46, 34.58,
#        36.15, 43.97, 42.08, 28.21, 27.42, 26.52, 24.07, 26.58, 25.55,
#        26.97, 27.74, 20.46, 29.17, 34.76, 16.56,  8.17,  9.14,  8.35,
#        12.6 , 28.1 , 36.41, 31.46, 29.14, 21.02, 38.74, 39.35, 28.75,
#        25.38, 28.16, 21.59, 15.77, 29.44, 26.07, 30.69, 19.98, 34.95,
#        51.33, 37.57, 38.26, 28.44, 37.47, 24.37, 26.35, 38.03, 43.81,
#        34.14, 28.49, 22.15, 26.58, 27.5 , 26.63, 23.72, 16.06, 21.05,
#        24.84, 24.6 , 22.69, 29.41, 29.04, 21.37, 29.05, 37.94, 30.85,
#        33.11, 27.99, 29.93, 41.65, 34.4 , 48.83, 42.08, 28.23, 42.08,
#        12.16, 49.77, 35.  , 29.41, 35.5 , 30.94, 48.14, 33.44, 37.29,
#        31.59, 26.16, 34.71, 41.54, 43.37, 36.77, 38.9 , 38.44, 38.48,
#        24.83, 23.57, 31.4 , 23.46, 25.6 , 20.58, 29.9 , 10.47, 17.53,
#        13.59, 14.68, 17.42, 30.01, 45.87, 39.84, 23.04, 32.84, 13.44,
#        12.71, 16.1 , 19.44, 23.1 , 22.58, 12.36, 13.26, 27.41, 24.39,
#        36.52, 54.8 , 18.35, 17.52, 22.12, 18.  , 23.82, 16.41, 22.52,
#        18.47, 20.55])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

# %%
def baseline_model():
    model = Sequential()
    model.add(Dense(26, input_dim=26, kernel_initializer='normal', activation='relu'))
    model.add(Dense(6, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=100, verbose=False)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X_train_scaled, y_train, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# WARNING:tensorflow:From C:\Users\austi\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\keras\initializers.py:143: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Results: -1181.87 (270.98) MSE

# %%
def baseline_model():
    model = Sequential()
    model.add(Dense(26, input_dim=26, kernel_initializer='normal', activation='relu'))
    model.add(Dense(6, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=100, verbose=False)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X_train, y_train, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Results: -1179.10 (422.89) MSE

# %%
def baseline_model():
    model = Sequential()
    model.add(Dense(26, input_dim=26, kernel_initializer='normal', activation='relu'))
    model.add(Dense(6, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=100, verbose=False)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Results: -1088.69 (299.53) MSE

# %%
def baseline_model():
    model = Sequential()
    model.add(Dense(26, input_dim=26, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=100, verbose=False)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Results: -4535.56 (5335.58) MSE

# %%
def baseline_model():
    model = Sequential()
    model.add(Dense(26, input_dim=26, kernel_initializer='normal', activation='relu'))
    model.add(Dense(6, kernel_initializer='normal', activation='relu'))
    model.add(Dense(6, kernel_initializer='normal', activation='relu'))
    model.add(Dense(6, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=100, verbose=False)
kfold = KFold(n_splits=20)
results = cross_val_score(estimator, X, y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Results: -1142.25 (455.57) MSE

# %%
model = Sequential()
model.add(Dense(26, input_dim=26, kernel_initializer='normal', activation='relu'))
model.add(Dense(6, kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))
model.compile(loss='mean_squared_error', optimizer='adam')

model.fit(X,y,epochs=100, batch_size=100)

from ann_visualizer.visualize import ann_viz;

ann_viz(model, title="My first neural network")
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 2ms/step - loss: 1184.4322
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 927.4743
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 741.3993
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 568.8067
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 449.9141
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 312.5534
# Epoch 7/100
# 4/4 [==============================] - 0s 3ms/step - loss: 193.4547
# Epoch 8/100
# 4/4 [==============================] - 0s 3ms/step - loss: 131.2969
# Epoch 9/100
# 4/4 [==============================] - 0s 3ms/step - loss: 137.2595
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 158.8087
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 159.8253
# Epoch 12/100
# 4/4 [==============================] - 0s 3ms/step - loss: 140.3820
# Epoch 13/100
# 4/4 [==============================] - 0s 3ms/step - loss: 126.2566
# Epoch 14/100
# 4/4 [==============================] - 0s 3ms/step - loss: 142.9683
# Epoch 15/100
# 4/4 [==============================] - 0s 3ms/step - loss: 129.5445
# Epoch 16/100
# 4/4 [==============================] - 0s 3ms/step - loss: 132.1359
# Epoch 17/100
# 4/4 [==============================] - 0s 3ms/step - loss: 122.0590
# Epoch 18/100
# 4/4 [==============================] - 0s 3ms/step - loss: 127.8275
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 131.2812
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 131.3933
# Epoch 21/100
# 4/4 [==============================] - 0s 3ms/step - loss: 128.1972
# Epoch 22/100
# 4/4 [==============================] - 0s 3ms/step - loss: 129.2611
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: 116.8287
# Epoch 24/100
# 4/4 [==============================] - 0s 3ms/step - loss: 133.9081
# Epoch 25/100
# 4/4 [==============================] - 0s 3ms/step - loss: 123.6787
# Epoch 26/100
# 4/4 [==============================] - 0s 3ms/step - loss: 121.9335
# Epoch 27/100
# 4/4 [==============================] - 0s 3ms/step - loss: 123.6106
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: 127.5677
# Epoch 29/100
# 4/4 [==============================] - 0s 2ms/step - loss: 134.2161
# Epoch 30/100
# 4/4 [==============================] - 0s 3ms/step - loss: 131.1312
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/step - loss: 136.1532
# Epoch 32/100
# 4/4 [==============================] - 0s 3ms/step - loss: 145.9477
# Epoch 33/100
# 4/4 [==============================] - 0s 3ms/step - loss: 134.4917
# Epoch 34/100
# 4/4 [==============================] - 0s 3ms/step - loss: 130.6929
# Epoch 35/100
# 4/4 [==============================] - 0s 3ms/step - loss: 118.5758
# Epoch 36/100
# 4/4 [==============================] - 0s 3ms/step - loss: 126.5248
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 124.3246
# Epoch 38/100
# 4/4 [==============================] - 0s 3ms/step - loss: 119.9653
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 124.0806
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 132.7536
# Epoch 41/100
# 4/4 [==============================] - 0s 3ms/step - loss: 127.5110
# Epoch 42/100
# 4/4 [==============================] - 0s 3ms/step - loss: 129.1080
# Epoch 43/100
# 4/4 [==============================] - 0s 3ms/step - loss: 138.0401
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 132.3317
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 133.1655
# Epoch 46/100
# 4/4 [==============================] - 0s 3ms/step - loss: 122.6922
# Epoch 47/100
# 4/4 [==============================] - 0s 3ms/step - loss: 124.8041
# Epoch 48/100
# 4/4 [==============================] - 0s 3ms/step - loss: 126.8182
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 130.7758
# Epoch 50/100
# 4/4 [==============================] - 0s 3ms/step - loss: 127.5137
# Epoch 51/100
# 4/4 [==============================] - 0s 2ms/step - loss: 121.3655
# Epoch 52/100
# 4/4 [==============================] - 0s 2ms/step - loss: 122.1576
# Epoch 53/100
# 4/4 [==============================] - 0s 3ms/step - loss: 130.0573
# Epoch 54/100
# 4/4 [==============================] - 0s 3ms/step - loss: 134.9152
# Epoch 55/100
# 4/4 [==============================] - 0s 3ms/step - loss: 144.6538
# Epoch 56/100
# 4/4 [==============================] - 0s 3ms/step - loss: 123.8656
# Epoch 57/100
# 4/4 [==============================] - 0s 3ms/step - loss: 130.4305
# Epoch 58/100
# 4/4 [==============================] - 0s 4ms/step - loss: 118.6741
# Epoch 59/100
# 4/4 [==============================] - 0s 4ms/step - loss: 131.4417
# Epoch 60/100
# 4/4 [==============================] - 0s 3ms/step - loss: 121.4085
# Epoch 61/100
# 4/4 [==============================] - 0s 3ms/step - loss: 127.2103
# Epoch 62/100
# 4/4 [==============================] - 0s 3ms/step - loss: 130.4792
# Epoch 63/100
# 4/4 [==============================] - 0s 3ms/step - loss: 117.1747
# Epoch 64/100
# 4/4 [==============================] - 0s 2ms/step - loss: 134.4798
# Epoch 65/100
# 4/4 [==============================] - 0s 3ms/step - loss: 128.9630
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 134.5550
# Epoch 67/100
# 4/4 [==============================] - 0s 3ms/step - loss: 125.4597
# Epoch 68/100
# 4/4 [==============================] - 0s 3ms/step - loss: 124.1512
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 133.0511
# Epoch 70/100
# 4/4 [==============================] - 0s 3ms/step - loss: 135.7191
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 126.2866
# Epoch 72/100
# 4/4 [==============================] - 0s 2ms/step - loss: 140.7624
# Epoch 73/100
# 4/4 [==============================] - 0s 3ms/step - loss: 142.2445
# Epoch 74/100
# 4/4 [==============================] - 0s 3ms/step - loss: 135.3476
# Epoch 75/100
# 4/4 [==============================] - 0s 3ms/step - loss: 135.0859
# Epoch 76/100
# 4/4 [==============================] - 0s 3ms/step - loss: 136.1028
# Epoch 77/100
# 4/4 [==============================] - 0s 3ms/step - loss: 136.8920
# Epoch 78/100
# 4/4 [==============================] - 0s 3ms/step - loss: 133.4402
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/step - loss: 119.1848
# Epoch 80/100
# 4/4 [==============================] - 0s 3ms/step - loss: 122.8102
# Epoch 81/100
# 4/4 [==============================] - 0s 3ms/step - loss: 134.5991
# Epoch 82/100
# 4/4 [==============================] - 0s 3ms/step - loss: 131.0942
# Epoch 83/100
# 4/4 [==============================] - 0s 3ms/step - loss: 127.3360
# Epoch 84/100
# 4/4 [==============================] - 0s 2ms/step - loss: 132.6406
# Epoch 85/100
# 4/4 [==============================] - 0s 2ms/step - loss: 137.2579
# Epoch 86/100
# 4/4 [==============================] - 0s 2ms/step - loss: 132.3714
# Epoch 87/100
# 4/4 [==============================] - 0s 3ms/step - loss: 126.5939
# Epoch 88/100
# 4/4 [==============================] - 0s 3ms/step - loss: 131.8111
# Epoch 89/100
# 4/4 [==============================] - 0s 3ms/step - loss: 134.8549
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 132.0352
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 136.1576
# Epoch 92/100
# 4/4 [==============================] - 0s 3ms/step - loss: 127.2269
# Epoch 93/100
# 4/4 [==============================] - 0s 3ms/step - loss: 133.0049
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 145.2503
# Epoch 95/100
# 4/4 [==============================] - 0s 3ms/step - loss: 128.2392
# Epoch 96/100
# 4/4 [==============================] - 0s 3ms/step - loss: 128.6966
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 134.0600
# Epoch 98/100
# 4/4 [==============================] - 0s 3ms/step - loss: 130.8045
# Epoch 99/100
# 4/4 [==============================] - 0s 2ms/step - loss: 122.7275
# Epoch 100/100
# 4/4 [==============================] - 0s 3ms/step - loss: 128.8589
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     163     try:
# --> 164         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     165     except OSError as e:
#
# ~\anaconda3\envs\PythonData\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# ~\anaconda3\envs\PythonData\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1016                                          os.fspath(cwd) if cwd is not None else None,
# -> 1017                                          startupinfo)
#    1018             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-13-f7664fc77d66> in <module>
#       9 from ann_visualizer.visualize import ann_viz;
#      10
# ---> 11 ann_viz(model, title="My first neural network")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\ann_visualizer\visualize.py in ann_viz(model, view, filename, title)
#     204         g.edge_attr.update(arrowhead="none", color="#707070");
#     205         if view == True:
# --> 206             g.view();
#
# ~\anaconda3\envs\PythonData\lib\site-packages\graphviz\files.py in view(self, filename, directory, cleanup, quiet, quiet_view)
#     282         return self.render(filename=filename, directory=directory,
#     283                            view=True, cleanup=cleanup,
# --> 284                            quiet=quiet, quiet_view=quiet_view)
#     285
#     286     def _view(self, filepath, format, quiet):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\graphviz\files.py in render(self, filename, directory, view, cleanup, format, renderer, formatter, quiet, quiet_view)
#     243         rendered = backend.render(self._engine, format, filepath,
#     244                                   renderer=renderer, formatter=formatter,
# --> 245                                   quiet=quiet)
#     246
#     247         if cleanup:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\graphviz\backend.py in render(***failed resolving arguments***)
#     221         cwd = None
#     222
# --> 223     run(cmd, capture_output=True, cwd=cwd, check=True, quiet=quiet)
#     224     return rendered
#     225
#
# ~\anaconda3\envs\PythonData\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     165     except OSError as e:
#     166         if e.errno == errno.ENOENT:
# --> 167             raise ExecutableNotFound(cmd)
#     168         else:
#     169             raise
#
# ExecutableNotFound: failed to execute ['dot', '-Kdot', '-Tpdf', '-O', 'network.gv'], make sure the Graphviz executables are on your systems' PATH
