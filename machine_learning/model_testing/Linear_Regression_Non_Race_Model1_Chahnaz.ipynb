# %% [markdown]
# # Machine Learning Linear Regression Model 1
# > ## Maternal Mortality Analysis without Race
# ***

# %% [markdown]
# ### Importing Dependencies

# %%
# Importing dependencies:
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read the CSV and Perform Basic Data Cleaning

# %%
# Reading the csv file into a pandas DataFrame
mmr_without_race = pd.read_csv('../Resources/non_race_data.csv')
mmr_without_race
# Out:
#      year      state     id state_code   latitude  longitude  deaths   births  \
# 0    2015    Alabama  US.AL         AL  32.318231 -86.902298    12.0  59657.0
# 1    2016    Alabama  US.AL         AL  32.318231 -86.902298    35.0  59151.0
# 2    2017    Alabama  US.AL         AL  32.318231 -86.902298    41.0  58941.0
# 3    2018    Alabama  US.AL         AL  32.318231 -86.902298    31.0  57761.0
# 4    2019    Alabama  US.AL         AL  32.318231 -86.902298    35.0  58615.0
# ..    ...        ...    ...        ...        ...        ...     ...      ...
# 303  2014  Wisconsin  US.WI         WI  43.784440 -88.787868    16.0  67161.0
# 304  2015  Wisconsin  US.WI         WI  43.784440 -88.787868    11.0  67041.0
# 305  2016  Wisconsin  US.WI         WI  43.784440 -88.787868    15.0  66615.0
# 306  2017  Wisconsin  US.WI         WI  43.784440 -88.787868    12.0  64975.0
# 307  2019  Wisconsin  US.WI         WI  43.784440 -88.787868    13.0  63270.0
#
#      maternal_mortality_ratio  population  ...  prem_death_val  smoking_val  \
# 0                       20.11   2505795.0  ...         10095.0         21.1
# 1                       59.17   2507714.0  ...         10097.0         21.4
# 2                       69.56   2514911.0  ...         10321.0         21.5
# 3                       53.67   2523756.0  ...         10720.0         20.9
# 4                       59.71   2533668.0  ...         10435.0         19.2
# ..                        ...         ...  ...             ...          ...
# 303                     23.82   2898057.0  ...          6207.0         18.7
# 304                     16.41   2903737.0  ...          6365.0         17.4
# 305                     22.52   2905282.0  ...          6324.0         17.3
# 306                     18.47   2912745.0  ...          6437.0         17.1
# 307                     20.55   2925225.0  ...          6800.0         16.4
#
#      uninsured_val  all_determs_val  all_outcomes_val  chlamydia_val  \
# 0             12.9           -0.371            -0.325          611.0
# 1             11.1           -0.427            -0.366          600.2
# 2              9.6           -0.427            -0.335          543.6
# 3              9.3           -0.483            -0.356          553.6
# 4              9.7           -0.437            -0.383          614.1
# ..             ...              ...               ...            ...
# 303            9.0            0.165             0.067          415.4
# 304            8.2            0.146             0.046          411.6
# 305            6.5            0.114             0.106          403.2
# 306            5.5            0.201             0.072          423.5
# 307            5.5            0.129             0.074          478.6
#
#      prem_death_ri_val  teen_birth_val  primary_care_val  low_birthweight_val
# 0                  1.2            34.3             103.5                 10.0
# 1                  1.1            32.0             116.4                 10.1
# 2                  1.2            30.1             119.3                 10.4
# 3                  1.1            28.4             122.8                 10.3
# 4                  1.2            27.0             122.8                 10.3
# ..                 ...             ...               ...                  ...
# 303                2.0            21.9             125.0                  7.1
# 304                1.9            19.6             125.3                  7.0
# 305                1.9            18.0             140.3                  7.3
# 306                1.9            16.2             145.2                  7.3
# 307                2.0            13.8             152.4                  7.7
#
# [308 rows x 42 columns]

# %%
# Checking dataframe rows
mmr_without_race.count()
# Out:
# year                        308
# state                       308
# id                          308
# state_code                  308
# latitude                    308
# longitude                   308
# deaths                      308
# births                      308
# maternal_mortality_ratio    308
# population                  308
# employer                    308
# non_group                   308
# medicaid                    308
# medicare                    308
# military                    308
# uninsured                   308
# air_pollution_val           308
# cancer_death_val            308
# cardio_death_val            308
# child_pov_val               308
# choles_check_val            308
# dent_vis_val                308
# dentists_val                308
# diabetes_val                308
# drug_deaths_val             308
# health_stat_fem_val         308
# immun_child_val             308
# income_ineq_val             308
# infant_mort_val             308
# infect_dis_val              308
# obesity_val                 308
# phys_inac_val               308
# prem_death_val              308
# smoking_val                 308
# uninsured_val               308
# all_determs_val             308
# all_outcomes_val            308
# chlamydia_val               308
# prem_death_ri_val           308
# teen_birth_val              308
# primary_care_val            308
# low_birthweight_val         308
# dtype: int64

# %%
# Checking data types and columns
mmr_without_race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      308 non-null    int64
#  1   state                     308 non-null    object
#  2   id                        308 non-null    object
#  3   state_code                308 non-null    object
#  4   latitude                  308 non-null    float64
#  5   longitude                 308 non-null    float64
#  6   deaths                    308 non-null    float64
#  7   births                    308 non-null    float64
#  8   maternal_mortality_ratio  308 non-null    float64
#  9   population                308 non-null    float64
#  10  employer                  308 non-null    float64
#  11  non_group                 308 non-null    float64
#  12  medicaid                  308 non-null    float64
#  13  medicare                  308 non-null    float64
#  14  military                  308 non-null    float64
#  15  uninsured                 308 non-null    float64
#  16  air_pollution_val         308 non-null    float64
#  17  cancer_death_val          308 non-null    float64
#  18  cardio_death_val          308 non-null    float64
#  19  child_pov_val             308 non-null    float64
#  20  choles_check_val          308 non-null    float64
#  21  dent_vis_val              308 non-null    float64
#  22  dentists_val              308 non-null    float64
#  23  diabetes_val              308 non-null    float64
#  24  drug_deaths_val           308 non-null    float64
#  25  health_stat_fem_val       308 non-null    float64
#  26  immun_child_val           308 non-null    float64
#  27  income_ineq_val           308 non-null    float64
#  28  infant_mort_val           308 non-null    float64
#  29  infect_dis_val            308 non-null    float64
#  30  obesity_val               308 non-null    float64
#  31  phys_inac_val             308 non-null    float64
#  32  prem_death_val            308 non-null    float64
#  33  smoking_val               308 non-null    float64
#  34  uninsured_val             308 non-null    float64
#  35  all_determs_val           308 non-null    float64
#  36  all_outcomes_val          308 non-null    float64
#  37  chlamydia_val             308 non-null    float64
#  38  prem_death_ri_val         308 non-null    float64
#  39  teen_birth_val            308 non-null    float64
#  40  primary_care_val          308 non-null    float64
#  41  low_birthweight_val       308 non-null    float64
# dtypes: float64(38), int64(1), object(3)
# memory usage: 101.2+ KB

# %%
mmr_without_race.columns
# Out:
# Index(['year', 'state', 'id', 'state_code', 'latitude', 'longitude', 'deaths',
#        'births', 'maternal_mortality_ratio', 'population', 'employer',
#        'non_group', 'medicaid', 'medicare', 'military', 'uninsured',
#        'air_pollution_val', 'cancer_death_val', 'cardio_death_val',
#        'child_pov_val', 'choles_check_val', 'dent_vis_val', 'dentists_val',
#        'diabetes_val', 'drug_deaths_val', 'health_stat_fem_val',
#        'immun_child_val', 'income_ineq_val', 'infant_mort_val',
#        'infect_dis_val', 'obesity_val', 'phys_inac_val', 'prem_death_val',
#        'smoking_val', 'uninsured_val', 'all_determs_val', 'all_outcomes_val',
#        'chlamydia_val', 'prem_death_ri_val', 'teen_birth_val',
#        'primary_care_val', 'low_birthweight_val'],
#       dtype='object')

# %% [markdown]
# ### Selected Features for the model

# %%
# Selecting the features from the dataframe that will be the X values
selected_features = mmr_without_race[['deaths',
       'births', 'maternal_mortality_ratio', 'population', 'employer',
       'non_group', 'medicaid', 'medicare', 'military', 'uninsured',
       'air_pollution_val', 'cancer_death_val', 'cardio_death_val',
       'child_pov_val', 'choles_check_val', 'dent_vis_val', 'dentists_val',
       'diabetes_val', 'drug_deaths_val', 'health_stat_fem_val',
       'immun_child_val', 'income_ineq_val', 'infant_mort_val',
       'infect_dis_val', 'obesity_val', 'phys_inac_val', 'prem_death_val',
       'smoking_val', 'uninsured_val', 'all_determs_val', 'all_outcomes_val',
       'chlamydia_val', 'prem_death_ri_val', 'teen_birth_val',
       'primary_care_val', 'low_birthweight_val']]
selected_features.head()
# Out:
#    deaths   births  maternal_mortality_ratio  population  employer  non_group  \
# 0    12.0  59657.0                     20.11   2505795.0      57.4        8.9
# 1    35.0  59151.0                     59.17   2507714.0      58.7        9.1
# 2    41.0  58941.0                     69.56   2514911.0      58.0        8.6
# 3    31.0  57761.0                     53.67   2523756.0      58.8        7.5
# 4    35.0  58615.0                     59.71   2533668.0      58.8        7.8
#
#    medicaid  medicare  military  uninsured  ...  prem_death_val  smoking_val  \
# 0      13.6       4.0       2.2       13.9  ...         10095.0         21.1
# 1      13.8       3.8       1.9       12.7  ...         10097.0         21.4
# 2      13.6       4.2       2.3       13.3  ...         10321.0         21.5
# 3      13.7       3.6       2.5       13.9  ...         10720.0         20.9
# 4      13.9       3.8       2.4       13.3  ...         10435.0         19.2
#
#    uninsured_val  all_determs_val  all_outcomes_val  chlamydia_val  \
# 0           12.9           -0.371            -0.325          611.0
# 1           11.1           -0.427            -0.366          600.2
# 2            9.6           -0.427            -0.335          543.6
# 3            9.3           -0.483            -0.356          553.6
# 4            9.7           -0.437            -0.383          614.1
#
#    prem_death_ri_val  teen_birth_val  primary_care_val  low_birthweight_val
# 0                1.2            34.3             103.5                 10.0
# 1                1.1            32.0             116.4                 10.1
# 2                1.2            30.1             119.3                 10.4
# 3                1.1            28.4             122.8                 10.3
# 4                1.2            27.0             122.8                 10.3
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Ploting Data for Visualization using Seaborn Heatmap
# ***

# %% [markdown]
# Correlation Matrix is also called square format formed by performing the `corr()` function on the dataset, and this matrix is plotted on the heatmap

# %%
# Printing the correlation matrix with `corr`
selected_features.corr()
# Out:
#                             deaths    births  maternal_mortality_ratio  \
# deaths                    1.000000  0.821868                  0.235069
# births                    0.821868  1.000000                 -0.229183
# maternal_mortality_ratio  0.235069 -0.229183                  1.000000
# population                0.789032  0.987923                 -0.249864
# employer                 -0.268798 -0.227187                 -0.262488
# non_group                 0.042867  0.094957                 -0.048984
# medicaid                 -0.081354  0.015316                  0.028156
# medicare                 -0.238558 -0.401775                  0.434098
# military                 -0.102549 -0.165440                  0.061844
# uninsured                 0.322587  0.224364                  0.157246
# air_pollution_val         0.193248  0.357900                 -0.157073
# cancer_death_val         -0.243798 -0.394844                  0.380225
# cardio_death_val         -0.043664 -0.195440                  0.435771
# child_pov_val             0.207110  0.090472                  0.348919
# choles_check_val         -0.025838 -0.012709                  0.011713
# dent_vis_val             -0.144108  0.051245                 -0.478982
# dentists_val              0.077386  0.306502                 -0.376888
# diabetes_val              0.107752 -0.076167                  0.504597
# drug_deaths_val          -0.223050 -0.257683                  0.115262
# health_stat_fem_val      -0.252339 -0.057786                 -0.500805
# immun_child_val          -0.064715  0.024073                 -0.195848
# income_ineq_val           0.339384  0.283412                  0.308895
# infant_mort_val          -0.185764 -0.333449                  0.325429
# infect_dis_val            0.075745  0.146541                 -0.154806
# obesity_val              -0.090784 -0.307941                  0.466571
# phys_inac_val             0.082480 -0.138683                  0.489462
# prem_death_val           -0.175551 -0.369198                  0.498445
# smoking_val              -0.247768 -0.400382                  0.329596
# uninsured_val             0.395845  0.311630                  0.122712
# all_determs_val          -0.085967  0.126885                 -0.496458
# all_outcomes_val          0.086018  0.256755                 -0.488129
# chlamydia_val             0.114382 -0.008703                  0.359987
# prem_death_ri_val        -0.237738 -0.067050                 -0.396286
# teen_birth_val            0.048008 -0.025878                  0.157247
# primary_care_val         -0.050138  0.026635                 -0.175889
# low_birthweight_val       0.011313 -0.210687                  0.472751
#
#                           population  employer  non_group  medicaid  medicare  \
# deaths                      0.789032 -0.268798   0.042867 -0.081354 -0.238558
# births                      0.987923 -0.227187   0.094957  0.015316 -0.401775
# maternal_mortality_ratio   -0.249864 -0.262488  -0.048984  0.028156  0.434098
# population                  1.000000 -0.208207   0.132825  0.069372 -0.400145
# employer                   -0.208207  1.000000  -0.084822 -0.131332 -0.408418
# non_group                   0.132825 -0.084822   1.000000 -0.024795 -0.078933
# medicaid                    0.069372 -0.131332  -0.024795  1.000000  0.080199
# medicare                   -0.400145 -0.408418  -0.078933  0.080199  1.000000
# military                   -0.191658 -0.287645   0.198937 -0.416706  0.272047
# uninsured                   0.159225 -0.628036  -0.223255 -0.603635  0.152066
# air_pollution_val           0.322393 -0.004652  -0.412854 -0.235470 -0.083899
# cancer_death_val           -0.398704 -0.164010  -0.327552  0.107574  0.762094
# cardio_death_val           -0.221212 -0.315888  -0.377560  0.004957  0.683542
# child_pov_val               0.064980 -0.758635  -0.160008  0.152601  0.481120
# choles_check_val            0.066372  0.237943   0.038970  0.291061  0.010836
# dent_vis_val                0.078537  0.679043  -0.160948 -0.125201 -0.631912
# dentists_val                0.344175  0.462935   0.052162  0.194294 -0.644779
# diabetes_val               -0.058821 -0.460402   0.004318  0.288176  0.711133
# drug_deaths_val            -0.222355 -0.037471   0.037315  0.380224  0.273155
# health_stat_fem_val        -0.040503  0.632368   0.091995 -0.199145 -0.677254
# immun_child_val             0.006193 -0.013619  -0.381768 -0.271123 -0.159792
# income_ineq_val             0.303970 -0.401613  -0.201239  0.428176  0.223083
# infant_mort_val            -0.350801 -0.317847  -0.288109 -0.172902  0.628006
# infect_dis_val              0.106374 -0.077265  -0.429040 -0.321377 -0.118935
# obesity_val                -0.327227 -0.242881  -0.090545  0.117477  0.692715
# phys_inac_val              -0.151575 -0.370062  -0.239780  0.072589  0.664565
# prem_death_val             -0.390039 -0.518399  -0.227284  0.041218  0.819422
# smoking_val                -0.417872 -0.292632  -0.351730  0.014845  0.724314
# uninsured_val               0.241285 -0.622332  -0.153542 -0.533526  0.077131
# all_determs_val             0.159525  0.627947   0.144042  0.007717 -0.719564
# all_outcomes_val            0.257701  0.513107   0.132474 -0.156394 -0.837802
# chlamydia_val               0.001806 -0.445105  -0.002229  0.264816  0.419071
# prem_death_ri_val          -0.070141  0.474462  -0.047133  0.019945 -0.471778
# teen_birth_val             -0.105223 -0.591573  -0.403596 -0.312497  0.360396
# primary_care_val            0.094877  0.515622   0.013671  0.445830 -0.279727
# low_birthweight_val        -0.211416 -0.411161  -0.212408  0.021510  0.557861
#
#                           military  uninsured  ...  prem_death_val  \
# deaths                   -0.102549   0.322587  ...       -0.175551
# births                   -0.165440   0.224364  ...       -0.369198
# maternal_mortality_ratio  0.061844   0.157246  ...        0.498445
# population               -0.191658   0.159225  ...       -0.390039
# employer                 -0.287645  -0.628036  ...       -0.518399
# non_group                 0.198937  -0.223255  ...       -0.227284
# medicaid                 -0.416706  -0.603635  ...        0.041218
# medicare                  0.272047   0.152066  ...        0.819422
# military                  1.000000   0.318316  ...        0.226023
# uninsured                 0.318316   1.000000  ...        0.345689
# air_pollution_val        -0.202053   0.349289  ...        0.014434
# cancer_death_val          0.025204   0.061857  ...        0.803867
# cardio_death_val          0.024652   0.293556  ...        0.844808
# child_pov_val             0.080386   0.504257  ...        0.620909
# choles_check_val         -0.009537  -0.439761  ...       -0.020052
# dent_vis_val             -0.224387  -0.324495  ...       -0.709516
# dentists_val             -0.291595  -0.441051  ...       -0.765029
# diabetes_val              0.156501   0.060470  ...        0.746847
# drug_deaths_val          -0.071829  -0.294867  ...        0.337980
# health_stat_fem_val      -0.116504  -0.313534  ...       -0.758445
# immun_child_val          -0.018525   0.354245  ...       -0.021455
# income_ineq_val          -0.069641   0.051644  ...        0.242834
# infant_mort_val           0.228449   0.381126  ...        0.836936
# infect_dis_val           -0.030931   0.458918  ...        0.054881
# obesity_val               0.108960   0.046474  ...        0.799950
# phys_inac_val             0.025177   0.249325  ...        0.753420
# prem_death_val            0.226023   0.345689  ...        1.000000
# smoking_val               0.072990   0.246978  ...        0.761194
# uninsured_val             0.282100   0.934328  ...        0.223519
# all_determs_val          -0.172467  -0.473089  ...       -0.885288
# all_outcomes_val         -0.184880  -0.228544  ...       -0.931573
# chlamydia_val             0.174497   0.097330  ...        0.557548
# prem_death_ri_val        -0.327746  -0.297922  ...       -0.515056
# teen_birth_val            0.215214   0.786947  ...        0.567983
# primary_care_val         -0.327872  -0.704647  ...       -0.383808
# low_birthweight_val       0.218896   0.296288  ...        0.759068
#
#                           smoking_val  uninsured_val  all_determs_val  \
# deaths                      -0.247768       0.395845        -0.085967
# births                      -0.400382       0.311630         0.126885
# maternal_mortality_ratio     0.329596       0.122712        -0.496458
# population                  -0.417872       0.241285         0.159525
# employer                    -0.292632      -0.622332         0.627947
# non_group                   -0.351730      -0.153542         0.144042
# medicaid                     0.014845      -0.533526         0.007717
# medicare                     0.724314       0.077131        -0.719564
# military                     0.072990       0.282100        -0.172467
# uninsured                    0.246978       0.934328        -0.473089
# air_pollution_val            0.166790       0.394317        -0.125304
# cancer_death_val             0.841140      -0.036277        -0.702628
# cardio_death_val             0.692811       0.190896        -0.764123
# child_pov_val                0.519304       0.497787        -0.754408
# choles_check_val            -0.225809      -0.512608         0.151191
# dent_vis_val                -0.471548      -0.284530         0.786692
# dentists_val                -0.681493      -0.335864         0.823168
# diabetes_val                 0.464458      -0.010822        -0.712708
# drug_deaths_val              0.126416      -0.366120        -0.148812
# health_stat_fem_val         -0.537599      -0.243513         0.805789
# immun_child_val              0.067161       0.335047         0.106137
# income_ineq_val              0.136175       0.097423        -0.265803
# infant_mort_val              0.718284       0.287312        -0.758892
# infect_dis_val               0.098285       0.456653        -0.063520
# obesity_val                  0.607513      -0.071184        -0.769372
# phys_inac_val                0.661901       0.183535        -0.734360
# prem_death_val               0.761194       0.223519        -0.885288
# smoking_val                  1.000000       0.179174        -0.736502
# uninsured_val                0.179174       1.000000        -0.404292
# all_determs_val             -0.736502      -0.404292         1.000000
# all_outcomes_val            -0.741679      -0.147936         0.857016
# chlamydia_val                0.261782       0.057686        -0.599847
# prem_death_ri_val           -0.312931      -0.262179         0.474048
# teen_birth_val               0.536390       0.752237        -0.611102
# primary_care_val            -0.384367      -0.689066         0.509177
# low_birthweight_val          0.519639       0.244671        -0.692751
#
#                           all_outcomes_val  chlamydia_val  prem_death_ri_val  \
# deaths                            0.086018       0.114382          -0.237738
# births                            0.256755      -0.008703          -0.067050
# maternal_mortality_ratio         -0.488129       0.359987          -0.396286
# population                        0.257701       0.001806          -0.070141
# employer                          0.513107      -0.445105           0.474462
# non_group                         0.132474      -0.002229          -0.047133
# medicaid                         -0.156394       0.264816           0.019945
# medicare                         -0.837802       0.419071          -0.471778
# military                         -0.184880       0.174497          -0.327746
# uninsured                        -0.228544       0.097330          -0.297922
# air_pollution_val                 0.008850      -0.158863           0.043735
# cancer_death_val                 -0.823955       0.373322          -0.374628
# cardio_death_val                 -0.821092       0.502197          -0.484233
# child_pov_val                    -0.622635       0.480229          -0.398403
# choles_check_val                 -0.055253       0.231965          -0.089409
# dent_vis_val                      0.741060      -0.597649           0.519251
# dentists_val                      0.668560      -0.404189           0.292084
# diabetes_val                     -0.859308       0.662307          -0.583376
# drug_deaths_val                  -0.344223       0.060686          -0.233079
# health_stat_fem_val               0.822205      -0.612598           0.563564
# immun_child_val                   0.149441      -0.261644           0.060679
# income_ineq_val                  -0.354992       0.518052          -0.383091
# infant_mort_val                  -0.768279       0.478971          -0.358976
# infect_dis_val                    0.100104      -0.200624           0.095346
# obesity_val                      -0.808942       0.585290          -0.354726
# phys_inac_val                    -0.772111       0.453436          -0.497177
# prem_death_val                   -0.931573       0.557548          -0.515056
# smoking_val                      -0.741679       0.261782          -0.312931
# uninsured_val                    -0.147936       0.057686          -0.262179
# all_determs_val                   0.857016      -0.599847           0.474048
# all_outcomes_val                  1.000000      -0.606804           0.601955
# chlamydia_val                    -0.606804       1.000000          -0.346987
# prem_death_ri_val                 0.601955      -0.346987           1.000000
# teen_birth_val                   -0.411969       0.122540          -0.259975
# primary_care_val                  0.276948      -0.026526           0.143405
# low_birthweight_val              -0.713993       0.682616          -0.506261
#
#                           teen_birth_val  primary_care_val  \
# deaths                          0.048008         -0.050138
# births                         -0.025878          0.026635
# maternal_mortality_ratio        0.157247         -0.175889
# population                     -0.105223          0.094877
# employer                       -0.591573          0.515622
# non_group                      -0.403596          0.013671
# medicaid                       -0.312497          0.445830
# medicare                        0.360396         -0.279727
# military                        0.215214         -0.327872
# uninsured                       0.786947         -0.704647
# air_pollution_val               0.455164         -0.305940
# cancer_death_val                0.368021         -0.151197
# cardio_death_val                0.522421         -0.270405
# child_pov_val                   0.595867         -0.446867
# choles_check_val               -0.542004          0.615085
# dent_vis_val                   -0.378674          0.411763
# dentists_val                   -0.606817          0.592445
# diabetes_val                    0.101760         -0.065069
# drug_deaths_val                -0.185620          0.253810
# health_stat_fem_val            -0.356894          0.292880
# immun_child_val                 0.423879         -0.165311
# income_ineq_val                 0.041014          0.210968
# infant_mort_val                 0.604506         -0.414158
# infect_dis_val                  0.536963         -0.214803
# obesity_val                     0.242349         -0.178859
# phys_inac_val                   0.405792         -0.199871
# prem_death_val                  0.567983         -0.383808
# smoking_val                     0.536390         -0.384367
# uninsured_val                   0.752237         -0.689066
# all_determs_val                -0.611102          0.509177
# all_outcomes_val               -0.411969          0.276948
# chlamydia_val                   0.122540         -0.026526
# prem_death_ri_val              -0.259975          0.143405
# teen_birth_val                  1.000000         -0.705372
# primary_care_val               -0.705372          1.000000
# low_birthweight_val             0.385708         -0.172063
#
#                           low_birthweight_val
# deaths                               0.011313
# births                              -0.210687
# maternal_mortality_ratio             0.472751
# population                          -0.211416
# employer                            -0.411161
# non_group                           -0.212408
# medicaid                             0.021510
# medicare                             0.557861
# military                             0.218896
# uninsured                            0.296288
# air_pollution_val                    0.002079
# cancer_death_val                     0.577306
# cardio_death_val                     0.698784
# child_pov_val                        0.508846
# choles_check_val                     0.188458
# dent_vis_val                        -0.496590
# dentists_val                        -0.510733
# diabetes_val                         0.627985
# drug_deaths_val                      0.075658
# health_stat_fem_val                 -0.587812
# immun_child_val                      0.034630
# income_ineq_val                      0.486606
# infant_mort_val                      0.755678
# infect_dis_val                       0.099283
# obesity_val                          0.552113
# phys_inac_val                        0.645750
# prem_death_val                       0.759068
# smoking_val                          0.519639
# uninsured_val                        0.244671
# all_determs_val                     -0.692751
# all_outcomes_val                    -0.713993
# chlamydia_val                        0.682616
# prem_death_ri_val                   -0.506261
# teen_birth_val                       0.385708
# primary_care_val                    -0.172063
# low_birthweight_val                  1.000000
#
# [36 rows x 36 columns]

# %% [markdown]
# The Heatmap correlation matrix shows how the variables are correlated to each other on a scale of -1 to 1.1 being positively correlated and -1 being inversely correlated.

# %%
# Importing dependencies for heatmap correlation visualization 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Using the figure, axes together using `plt.subplots()` function:
fig, ax = plt.subplots(figsize=(36, 30), dpi=80, facecolor='w', edgecolor='k')

# Calculating the correlation matrix for each features in dataset 
corr = selected_features.dropna().corr()

# Setting features
top_corr_features = corr.index
sns.set(font_scale=3.5)
sns.set_theme(context = "paper", style="ticks", font_scale=1.8)

# include diagonal elements also
mask=np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False

# Adjusting the x & y ticks and adding title
ax.set(title="Maternal Maternity Ratio Heatmap Correlation")
plt.title("Maternal Maternity Ratio Heatmap Correlation", fontsize = 30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)


# Plotting the heatmap
sns.heatmap(corr[top_corr_features], mask=mask, 
            cmap=sns.diverging_palette(220, 10, sep=50, as_cmap=True),
            square=True, annot=True, ax=ax, fmt='.2f', linewidths=2, linecolor='white', 
            cbar_kws={"shrink": .95, "extend":'both'})

# Saving the heatmap
plt.savefig("../../static/img/LR_Non_Race_heatmap1.png")
plt.savefig("../../Images/LR_Non_Race_heatmap1.png")

# %% [markdown]
# #### Based on the above heatmap and the correlation matrix a more focused correlation matrix and heatmap is generated with stronger associations to maternal mortality ratio

# %%
# Selecting the features from the dataframe have stronger associations with maternal mortality ratio
heatmap2 = mmr_without_race[['maternal_mortality_ratio', 'medicare', 
        'cancer_death_val', 'cardio_death_val',
       'child_pov_val', 'dent_vis_val', 'dentists_val',
       'diabetes_val', 'health_stat_fem_val',
       'income_ineq_val', 'infant_mort_val',
       'obesity_val', 'phys_inac_val', 'prem_death_val',
       'smoking_val', 'all_determs_val', 'all_outcomes_val',
       'chlamydia_val', 'prem_death_ri_val', 'low_birthweight_val']]
heatmap2.head()
# Out:
#    maternal_mortality_ratio  medicare  cancer_death_val  cardio_death_val  \
# 0                     20.11       4.0             211.6             330.1
# 1                     59.17       3.8             211.1             332.9
# 2                     69.56       4.2             210.6             339.6
# 3                     53.67       3.6             210.5             342.6
# 4                     59.71       3.8             210.8             347.0
#
#    child_pov_val  dent_vis_val  dentists_val  diabetes_val  \
# 0           25.2          60.0          44.0          12.9
# 1           22.3          60.0          43.8          13.5
# 2           24.3          62.3          43.7          14.6
# 3           24.5          62.3          40.4          14.1
# 4           23.8          60.8          41.8          14.5
#
#    health_stat_fem_val  income_ineq_val  infant_mort_val  obesity_val  \
# 0                 43.5             5.27              8.8         33.5
# 1                 43.8             5.24              8.6         35.6
# 2                 43.8             5.31              8.5         35.7
# 3                 43.5             5.25              8.7         36.3
# 4                 41.1             5.31              8.2         36.2
#
#    phys_inac_val  prem_death_val  smoking_val  all_determs_val  \
# 0           27.6         10095.0         21.1           -0.371
# 1           31.9         10097.0         21.4           -0.427
# 2           29.4         10321.0         21.5           -0.427
# 3           32.0         10720.0         20.9           -0.483
# 4           30.7         10435.0         19.2           -0.437
#
#    all_outcomes_val  chlamydia_val  prem_death_ri_val  low_birthweight_val
# 0            -0.325          611.0                1.2                 10.0
# 1            -0.366          600.2                1.1                 10.1
# 2            -0.335          543.6                1.2                 10.4
# 3            -0.356          553.6                1.1                 10.3
# 4            -0.383          614.1                1.2                 10.3

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Using the figure, axes together using `plt.subplots()` function:
fig, ax = plt.subplots(figsize=(32, 28), dpi=80, facecolor='w', edgecolor='k')

# Calculating the correlation matrix for each features in dataset 
corr = heatmap2.dropna().corr()

# Setting features
top_corr_features = corr.index
sns.set(font_scale=2.5)
sns.set_theme(context = "notebook", style="ticks", font_scale=1.8)

# include diagonal elements also
mask=np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False

# Adjusting the x & y ticks and adding title
ax.set(title="Maternal Maternity Ratio Heatmap Correlation")
plt.title("Maternal Maternity Ratio Heatmap Correlation", fontsize = 25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

# Plotting the heatmap
sns.heatmap(corr[top_corr_features], mask=mask, 
            cmap=sns.diverging_palette(220, 10, sep=50, as_cmap=True),
            square=True, annot=True, ax=ax, fmt='.2f', linewidths=2, linecolor='white', 
            cbar_kws={"shrink": .95, "extend":'both'})

# Saving the heatmap
plt.savefig("../../static/img/LR_Non_Race_heatmap2.png")
plt.savefig("../../Images/LR_Non_Race_heatmap2.png")

# %% [markdown]
# ### Creating a Train Test Split
# ***
# We are using `maternal_mortality_ratio` for the y values

# %%
# Selecting and assigning the X & y values
y = mmr_without_race['maternal_mortality_ratio'].values.reshape(-1,1)
X = selected_features.drop(columns=['maternal_mortality_ratio', 'deaths', 'births'], axis=1)

# %%
# Print the selecting X & y shapes
print('Shape:', X.shape, y.shape)
# Out:
# Shape: (308, 33) (308, 1)

# %% [markdown]
# #### Create a Train Test Split

# %%
# Spliting our data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

# %%
# Checking X_train length
len(X_train)
# Out:
# 215

# %%
# Checking y_train length
len(y_train)
# Out:
# 215

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Linear Regression Baseline Model

# %%
# from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

# %%
# Step 1: Creating a linear regression model
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
# Step 2: Fitting (train) our model to the data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Obtaining the coefficient of determination (R2)
r_sq = model.score(X_train, y_train)
print('Coefficient of determination:', r_sq)
# Out:
# Coefficient of determination: 0.5372717318940253

# %%
# Printing the intercept
print('intercept:', model.intercept_)
# Out:
# intercept: [802.43445073]

# %%
# Printing the slope
print('slope:', model.coef_)
# Out:
# slope: [[-1.52305284e-06 -7.45898318e+00 -8.20725091e+00 -7.44168147e+00
#   -8.90473835e+00 -9.05118233e+00 -7.37963797e+00  1.23546274e+00
#   -2.32081917e-02  2.26801462e-02 -1.85694046e-02 -2.12281418e-01
#   -1.53700191e-02 -4.11082311e-01  2.79487488e-01 -3.63625279e-01
#    2.80072386e-02 -6.63856512e-02  1.11262461e+01 -3.63926869e+00
#    1.40182946e-02  6.20057311e-01  7.49938094e-02  3.66955285e-03
#   -9.51695165e-01  6.08018923e-01 -1.38656342e+01  1.74893131e+01
#   -2.92165873e-02 -1.29918735e+01 -7.14078106e-01 -3.89833886e-02
#    2.28178610e+00]]

# %%
# Step 3: Predicting
y_pred = model.predict(X_test)
print('Predicted response:', y_pred, sep='\n')
# Out:
# Predicted response:
# [[15.24745336]
#  [25.41191391]
#  [36.59494593]
#  [51.24486682]
#  [42.82578603]
#  [46.38372944]
#  [40.6127712 ]
#  [32.02089861]
#  [46.00017402]
#  [22.05798492]
#  [28.05709564]
#  [35.97516243]
#  [17.08126379]
#  [24.40549852]
#  [29.05479021]
#  [16.05749038]
#  [19.44123276]
#  [62.46179715]
#  [35.66008891]
#  [35.91572975]
#  [28.15076624]
#  [43.00956657]
#  [28.74468579]
#  [29.24716838]
#  [29.06942489]
#  [33.02589408]
#  [52.38272795]
#  [11.54638039]
#  [30.88210628]
#  [49.02992253]
#  [53.1888202 ]
#  [55.94497516]
#  [38.33714819]
#  [37.63294122]
#  [25.57295605]
#  [42.78657465]
#  [25.81265897]
#  [38.86858365]
#  [33.47650242]
#  [29.59789036]
#  [25.10490176]
#  [39.57949751]
#  [38.09621088]
#  [34.14788943]
#  [16.33539066]
#  [22.73558011]
#  [42.39259235]
#  [23.43733323]
#  [29.11536199]
#  [25.85030124]
#  [53.401096  ]
#  [31.47729583]
#  [ 8.34357297]
#  [40.55943356]
#  [25.63436441]
#  [28.00712332]
#  [19.52025394]
#  [33.026305  ]
#  [26.20414578]
#  [31.35971454]
#  [39.55370614]
#  [26.23417014]
#  [33.80680813]
#  [50.67227643]
#  [44.59121634]
#  [29.47599101]
#  [29.64505917]
#  [26.11099748]
#  [ 8.777917  ]
#  [48.10735831]
#  [23.3029486 ]
#  [14.77849729]
#  [39.71636443]
#  [21.27217098]
#  [40.67961138]
#  [33.03346756]
#  [37.7013704 ]
#  [ 7.44475202]
#  [10.7025798 ]
#  [30.60124119]
#  [26.70481325]
#  [31.64482144]
#  [13.16177625]
#  [34.63975217]
#  [39.46136821]
#  [35.01810213]
#  [48.25386725]
#  [19.00567561]
#  [35.91080422]
#  [47.61056167]
#  [46.33274318]
#  [ 8.80058711]
#  [31.26732729]]

# %%
# Predicting the min & max values
X_min = np.array([X.min()])
X_max = np.array([X.max()])
print(f"Min X Value: {X_min}")
print(f"Max X Value: {X_max}")
# Out:
# Min X Value: [[ 7.82258e+05  4.68000e+01  4.50000e+00  6.60000e+00  8.00000e-01
#    3.00000e-01  2.60000e+00  5.70000e+00  1.42300e+02  1.82700e+02
#    8.00000e+00  6.63000e+01  5.41000e+01  3.86000e+01  5.90000e+00
#    6.00000e+00  3.93000e+01  5.71000e+01  3.70000e+00  4.10000e+00
#   -1.01700e+00  2.02000e+01  1.57000e+01  5.35800e+03  8.80000e+00
#    2.70000e+00 -7.67000e-01 -3.83000e-01  2.37500e+02  1.00000e+00
#    8.50000e+00  7.61000e+01  6.10000e+00]]
# Max X Value: [[1.9893468e+07 6.9900000e+01 1.4500000e+01 3.1000000e+01 4.2000000e+00
#   5.2000000e+00 2.9900000e+01 1.5300000e+01 2.3490000e+02 3.7370000e+02
#   3.3700000e+01 9.1100000e+01 8.1600000e+01 8.2700000e+01 1.5200000e+01
#   4.1400000e+01 6.1700000e+01 9.5980000e+01 5.8300000e+00 1.0300000e+01
#   3.9900000e+01 3.9500000e+01 3.7200000e+01 1.1485000e+04 2.8300000e+01
#   2.5600000e+01 7.7800000e-01 3.4100000e-01 7.9910000e+02 3.3000000e+00
#   7.1900000e+01 2.4500000e+02 1.2300000e+01]]

# %%
# Calculate the y_min and y_max using model.predict and x_min and x_max
y_min = model.predict(X_min)
y_max = model.predict(X_max)
print(f"Min Y Value: {y_min}")
print(f"Max Y Value: {y_max}")
# Out:
# Min Y Value: [[352.57806899]]
# Max Y Value: [[-470.67097576]]

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Using the model to predict a value
predicted = model.predict(X)

# Scoring the prediction with mse and r2
mse = mean_squared_error(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Mean Squared Error (MSE): 87.8900029431369

# %%
# Calling the `score` method on the model to show the r2 score
model.score(X_test, y_test)
# Out:
# 0.3583576674946365

# %%
# Fitting the model to the training data and calculating the scores for the training and testing data
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.5372717318940253
# Testing Score: 0.3583576674946365

# %%
# Plotting training and testing data
plt.figure(figsize=(10,8))
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="steelblue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Maternal Mortality")
# Out:
# Text(0.5, 1.0, 'Maternal Mortality')

# %% [markdown]
# ## Note:
# ***
# This notebook contains the baseline model for Linear Regression of Maternal Mortality without race, refer to [notebook 2](https://github.com/abpuccini/maternal-mortality-project/blob/main/machine_learning/model_testing/LR_Non_Race_Model2_Chahnaz.ipynb) for further analysis and time-series forcast predictions.

# %% [markdown]
# ### Saving the Model

# %%
# Saving the model with `joblib`
import joblib 

filename = '../models/LR_model1_Chahnaz.sav'
joblib.dump(model, filename)
# Out:
# ['../models/LR_model1_Chahnaz.sav']
