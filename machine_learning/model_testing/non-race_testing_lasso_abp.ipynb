# %%
import pandas as pd

# %%
# Extract CSV file
filepath = "../Resources/non_race_data.csv"
non_race_data = pd.read_csv(filepath)

print(len(non_race_data))
non_race_data.head()
# Out:
# 308
#    year    state     id state_code   latitude  longitude  deaths   births  \
# 0  2015  Alabama  US.AL         AL  32.318231 -86.902298    12.0  59657.0
# 1  2016  Alabama  US.AL         AL  32.318231 -86.902298    35.0  59151.0
# 2  2017  Alabama  US.AL         AL  32.318231 -86.902298    41.0  58941.0
# 3  2018  Alabama  US.AL         AL  32.318231 -86.902298    31.0  57761.0
# 4  2019  Alabama  US.AL         AL  32.318231 -86.902298    35.0  58615.0
#
#    maternal_mortality_ratio  population  ...  prem_death_val  smoking_val  \
# 0                     20.11   2505795.0  ...         10095.0         21.1
# 1                     59.17   2507714.0  ...         10097.0         21.4
# 2                     69.56   2514911.0  ...         10321.0         21.5
# 3                     53.67   2523756.0  ...         10720.0         20.9
# 4                     59.71   2533668.0  ...         10435.0         19.2
#
#    uninsured_val  all_determs_val  all_outcomes_val  chlamydia_val  \
# 0           12.9           -0.371            -0.325          611.0
# 1           11.1           -0.427            -0.366          600.2
# 2            9.6           -0.427            -0.335          543.6
# 3            9.3           -0.483            -0.356          553.6
# 4            9.7           -0.437            -0.383          614.1
#
#    prem_death_ri_val  teen_birth_val  primary_care_val  low_birthweight_val
# 0                1.2            34.3             103.5                 10.0
# 1                1.1            32.0             116.4                 10.1
# 2                1.2            30.1             119.3                 10.4
# 3                1.1            28.4             122.8                 10.3
# 4                1.2            27.0             122.8                 10.3
#
# [5 rows x 42 columns]

# %%
non_race_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      308 non-null    int64
#  1   state                     308 non-null    object
#  2   id                        308 non-null    object
#  3   state_code                308 non-null    object
#  4   latitude                  308 non-null    float64
#  5   longitude                 308 non-null    float64
#  6   deaths                    308 non-null    float64
#  7   births                    308 non-null    float64
#  8   maternal_mortality_ratio  308 non-null    float64
#  9   population                308 non-null    float64
#  10  employer                  308 non-null    float64
#  11  non_group                 308 non-null    float64
#  12  medicaid                  308 non-null    float64
#  13  medicare                  308 non-null    float64
#  14  military                  308 non-null    float64
#  15  uninsured                 308 non-null    float64
#  16  air_pollution_val         308 non-null    float64
#  17  cancer_death_val          308 non-null    float64
#  18  cardio_death_val          308 non-null    float64
#  19  child_pov_val             308 non-null    float64
#  20  choles_check_val          308 non-null    float64
#  21  dent_vis_val              308 non-null    float64
#  22  dentists_val              308 non-null    float64
#  23  diabetes_val              308 non-null    float64
#  24  drug_deaths_val           308 non-null    float64
#  25  health_stat_fem_val       308 non-null    float64
#  26  immun_child_val           308 non-null    float64
#  27  income_ineq_val           308 non-null    float64
#  28  infant_mort_val           308 non-null    float64
#  29  infect_dis_val            308 non-null    float64
#  30  obesity_val               308 non-null    float64
#  31  phys_inac_val             308 non-null    float64
#  32  prem_death_val            308 non-null    float64
#  33  smoking_val               308 non-null    float64
#  34  uninsured_val             308 non-null    float64
#  35  all_determs_val           308 non-null    float64
#  36  all_outcomes_val          308 non-null    float64
#  37  chlamydia_val             308 non-null    float64
#  38  prem_death_ri_val         308 non-null    float64
#  39  teen_birth_val            308 non-null    float64
#  40  primary_care_val          308 non-null    float64
#  41  low_birthweight_val       308 non-null    float64
# dtypes: float64(38), int64(1), object(3)
# memory usage: 101.2+ KB

# %%
non_race_data.corr()
# Out:
#                               year  latitude  longitude    deaths    births  \
# year                      1.000000 -0.027653  -0.004793  0.003753 -0.071986
# latitude                 -0.027653  1.000000  -0.093409 -0.327565 -0.163899
# longitude                -0.004793 -0.093409   1.000000 -0.035413 -0.208043
# deaths                    0.003753 -0.327565  -0.035413  1.000000  0.821868
# births                   -0.071986 -0.163899  -0.208043  0.821868  1.000000
# maternal_mortality_ratio  0.193755 -0.394296   0.170854  0.235069 -0.229183
# population               -0.023038 -0.147033  -0.154017  0.789032  0.987923
# employer                  0.088274  0.718879   0.260086 -0.268798 -0.227187
# non_group                 0.436825 -0.155373  -0.253765  0.042867  0.094957
# medicaid                  0.432700  0.196342  -0.003201 -0.081354  0.015316
# medicare                  0.136949 -0.392994   0.247252 -0.238558 -0.401775
# military                  0.016133 -0.418458  -0.063973 -0.102549 -0.165440
# uninsured                -0.556770 -0.606007  -0.160331  0.322587  0.224364
# air_pollution_val        -0.650710 -0.012822  -0.021402  0.193248  0.357900
# cancer_death_val          0.003502 -0.177266   0.363725 -0.243798 -0.394844
# cardio_death_val         -0.097905 -0.363431   0.274357 -0.043664 -0.195440
# child_pov_val            -0.115628 -0.563403  -0.027460  0.207110  0.090472
# choles_check_val          0.564654  0.002495   0.441126 -0.025838 -0.012709
# dent_vis_val             -0.296100  0.633593   0.147121 -0.144108  0.051245
# dentists_val              0.062348  0.558539  -0.081938  0.077386  0.306502
# diabetes_val              0.477555 -0.544266   0.261648  0.107752 -0.076167
# drug_deaths_val           0.492653 -0.030168   0.034120 -0.223050 -0.257683
# health_stat_fem_val      -0.290985  0.584414  -0.056401 -0.252339 -0.057786
# immun_child_val          -0.626643  0.022177   0.087873 -0.064715  0.024073
# income_ineq_val           0.148032 -0.310538   0.283065  0.339384  0.283412
# infant_mort_val          -0.235558 -0.473378   0.346936 -0.185764 -0.333449
# infect_dis_val           -0.733841 -0.078188   0.058746  0.075745  0.146541
# obesity_val               0.353555 -0.338568   0.180539 -0.090784 -0.307941
# phys_inac_val             0.042305 -0.494314   0.409027  0.082480 -0.138683
# prem_death_val            0.046539 -0.572090   0.187744 -0.175551 -0.369198
# smoking_val              -0.221430 -0.217094   0.281804 -0.247768 -0.400382
# uninsured_val            -0.606058 -0.583706  -0.164899  0.395845  0.311630
# all_determs_val          -0.002987  0.653423  -0.097749 -0.085967  0.126885
# all_outcomes_val         -0.179363  0.540649  -0.238456  0.086018  0.256755
# chlamydia_val             0.378793 -0.468779   0.133204  0.114382 -0.008703
# prem_death_ri_val        -0.125269  0.585510  -0.263424 -0.237738 -0.067050
# teen_birth_val           -0.656458 -0.472547  -0.124243  0.048008 -0.025878
# primary_care_val          0.436571  0.460243   0.358423 -0.050138  0.026635
# low_birthweight_val       0.023204 -0.612014   0.478018  0.011313 -0.210687
#
#                           maternal_mortality_ratio  population  employer  \
# year                                      0.193755   -0.023038  0.088274
# latitude                                 -0.394296   -0.147033  0.718879
# longitude                                 0.170854   -0.154017  0.260086
# deaths                                    0.235069    0.789032 -0.268798
# births                                   -0.229183    0.987923 -0.227187
# maternal_mortality_ratio                  1.000000   -0.249864 -0.262488
# population                               -0.249864    1.000000 -0.208207
# employer                                 -0.262488   -0.208207  1.000000
# non_group                                -0.048984    0.132825 -0.084822
# medicaid                                  0.028156    0.069372 -0.131332
# medicare                                  0.434098   -0.400145 -0.408418
# military                                  0.061844   -0.191658 -0.287645
# uninsured                                 0.157246    0.159225 -0.628036
# air_pollution_val                        -0.157073    0.322393 -0.004652
# cancer_death_val                          0.380225   -0.398704 -0.164010
# cardio_death_val                          0.435771   -0.221212 -0.315888
# child_pov_val                             0.348919    0.064980 -0.758635
# choles_check_val                          0.011713    0.066372  0.237943
# dent_vis_val                             -0.478982    0.078537  0.679043
# dentists_val                             -0.376888    0.344175  0.462935
# diabetes_val                              0.504597   -0.058821 -0.460402
# drug_deaths_val                           0.115262   -0.222355 -0.037471
# health_stat_fem_val                      -0.500805   -0.040503  0.632368
# immun_child_val                          -0.195848    0.006193 -0.013619
# income_ineq_val                           0.308895    0.303970 -0.401613
# infant_mort_val                           0.325429   -0.350801 -0.317847
# infect_dis_val                           -0.154806    0.106374 -0.077265
# obesity_val                               0.466571   -0.327227 -0.242881
# phys_inac_val                             0.489462   -0.151575 -0.370062
# prem_death_val                            0.498445   -0.390039 -0.518399
# smoking_val                               0.329596   -0.417872 -0.292632
# uninsured_val                             0.122712    0.241285 -0.622332
# all_determs_val                          -0.496458    0.159525  0.627947
# all_outcomes_val                         -0.488129    0.257701  0.513107
# chlamydia_val                             0.359987    0.001806 -0.445105
# prem_death_ri_val                        -0.396286   -0.070141  0.474462
# teen_birth_val                            0.157247   -0.105223 -0.591573
# primary_care_val                         -0.175889    0.094877  0.515622
# low_birthweight_val                       0.472751   -0.211416 -0.411161
#
#                           non_group  medicaid  ...  prem_death_val  \
# year                       0.436825  0.432700  ...        0.046539
# latitude                  -0.155373  0.196342  ...       -0.572090
# longitude                 -0.253765 -0.003201  ...        0.187744
# deaths                     0.042867 -0.081354  ...       -0.175551
# births                     0.094957  0.015316  ...       -0.369198
# maternal_mortality_ratio  -0.048984  0.028156  ...        0.498445
# population                 0.132825  0.069372  ...       -0.390039
# employer                  -0.084822 -0.131332  ...       -0.518399
# non_group                  1.000000 -0.024795  ...       -0.227284
# medicaid                  -0.024795  1.000000  ...        0.041218
# medicare                  -0.078933  0.080199  ...        0.819422
# military                   0.198937 -0.416706  ...        0.226023
# uninsured                 -0.223255 -0.603635  ...        0.345689
# air_pollution_val         -0.412854 -0.235470  ...        0.014434
# cancer_death_val          -0.327552  0.107574  ...        0.803867
# cardio_death_val          -0.377560  0.004957  ...        0.844808
# child_pov_val             -0.160008  0.152601  ...        0.620909
# choles_check_val           0.038970  0.291061  ...       -0.020052
# dent_vis_val              -0.160948 -0.125201  ...       -0.709516
# dentists_val               0.052162  0.194294  ...       -0.765029
# diabetes_val               0.004318  0.288176  ...        0.746847
# drug_deaths_val            0.037315  0.380224  ...        0.337980
# health_stat_fem_val        0.091995 -0.199145  ...       -0.758445
# immun_child_val           -0.381768 -0.271123  ...       -0.021455
# income_ineq_val           -0.201239  0.428176  ...        0.242834
# infant_mort_val           -0.288109 -0.172902  ...        0.836936
# infect_dis_val            -0.429040 -0.321377  ...        0.054881
# obesity_val               -0.090545  0.117477  ...        0.799950
# phys_inac_val             -0.239780  0.072589  ...        0.753420
# prem_death_val            -0.227284  0.041218  ...        1.000000
# smoking_val               -0.351730  0.014845  ...        0.761194
# uninsured_val             -0.153542 -0.533526  ...        0.223519
# all_determs_val            0.144042  0.007717  ...       -0.885288
# all_outcomes_val           0.132474 -0.156394  ...       -0.931573
# chlamydia_val             -0.002229  0.264816  ...        0.557548
# prem_death_ri_val         -0.047133  0.019945  ...       -0.515056
# teen_birth_val            -0.403596 -0.312497  ...        0.567983
# primary_care_val           0.013671  0.445830  ...       -0.383808
# low_birthweight_val       -0.212408  0.021510  ...        0.759068
#
#                           smoking_val  uninsured_val  all_determs_val  \
# year                        -0.221430      -0.606058        -0.002987
# latitude                    -0.217094      -0.583706         0.653423
# longitude                    0.281804      -0.164899        -0.097749
# deaths                      -0.247768       0.395845        -0.085967
# births                      -0.400382       0.311630         0.126885
# maternal_mortality_ratio     0.329596       0.122712        -0.496458
# population                  -0.417872       0.241285         0.159525
# employer                    -0.292632      -0.622332         0.627947
# non_group                   -0.351730      -0.153542         0.144042
# medicaid                     0.014845      -0.533526         0.007717
# medicare                     0.724314       0.077131        -0.719564
# military                     0.072990       0.282100        -0.172467
# uninsured                    0.246978       0.934328        -0.473089
# air_pollution_val            0.166790       0.394317        -0.125304
# cancer_death_val             0.841140      -0.036277        -0.702628
# cardio_death_val             0.692811       0.190896        -0.764123
# child_pov_val                0.519304       0.497787        -0.754408
# choles_check_val            -0.225809      -0.512608         0.151191
# dent_vis_val                -0.471548      -0.284530         0.786692
# dentists_val                -0.681493      -0.335864         0.823168
# diabetes_val                 0.464458      -0.010822        -0.712708
# drug_deaths_val              0.126416      -0.366120        -0.148812
# health_stat_fem_val         -0.537599      -0.243513         0.805789
# immun_child_val              0.067161       0.335047         0.106137
# income_ineq_val              0.136175       0.097423        -0.265803
# infant_mort_val              0.718284       0.287312        -0.758892
# infect_dis_val               0.098285       0.456653        -0.063520
# obesity_val                  0.607513      -0.071184        -0.769372
# phys_inac_val                0.661901       0.183535        -0.734360
# prem_death_val               0.761194       0.223519        -0.885288
# smoking_val                  1.000000       0.179174        -0.736502
# uninsured_val                0.179174       1.000000        -0.404292
# all_determs_val             -0.736502      -0.404292         1.000000
# all_outcomes_val            -0.741679      -0.147936         0.857016
# chlamydia_val                0.261782       0.057686        -0.599847
# prem_death_ri_val           -0.312931      -0.262179         0.474048
# teen_birth_val               0.536390       0.752237        -0.611102
# primary_care_val            -0.384367      -0.689066         0.509177
# low_birthweight_val          0.519639       0.244671        -0.692751
#
#                           all_outcomes_val  chlamydia_val  prem_death_ri_val  \
# year                             -0.179363       0.378793          -0.125269
# latitude                          0.540649      -0.468779           0.585510
# longitude                        -0.238456       0.133204          -0.263424
# deaths                            0.086018       0.114382          -0.237738
# births                            0.256755      -0.008703          -0.067050
# maternal_mortality_ratio         -0.488129       0.359987          -0.396286
# population                        0.257701       0.001806          -0.070141
# employer                          0.513107      -0.445105           0.474462
# non_group                         0.132474      -0.002229          -0.047133
# medicaid                         -0.156394       0.264816           0.019945
# medicare                         -0.837802       0.419071          -0.471778
# military                         -0.184880       0.174497          -0.327746
# uninsured                        -0.228544       0.097330          -0.297922
# air_pollution_val                 0.008850      -0.158863           0.043735
# cancer_death_val                 -0.823955       0.373322          -0.374628
# cardio_death_val                 -0.821092       0.502197          -0.484233
# child_pov_val                    -0.622635       0.480229          -0.398403
# choles_check_val                 -0.055253       0.231965          -0.089409
# dent_vis_val                      0.741060      -0.597649           0.519251
# dentists_val                      0.668560      -0.404189           0.292084
# diabetes_val                     -0.859308       0.662307          -0.583376
# drug_deaths_val                  -0.344223       0.060686          -0.233079
# health_stat_fem_val               0.822205      -0.612598           0.563564
# immun_child_val                   0.149441      -0.261644           0.060679
# income_ineq_val                  -0.354992       0.518052          -0.383091
# infant_mort_val                  -0.768279       0.478971          -0.358976
# infect_dis_val                    0.100104      -0.200624           0.095346
# obesity_val                      -0.808942       0.585290          -0.354726
# phys_inac_val                    -0.772111       0.453436          -0.497177
# prem_death_val                   -0.931573       0.557548          -0.515056
# smoking_val                      -0.741679       0.261782          -0.312931
# uninsured_val                    -0.147936       0.057686          -0.262179
# all_determs_val                   0.857016      -0.599847           0.474048
# all_outcomes_val                  1.000000      -0.606804           0.601955
# chlamydia_val                    -0.606804       1.000000          -0.346987
# prem_death_ri_val                 0.601955      -0.346987           1.000000
# teen_birth_val                   -0.411969       0.122540          -0.259975
# primary_care_val                  0.276948      -0.026526           0.143405
# low_birthweight_val              -0.713993       0.682616          -0.506261
#
#                           teen_birth_val  primary_care_val  \
# year                           -0.656458          0.436571
# latitude                       -0.472547          0.460243
# longitude                      -0.124243          0.358423
# deaths                          0.048008         -0.050138
# births                         -0.025878          0.026635
# maternal_mortality_ratio        0.157247         -0.175889
# population                     -0.105223          0.094877
# employer                       -0.591573          0.515622
# non_group                      -0.403596          0.013671
# medicaid                       -0.312497          0.445830
# medicare                        0.360396         -0.279727
# military                        0.215214         -0.327872
# uninsured                       0.786947         -0.704647
# air_pollution_val               0.455164         -0.305940
# cancer_death_val                0.368021         -0.151197
# cardio_death_val                0.522421         -0.270405
# child_pov_val                   0.595867         -0.446867
# choles_check_val               -0.542004          0.615085
# dent_vis_val                   -0.378674          0.411763
# dentists_val                   -0.606817          0.592445
# diabetes_val                    0.101760         -0.065069
# drug_deaths_val                -0.185620          0.253810
# health_stat_fem_val            -0.356894          0.292880
# immun_child_val                 0.423879         -0.165311
# income_ineq_val                 0.041014          0.210968
# infant_mort_val                 0.604506         -0.414158
# infect_dis_val                  0.536963         -0.214803
# obesity_val                     0.242349         -0.178859
# phys_inac_val                   0.405792         -0.199871
# prem_death_val                  0.567983         -0.383808
# smoking_val                     0.536390         -0.384367
# uninsured_val                   0.752237         -0.689066
# all_determs_val                -0.611102          0.509177
# all_outcomes_val               -0.411969          0.276948
# chlamydia_val                   0.122540         -0.026526
# prem_death_ri_val              -0.259975          0.143405
# teen_birth_val                  1.000000         -0.705372
# primary_care_val               -0.705372          1.000000
# low_birthweight_val             0.385708         -0.172063
#
#                           low_birthweight_val
# year                                 0.023204
# latitude                            -0.612014
# longitude                            0.478018
# deaths                               0.011313
# births                              -0.210687
# maternal_mortality_ratio             0.472751
# population                          -0.211416
# employer                            -0.411161
# non_group                           -0.212408
# medicaid                             0.021510
# medicare                             0.557861
# military                             0.218896
# uninsured                            0.296288
# air_pollution_val                    0.002079
# cancer_death_val                     0.577306
# cardio_death_val                     0.698784
# child_pov_val                        0.508846
# choles_check_val                     0.188458
# dent_vis_val                        -0.496590
# dentists_val                        -0.510733
# diabetes_val                         0.627985
# drug_deaths_val                      0.075658
# health_stat_fem_val                 -0.587812
# immun_child_val                      0.034630
# income_ineq_val                      0.486606
# infant_mort_val                      0.755678
# infect_dis_val                       0.099283
# obesity_val                          0.552113
# phys_inac_val                        0.645750
# prem_death_val                       0.759068
# smoking_val                          0.519639
# uninsured_val                        0.244671
# all_determs_val                     -0.692751
# all_outcomes_val                    -0.713993
# chlamydia_val                        0.682616
# prem_death_ri_val                   -0.506261
# teen_birth_val                       0.385708
# primary_care_val                    -0.172063
# low_birthweight_val                  1.000000
#
# [39 rows x 39 columns]

# %%
# Selecting the features from the dataframe that will be the X values
selected_features = non_race_data[['maternal_mortality_ratio', 'population', 'employer',
       'non_group', 'medicaid', 'medicare', 'military', 'uninsured',
       'air_pollution_val', 'cancer_death_val', 'cardio_death_val',
       'child_pov_val', 'choles_check_val', 'dent_vis_val', 'dentists_val',
       'diabetes_val', 'drug_deaths_val', 'health_stat_fem_val',
       'immun_child_val', 'income_ineq_val', 'infant_mort_val',
       'infect_dis_val', 'obesity_val', 'phys_inac_val', 'prem_death_val',
       'smoking_val', 'uninsured_val', 'all_determs_val', 'all_outcomes_val',
       'chlamydia_val', 'prem_death_ri_val', 'teen_birth_val',
       'primary_care_val', 'low_birthweight_val']]
selected_features.head()
# Out:
#    maternal_mortality_ratio  population  employer  non_group  medicaid  \
# 0                     20.11   2505795.0      57.4        8.9      13.6
# 1                     59.17   2507714.0      58.7        9.1      13.8
# 2                     69.56   2514911.0      58.0        8.6      13.6
# 3                     53.67   2523756.0      58.8        7.5      13.7
# 4                     59.71   2533668.0      58.8        7.8      13.9
#
#    medicare  military  uninsured  air_pollution_val  cancer_death_val  ...  \
# 0       4.0       2.2       13.9                9.5             211.6  ...
# 1       3.8       1.9       12.7                9.1             211.1  ...
# 2       4.2       2.3       13.3                8.9             210.6  ...
# 3       3.6       2.5       13.9                8.4             210.5  ...
# 4       3.8       2.4       13.3                8.1             210.8  ...
#
#    prem_death_val  smoking_val  uninsured_val  all_determs_val  \
# 0         10095.0         21.1           12.9           -0.371
# 1         10097.0         21.4           11.1           -0.427
# 2         10321.0         21.5            9.6           -0.427
# 3         10720.0         20.9            9.3           -0.483
# 4         10435.0         19.2            9.7           -0.437
#
#    all_outcomes_val  chlamydia_val  prem_death_ri_val  teen_birth_val  \
# 0            -0.325          611.0                1.2            34.3
# 1            -0.366          600.2                1.1            32.0
# 2            -0.335          543.6                1.2            30.1
# 3            -0.356          553.6                1.1            28.4
# 4            -0.383          614.1                1.2            27.0
#
#    primary_care_val  low_birthweight_val
# 0             103.5                 10.0
# 1             116.4                 10.1
# 2             119.3                 10.4
# 3             122.8                 10.3
# 4             122.8                 10.3
#
# [5 rows x 34 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Using the figure, axes together using `plt.subplots()` function:
fig, ax = plt.subplots(figsize=(36, 30), dpi=80, facecolor='w', edgecolor='k')

# Calculating the correlation matrix for each features in dataset 
corr = selected_features.dropna().corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Want diagonal elements as well
mask[np.diag_indices_from(mask)] = False

# Setting features
top_corr_features = corr.index
sns.set(font_scale=3.5)
sns.set_theme(context = "paper", style="ticks", font_scale=1.8)


# Adjusting the x & y ticks and adding title
ax.set(title="Maternal Maternity Ratio Heatmap Correlation")
plt.title("Maternal Maternity Ratio Heatmap Correlation", fontsize = 30, fontweight='bold')
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)


# Plotting the heatmap
sns.heatmap(corr[top_corr_features], mask=mask, 
            cmap=sns.diverging_palette(220, 10, sep=50, as_cmap=True),
            square=True, annot=True, ax=ax, fmt='.2f', linewidths=1, linecolor='white', 
            cbar_kws={"shrink": .95, "extend":'both'})

plt.savefig('../../static/img/heatmap_non_race.png')

plt.show()

# %%
# Selecting and assigning the X & y values

X = selected_features.drop(columns=['maternal_mortality_ratio'], axis=1)
y = non_race_data['maternal_mortality_ratio'].values.reshape(-1, 1)

# %%
# Print the selecting X & y shapes
print('Shape:', X.shape, y.shape)
# Out:
# Shape: (308, 33) (308, 1)

# %%
# Spliting our data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

# %%
# LASSO model
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Lasso
from numpy import arange

# Note: Use an alpha of .01 when creating the model for this activity
lasso = Lasso(alpha=0.01).fit(X_train, y_train)
predictions = lasso.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = lasso.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")
lasso.coef_
# Out:
# MSE: 108.44880828950066, R2: 0.3658376295023624
# /Users/abpuccini/opt/anaconda3/envs/finalproject/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8486.1440884434, tolerance: 3.6447784448372094
#   positive)
# array([-1.52133323e-06, -2.93138316e-02, -7.63118726e-01,  0.00000000e+00,
#        -1.68535241e+00, -1.59511007e+00,  8.43934867e-02,  1.26900031e+00,
#        -4.93962812e-02,  2.24750129e-02,  5.31102006e-03, -1.83699074e-01,
#        -5.10346882e-02, -4.12883297e-01, -0.00000000e+00, -3.79071693e-01,
#         3.93715500e-02, -7.27743827e-02,  1.08550926e+01, -3.90326519e+00,
#         2.16297675e-02,  7.38637570e-01,  7.38806090e-02,  3.11127260e-03,
#        -9.63061782e-01,  5.52578404e-01, -1.15405763e+01,  5.51570496e+00,
#        -3.21411361e-02, -1.23349195e+01, -6.79659101e-01, -3.82167939e-02,
#         2.67039927e+00])

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
# LASSO model
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Lasso
from numpy import arange

# Note: Use an alpha of .01 when creating the model for this activity
lasso = Lasso(alpha=0.01).fit(X_train_scaled, y_train_scaled)
predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
lasso.coef_
# Out:
# MSE: 0.5963059205636168, R2: 0.40887751404226225
# array([-0.42415782,  0.        , -0.07545003, -0.08768569, -0.        ,
#        -0.14307192,  0.        ,  0.03737676, -0.        ,  0.        ,
#         0.        , -0.03506447, -0.        , -0.18501126,  0.0259851 ,
#        -0.06074705, -0.02932363, -0.04386043,  0.295947  , -0.19022684,
#        -0.        ,  0.10996376,  0.02423262,  0.        , -0.28065643,
#         0.05624244, -0.41352657,  0.        , -0.14678733, -0.20719432,
#        -0.30975314, -0.11102478,  0.1789432 ])

# %%
# Source: https://machinelearningmastery.com/lasso-regression-with-python/

# define model
model = Lasso()

# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=42)

# define grid
grid = dict()
grid['alpha'] = arange(0, 1, 0.01)

# define search
search = GridSearchCV(model, grid, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# perform the search
results = search.fit(X_train_scaled, y_train_scaled)

# summarize
print('MAE: %.3f' % results.best_score_)
print('Config: %s' % results.best_params_)
# Out:
# MAE: -0.601
# Config: {'alpha': 0.02}

# %%
predictions_grid = results.predict(X_test_scaled)

MSE_grid = mean_squared_error(y_test_scaled, predictions_grid)
r2_grid = results.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE_grid}, R2: {r2_grid}")
# Out:
# MSE: 0.590268544860258, R2: -0.6168681604462024
